# %%
import scipy as sp
import numpy as np
import pandas as pd
import timeit
import re
import json
import pickle
import fastparquet
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.iolib.summary2 as summary2
import logging
# Out:
# /homedir/eco/sfeng/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig(level=logging.INFO)
logger.addHandler(logging.FileHandler('Logs/reg_{0}.log'.format(datetime.datetime.now().\
                                                            strftime("%Y-%m-%d"), 'a')))
print = logging.info
print('good day to you madam fiona')
print('started')
print(datetime.datetime.now())
# Out:
# INFO:root:good day to you madam fiona
# INFO:root:started
# INFO:root:2018-09-10 17:51:12.361121

# %%
# Initial full list
regs = {}
pathdir = "DataStore/2018-08/Reg0910/"
reg_f = "reg_model_0910.pkl"
# Similarity regressions

for dm in ["sim_ldavecs", "sim_docvecs", "num_common_cites"]:
    sim_regs = [
     # Main results

     # No FE
     #0
     "{0} ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff)".format(dm),
     #1
     "{0} ~ C(inv_msa_match):C(year_diff) + C(tp_appyear)".format(dm),
     #2
     "{0} ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(tp_naics_name)".format(dm),
     #3
     "{0} ~ C(inv_msa_match):C(year_diff) + C(tp_appyear) + C(year_diff) + C(tp_naics_name)".format(dm),
     #4
     "{0} ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(tp_naics_name) + C(primclass_match)".format(dm),
     #5
     "{0} ~ C(inv_msa_match):C(year_diff) + C(tp_appyear) + C(tp_naics_name) + C(primclass_match)".format(dm),
     #6
     "{0} ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(primclass_match)".format(dm),
     #7
     "{0} ~ C(inv_msa_match):C(year_diff) + C(tp_appyear) + C(primclass_match)".format(dm),
    ]
    

    # Replace sim with norm
    n_sim_regs = [i.replace("sim_","norm_sim_") for i in sim_regs]

    # Replace num_common_cites with norm
    n_sim_regs = [i.replace("num_common_cites","norm_num_common_cites") for i in n_sim_regs]
    # Number of all equations in sim_regs
    n_eqns = len(sim_regs)
    # Update regression list
    sim_regs = sim_regs+n_sim_regs

    # NAICS indices
    regs[dm, "all_models"] = pd.Series(sim_regs)
    
mn = [
    "Year FE", #0
    "Year FE Int", #1
    "NAICS FE", #2
    "NAICS FE Int", #3
    "NAICS FE & PC Match", #4
    "NAICS FE & PC Match", #5
    "PC Match", #6
    "PC Match Int", #7
]
# Add Norm
n_mn = ["N "+i for i in mn]
mn = mn+n_mn

regs["model_names"] = pd.Series(mn)
pickle.dump(regs, open(pathdir+reg_f, "wb"))

# %%
info_dict = {'$N$':lambda x: "{0:d}".format(int(x.nobs)),
'Adjusted $R^2$':lambda x: "{:.2f}".format(x.rsquared_adj)}

def get_fit(formula, grouped_data, group_col, cov_type, return_fit = False):
    summ = []
    tables = {}
    
    # Remove missing values used in formula
    col_used = re.findall('\((.*?)\)',formula)
    grouped_data = grouped_data.dropna(how="any", subset=col_used) # Should take care of gyear > 1980 issues
    
    # Group and then get results
    grouped_data = grouped_data.groupby(group_col)
    
    for n,g in grouped_data:
        try:
            fit = smf.ols(formula = formula, data = g, missing="drop").fit(cov_type=cov_type)
            # Get results tables
            tables[n] = fit.summary2().tables
            # Append results
            summ.append(fit)
        except Exception:
            print(n)
            print("Regression error")
            pass
    # Get full results output
    # Dataframe of full results
    res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    
    # Get partial results
    # 1. Get relevant variables from index of full results: UPDATED
    regressors = [v for v in res_no_stars.index.unique() if ("sim_" in v) | ("match" in v) | ("common_" in v)]
    # 2. Make sure regressors come last
    regressors = regressors+["Intercept"]
    # 3. Get results with regressors
    part_res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    part_res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    
    # 4. Get index of where Intercept is and add 2 (to include standard error)
    last_ind = list(part_res_stars.index).index("Intercept")+2
    
    # 5. Get partial results
    part_res_no_stars = pd.concat([part_res_no_stars.iloc[:last_ind], part_res_no_stars.iloc[-2::]])
    part_res_stars = pd.concat([part_res_stars.iloc[:last_ind], part_res_stars.iloc[-2::]])
    
    if return_fit == True:
        return summ, tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars
    else:
        return tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars

# %%
# Regressions for random sample
dms = ["sim_ldavecs", "sim_docvecs", "num_common_cites"]
# dms = ["num_common_cites"]
file_pathdir = "DataStore/2018-08"
mod_keys = ["all_models"]
seed = 3
# Merge common inventor data
rs = fastparquet.ParquetFile("DataStore/2018-08/newterms_lead_follow_0910.parq").to_pandas().sample(frac=0.3, random_state = seed)
# Add year_group
rs["year_group"] = "all"
# Drop missing term
print(len(rs))
rs = rs.loc[rs["term"].notnull()]
print(len(rs))
print(rs.columns)

# Industry and primary class match
for c in ["naics_name", "primclass"]:
    rs["{0}_match".format(c)] = (rs["tp_{0}".format(c)] == rs["op_{0}".format(c)])

for k in mod_keys:
    for dm in dms:

        print((dm, k, "started"))
        print(datetime.datetime.now())
        # 3. Define output
        samp_out = {}
        formulas = list(regs[dm,k])
        formulas_ind = list(regs[dm,k].index)
        cov = "HC1"
        for i, j in zip(formulas_ind, formulas):
            print(k)
            print(i)
            print(j)
            print(datetime.datetime.now())
            try:
                out = get_fit(j, rs, "year_group", cov, return_fit = False)
                samp_out[i] = {}
                samp_out[i]["model"] = j
                samp_out[i]["tables"] = out[0]
                samp_out[i]["res_no_stars"] = out[1]
                samp_out[i]["res_stars"] = out[2]
                samp_out[i]["part_res_no_stars"] = out[3]
                samp_out[i]["part_res_stars"] = out[4]
            except Exception as e:
                logging.exception("error here")
                pass
            print("finished")
            print(datetime.datetime.now())
        # Define outfile
        o_f = "reg_{0}_{1}_out_0910.pkl".format(k,dm)
        pickle.dump(samp_out, open(pathdir+o_f, "wb"))
# Out:
# INFO:root:1682770
# INFO:root:1682770
# INFO:root:Index(['sim_docvecs', 'tp', 'op', 'term', 'sim_ldavecs', 'tp_appyear',
#        'tp_inv_msa', 'tp_primclass', 'tp_naics_name', 'tp_title', 'op_appyear',
#        'op_inv_msa', 'op_primclass', 'op_naics_name', 'op_title',
#        'inv_msa_match', 'year_diff', 'direct_cite', 'num_common_cites',
#        'norm_sim_ldavecs', 'norm_sim_docvecs', 'norm_num_common_cites',
#        'year_group'],
#       dtype='object')
# INFO:root:('sim_ldavecs', 'all_models', 'started')
# INFO:root:2018-09-11 12:25:41.122748
# INFO:root:all_models
# INFO:root:0
# INFO:root:sim_ldavecs ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff)
# INFO:root:2018-09-11 12:25:41.126903
# INFO:root:finished
# INFO:root:2018-09-11 12:26:06.489361
# INFO:root:all_models
# INFO:root:1
# INFO:root:sim_ldavecs ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(term)
# INFO:root:2018-09-11 12:26:06.492538
# INFO:root:finished
# INFO:root:2018-09-11 12:27:08.285149
# INFO:root:all_models
# INFO:root:2
# INFO:root:sim_ldavecs ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(term) + C(tp_naics_name)
# INFO:root:2018-09-11 12:27:08.287684
# INFO:root:finished
# INFO:root:2018-09-11 12:28:23.556233
# INFO:root:all_models
# INFO:root:3
# INFO:root:sim_ldavecs ~ C(inv_msa_match) + C(tp_appyear) + C(year_diff) + C(term) + C(tp_naics_name) + C(naics_name_match)
# INFO:root:2018-09-11 12:28:23.559139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-01d72b692424> in <module>()
#      35             print(datetime.datetime.now())
#      36             try:
# ---> 37                 out = get_fit(j, rs, "year_group", cov, return_fit = False)
#      38                 samp_out[i] = {}
#      39                 samp_out[i]["model"] = j
#
# <ipython-input-11-ec1eee88dc3a> in get_fit(formula, grouped_data, group_col, cov_type, return_fit)
#      15     for n,g in grouped_data:
#      16         try:
# ---> 17             fit = smf.ols(formula = formula, data = g, missing="drop").fit(cov_type=cov_type)
#      18             # Get results tables
#      19             tables[n] = fit.summary2().tables
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     446                     cat_sniffers[factor] = CategoricalSniffer(NA_action,
#     447                                                               factor.origin)
# --> 448                 done = cat_sniffers[factor].sniff(value)
#     449                 if done:
#     450                     examine_needed.remove(factor)
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/categorical.py in sniff(self, data)
#     203
#     204         for value in data:
# --> 205             if self._NA_action.is_categorical_NA(value):
#     206                 continue
#     207             if value is True or value is False:
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/missing.py in is_categorical_NA(self, obj)
#     121
#     122         Note that here `obj` is a single scalar value."""
# --> 123         if "NaN" in self.NA_types and safe_scalar_isnan(obj):
#     124             return True
#     125         if "None" in self.NA_types and obj is None:
#
# ~/bigdata/python/miniconda3/lib/python3.6/site-packages/patsy/util.py in safe_scalar_isnan(x)
#     539 def safe_scalar_isnan(x):
#     540     try:
# --> 541         return np.isnan(float(x))
#     542     except (TypeError, ValueError, NotImplementedError):
#     543         return False
#
# KeyboardInterrupt:

# %%
# Regressions for random sample
dms = ["sim_ldavecs", "sim_docvecs", "num_common_cites"]
# dms = ["num_common_cites"]
file_pathdir = "DataStore/2018-08"
mod_keys = ["all_models"]
pathdir = "DataStore/2018-08/Reg0910/"
reg_f = "reg_model_0910.pkl"
regs = pickle.load(open(pathdir+reg_f, "rb"))
tab = {}
for dm in dms:
    for g in mod_keys:
        
        o_f = "reg_{0}_{1}_out_0910.pkl".format(g,dm)
        
        res = pickle.load(open(pathdir+o_f, "rb"))

        res_out = pd.DataFrame()

        for k in res.keys():
            lks = res[k]["model"].split(" ~ ")[0]
            
            # Selecting portion of results without intercept
            cdf = res[k]["part_res_stars"].reset_index()
            ic_ind = cdf.loc[cdf["index"] == "Intercept"].index[0]
            # Include N & R^2
            cdf = cdf.iloc[pd.np.r_[0:ic_ind,ic_ind+2:len(cdf)]]
            cdf["Model"] = regs["model_names"][k]
            cdf["Model Num"] = k
            cdf["LKS"] = lks
        
            res_out = res_out.append(cdf)
        
#         res_out = res_out.replace("C(inv_msa_match)[T.True]", "$I(MSA \, Match)$")
#         res_out = res_out.replace("C(tp_from_uni)[T.True]", "$I(tp \, from \, uni)$")
#         res_out["Sample"] = samp_name[f]
        
#         m_ind = res_out["Model"].drop_duplicates().index.tolist()
#         res_out.loc[~(res_out.index.isin(m_ind)), ["LKS", "Sample"]] = ""
        
        tab[dm,g] = res_out
        del(res_out)
        
full_tab = tab

# %%
r = pd.DataFrame()
for k,v in tab.items():
    print(k)
    display(v)
    v["samp"] = str(k)
    v = v.reset_index(drop=True)
    r = pd.concat([r,v],axis=0)
# Out:
# INFO:root:('sim_ldavecs', 'all_models')
#                          index                 all  \
# 0     C(inv_msa_match)[T.True]           0.2265***
# 1                                         (0.0317)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.02
# 0     C(inv_msa_match)[T.True]     7041682729.5868
# 1                                (4878023053.8826)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.03
# 0     C(inv_msa_match)[T.True]     7782178530.3229
# 1                                (4775290894.0600)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]     7592508543.3298
# 1                                (4877090780.6177)
# 2  C(naics_name_match)[T.True]           0.0339***
# 3                                         (0.0014)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.06
# 0     C(inv_msa_match)[T.True]     7827236300.4155
# 1                                (4797111098.9094)
# 2   C(primclass_match)[T.True]           0.0322***
# 3                                         (0.0015)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.06
# 0     C(inv_msa_match)[T.True]     7037363909.9532
# 1                                (4899883018.8385)
# 2   C(primclass_match)[T.True]           0.0310***
# 3                                         (0.0015)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]             -0.0798
# 1                                         (0.1479)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.02
# 0     C(inv_msa_match)[T.True]    32838658211.0231
# 1                               (22764195374.6301)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.03
# 0     C(inv_msa_match)[T.True]    36291936275.6582
# 1                               (22252595822.8305)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]    35407416464.8105
# 1                               (22743537674.2847)
# 2  C(naics_name_match)[T.True]           0.1582***
# 3                                         (0.0065)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.06
# 0     C(inv_msa_match)[T.True]    36502061719.9147
# 1                               (22384807755.5319)
# 2   C(primclass_match)[T.True]           0.1502***
# 3                                         (0.0068)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.06
# 0     C(inv_msa_match)[T.True]    32818517536.2339
# 1                               (22829623078.2968)
# 2   C(primclass_match)[T.True]           0.1445***
# 3                                         (0.0070)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
#
#                         Model  Model Num               LKS
# 0                     Year FE          0       sim_ldavecs
# 1                     Year FE          0       sim_ldavecs
# 4                     Year FE          0       sim_ldavecs
# 5                     Year FE          0       sim_ldavecs
# 0                     Term FE          1       sim_ldavecs
# 1                     Term FE          1       sim_ldavecs
# 4                     Term FE          1       sim_ldavecs
# 5                     Term FE          1       sim_ldavecs
# 0               Term NAICS FE          2       sim_ldavecs
# 1               Term NAICS FE          2       sim_ldavecs
# 4               Term NAICS FE          2       sim_ldavecs
# 5               Term NAICS FE          2       sim_ldavecs
# 0       Term NAICS FE & Match          3       sim_ldavecs
# 1       Term NAICS FE & Match          3       sim_ldavecs
# 2       Term NAICS FE & Match          3       sim_ldavecs
# 3       Term NAICS FE & Match          3       sim_ldavecs
# 6       Term NAICS FE & Match          3       sim_ldavecs
# 7       Term NAICS FE & Match          3       sim_ldavecs
# 0    Term NAICS FE & PC Match          4       sim_ldavecs
# 1    Term NAICS FE & PC Match          4       sim_ldavecs
# 2    Term NAICS FE & PC Match          4       sim_ldavecs
# 3    Term NAICS FE & PC Match          4       sim_ldavecs
# 6    Term NAICS FE & PC Match          4       sim_ldavecs
# 7    Term NAICS FE & PC Match          4       sim_ldavecs
# 0          Term FE & PC Match          5       sim_ldavecs
# 1          Term FE & PC Match          5       sim_ldavecs
# 2          Term FE & PC Match          5       sim_ldavecs
# 3          Term FE & PC Match          5       sim_ldavecs
# 6          Term FE & PC Match          5       sim_ldavecs
# 7          Term FE & PC Match          5       sim_ldavecs
# 0                   N Year FE          6  norm_sim_ldavecs
# 1                   N Year FE          6  norm_sim_ldavecs
# 4                   N Year FE          6  norm_sim_ldavecs
# 5                   N Year FE          6  norm_sim_ldavecs
# 0                   N Term FE          7  norm_sim_ldavecs
# 1                   N Term FE          7  norm_sim_ldavecs
# 4                   N Term FE          7  norm_sim_ldavecs
# 5                   N Term FE          7  norm_sim_ldavecs
# 0             N Term NAICS FE          8  norm_sim_ldavecs
# 1             N Term NAICS FE          8  norm_sim_ldavecs
# 4             N Term NAICS FE          8  norm_sim_ldavecs
# 5             N Term NAICS FE          8  norm_sim_ldavecs
# 0     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 1     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 2     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 3     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 6     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 7     N Term NAICS FE & Match          9  norm_sim_ldavecs
# 0  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 1  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 2  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 3  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 6  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 7  N Term NAICS FE & PC Match         10  norm_sim_ldavecs
# 0        N Term FE & PC Match         11  norm_sim_ldavecs
# 1        N Term FE & PC Match         11  norm_sim_ldavecs
# 2        N Term FE & PC Match         11  norm_sim_ldavecs
# 3        N Term FE & PC Match         11  norm_sim_ldavecs
# 6        N Term FE & PC Match         11  norm_sim_ldavecs
# 7        N Term FE & PC Match         11  norm_sim_ldavecs
# INFO:root:('sim_docvecs', 'all_models')
#                          index                 all  \
# 0     C(inv_msa_match)[T.True]           0.1226***
# 1                                         (0.0149)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]   5107302478.9594**
# 1                                (2512970605.5584)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]    4197787056.5718*
# 1                                (2480185459.3837)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]    4136889745.2447*
# 1                                (2450974504.7404)
# 2  C(naics_name_match)[T.True]           0.0155***
# 3                                         (0.0009)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]    4214692713.5623*
# 1                                (2470957910.8049)
# 2   C(primclass_match)[T.True]           0.0148***
# 3                                         (0.0009)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]   5106692321.5186**
# 1                                (2506994648.9077)
# 2   C(primclass_match)[T.True]           0.0149***
# 3                                         (0.0009)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]             -0.0311
# 1                                         (0.1131)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]  38867654784.8155**
# 1                               (19126316050.6546)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.04
# 0     C(inv_msa_match)[T.True]   31946049572.3724*
# 1                               (18887371686.4608)
# 4                          $N$             1040690
# 5               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]   31482608120.8804*
# 1                               (18658621985.5627)
# 2  C(naics_name_match)[T.True]           0.1178***
# 3                                         (0.0065)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]   32074705206.6415*
# 1                               (18804641749.1556)
# 2   C(primclass_match)[T.True]           0.1129***
# 3                                         (0.0065)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
# 0     C(inv_msa_match)[T.True]  38863011357.3168**
# 1                               (19069232251.1812)
# 2   C(primclass_match)[T.True]           0.1135***
# 3                                         (0.0066)
# 6                          $N$             1040690
# 7               Adjusted $R^2$                0.05
#
#                         Model  Model Num               LKS
# 0                     Year FE          0       sim_docvecs
# 1                     Year FE          0       sim_docvecs
# 4                     Year FE          0       sim_docvecs
# 5                     Year FE          0       sim_docvecs
# 0                     Term FE          1       sim_docvecs
# 1                     Term FE          1       sim_docvecs
# 4                     Term FE          1       sim_docvecs
# 5                     Term FE          1       sim_docvecs
# 0               Term NAICS FE          2       sim_docvecs
# 1               Term NAICS FE          2       sim_docvecs
# 4               Term NAICS FE          2       sim_docvecs
# 5               Term NAICS FE          2       sim_docvecs
# 0       Term NAICS FE & Match          3       sim_docvecs
# 1       Term NAICS FE & Match          3       sim_docvecs
# 2       Term NAICS FE & Match          3       sim_docvecs
# 3       Term NAICS FE & Match          3       sim_docvecs
# 6       Term NAICS FE & Match          3       sim_docvecs
# 7       Term NAICS FE & Match          3       sim_docvecs
# 0    Term NAICS FE & PC Match          4       sim_docvecs
# 1    Term NAICS FE & PC Match          4       sim_docvecs
# 2    Term NAICS FE & PC Match          4       sim_docvecs
# 3    Term NAICS FE & PC Match          4       sim_docvecs
# 6    Term NAICS FE & PC Match          4       sim_docvecs
# 7    Term NAICS FE & PC Match          4       sim_docvecs
# 0          Term FE & PC Match          5       sim_docvecs
# 1          Term FE & PC Match          5       sim_docvecs
# 2          Term FE & PC Match          5       sim_docvecs
# 3          Term FE & PC Match          5       sim_docvecs
# 6          Term FE & PC Match          5       sim_docvecs
# 7          Term FE & PC Match          5       sim_docvecs
# 0                   N Year FE          6  norm_sim_docvecs
# 1                   N Year FE          6  norm_sim_docvecs
# 4                   N Year FE          6  norm_sim_docvecs
# 5                   N Year FE          6  norm_sim_docvecs
# 0                   N Term FE          7  norm_sim_docvecs
# 1                   N Term FE          7  norm_sim_docvecs
# 4                   N Term FE          7  norm_sim_docvecs
# 5                   N Term FE          7  norm_sim_docvecs
# 0             N Term NAICS FE          8  norm_sim_docvecs
# 1             N Term NAICS FE          8  norm_sim_docvecs
# 4             N Term NAICS FE          8  norm_sim_docvecs
# 5             N Term NAICS FE          8  norm_sim_docvecs
# 0     N Term NAICS FE & Match          9  norm_sim_docvecs
# 1     N Term NAICS FE & Match          9  norm_sim_docvecs
# 2     N Term NAICS FE & Match          9  norm_sim_docvecs
# 3     N Term NAICS FE & Match          9  norm_sim_docvecs
# 6     N Term NAICS FE & Match          9  norm_sim_docvecs
# 7     N Term NAICS FE & Match          9  norm_sim_docvecs
# 0  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 1  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 2  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 3  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 6  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 7  N Term NAICS FE & PC Match         10  norm_sim_docvecs
# 0        N Term FE & PC Match         11  norm_sim_docvecs
# 1        N Term FE & PC Match         11  norm_sim_docvecs
# 2        N Term FE & PC Match         11  norm_sim_docvecs
# 3        N Term FE & PC Match         11  norm_sim_docvecs
# 6        N Term FE & PC Match         11  norm_sim_docvecs
# 7        N Term FE & PC Match         11  norm_sim_docvecs
# INFO:root:('num_common_cites', 'all_models')
#                          index               all                       Model  \
# 0     C(inv_msa_match)[T.True]          0.0008**                     Year FE
# 1                                       (0.0003)                     Year FE
# 4                          $N$           1040690                     Year FE
# 5               Adjusted $R^2$              0.00                     Year FE
# 0     C(inv_msa_match)[T.True]     42842804.6402                     Term FE
# 1                                (78115634.3397)                     Term FE
# 4                          $N$           1040690                     Term FE
# 5               Adjusted $R^2$              0.18                     Term FE
# 0     C(inv_msa_match)[T.True]    -11670644.2190               Term NAICS FE
# 1                                (73383294.0815)               Term NAICS FE
# 4                          $N$           1040690               Term NAICS FE
# 5               Adjusted $R^2$              0.18               Term NAICS FE
# 0     C(inv_msa_match)[T.True]    -19912096.4742       Term NAICS FE & Match
# 1                                (72204210.3327)       Term NAICS FE & Match
# 2  C(naics_name_match)[T.True]         0.0052***       Term NAICS FE & Match
# 3                                       (0.0011)       Term NAICS FE & Match
# 6                          $N$           1040690       Term NAICS FE & Match
# 7               Adjusted $R^2$              0.18       Term NAICS FE & Match
# 0     C(inv_msa_match)[T.True]     -6907937.5660    Term NAICS FE & PC Match
# 1                                (70767911.3059)    Term NAICS FE & PC Match
# 2   C(primclass_match)[T.True]         0.0050***    Term NAICS FE & PC Match
# 3                                       (0.0010)    Term NAICS FE & PC Match
# 6                          $N$           1040690    Term NAICS FE & PC Match
# 7               Adjusted $R^2$              0.18    Term NAICS FE & PC Match
# 0     C(inv_msa_match)[T.True]     42503856.2122          Term FE & PC Match
# 1                                (76073255.6645)          Term FE & PC Match
# 2   C(primclass_match)[T.True]         0.0050***          Term FE & PC Match
# 3                                       (0.0010)          Term FE & PC Match
# 6                          $N$           1040690          Term FE & PC Match
# 7               Adjusted $R^2$              0.18          Term FE & PC Match
# 0     C(inv_msa_match)[T.True]           -0.0027                   N Year FE
# 1                                       (0.0021)                   N Year FE
# 4                          $N$           1040690                   N Year FE
# 5               Adjusted $R^2$              0.00                   N Year FE
# 0     C(inv_msa_match)[T.True]    262372206.7966                   N Term FE
# 1                               (495048694.7587)                   N Term FE
# 4                          $N$           1040690                   N Term FE
# 5               Adjusted $R^2$              0.18                   N Term FE
# 0     C(inv_msa_match)[T.True]    -71471807.3372             N Term NAICS FE
# 1                               (445785379.6156)             N Term NAICS FE
# 4                          $N$           1040690             N Term NAICS FE
# 5               Adjusted $R^2$              0.18             N Term NAICS FE
# 0     C(inv_msa_match)[T.True]   -121943013.2633     N Term NAICS FE & Match
# 1                               (443261343.6358)     N Term NAICS FE & Match
# 2  C(naics_name_match)[T.True]         0.0321***     N Term NAICS FE & Match
# 3                                       (0.0065)     N Term NAICS FE & Match
# 6                          $N$           1040690     N Term NAICS FE & Match
# 7               Adjusted $R^2$              0.18     N Term NAICS FE & Match
# 0     C(inv_msa_match)[T.True]    -42304672.6123  N Term NAICS FE & PC Match
# 1                               (435257149.7557)  N Term NAICS FE & PC Match
# 2   C(primclass_match)[T.True]         0.0304***  N Term NAICS FE & PC Match
# 3                                       (0.0064)  N Term NAICS FE & PC Match
# 6                          $N$           1040690  N Term NAICS FE & PC Match
# 7               Adjusted $R^2$              0.18  N Term NAICS FE & PC Match
# 0     C(inv_msa_match)[T.True]    260296463.9071        N Term FE & PC Match
# 1                               (459218454.1707)        N Term FE & PC Match
# 2   C(primclass_match)[T.True]         0.0305***        N Term FE & PC Match
# 3                                       (0.0064)        N Term FE & PC Match
# 6                          $N$           1040690        N Term FE & PC Match
# 7               Adjusted $R^2$              0.18        N Term FE & PC Match
#
#    Model Num                    LKS
# 0          0       num_common_cites
# 1          0       num_common_cites
# 4          0       num_common_cites
# 5          0       num_common_cites
# 0          1       num_common_cites
# 1          1       num_common_cites
# 4          1       num_common_cites
# 5          1       num_common_cites
# 0          2       num_common_cites
# 1          2       num_common_cites
# 4          2       num_common_cites
# 5          2       num_common_cites
# 0          3       num_common_cites
# 1          3       num_common_cites
# 2          3       num_common_cites
# 3          3       num_common_cites
# 6          3       num_common_cites
# 7          3       num_common_cites
# 0          4       num_common_cites
# 1          4       num_common_cites
# 2          4       num_common_cites
# 3          4       num_common_cites
# 6          4       num_common_cites
# 7          4       num_common_cites
# 0          5       num_common_cites
# 1          5       num_common_cites
# 2          5       num_common_cites
# 3          5       num_common_cites
# 6          5       num_common_cites
# 7          5       num_common_cites
# 0          6  norm_num_common_cites
# 1          6  norm_num_common_cites
# 4          6  norm_num_common_cites
# 5          6  norm_num_common_cites
# 0          7  norm_num_common_cites
# 1          7  norm_num_common_cites
# 4          7  norm_num_common_cites
# 5          7  norm_num_common_cites
# 0          8  norm_num_common_cites
# 1          8  norm_num_common_cites
# 4          8  norm_num_common_cites
# 5          8  norm_num_common_cites
# 0          9  norm_num_common_cites
# 1          9  norm_num_common_cites
# 2          9  norm_num_common_cites
# 3          9  norm_num_common_cites
# 6          9  norm_num_common_cites
# 7          9  norm_num_common_cites
# 0         10  norm_num_common_cites
# 1         10  norm_num_common_cites
# 2         10  norm_num_common_cites
# 3         10  norm_num_common_cites
# 6         10  norm_num_common_cites
# 7         10  norm_num_common_cites
# 0         11  norm_num_common_cites
# 1         11  norm_num_common_cites
# 2         11  norm_num_common_cites
# 3         11  norm_num_common_cites
# 6         11  norm_num_common_cites
# 7         11  norm_num_common_cites
