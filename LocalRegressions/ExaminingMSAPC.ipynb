# %%
import scipy as sp
import numpy as np
import pandas as pd
import timeit
import re
import json
import pickle
import fastparquet
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.iolib.summary2 as summary2
# Out:
# /homedir/eco/sfeng/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
ns = fastparquet.ParquetFile("DataStore/2018-08/Reg0820/naics_name_docvecs_0824.parq").to_pandas()

# %%
import math
def round_up(x, a):
    try:
        r = int(math.ceil(x / a)) * a
    except Exception:
        r = np.nan
    return r

ns["bin_pc"] = ns["norm_sim_mean_docvecs_pc"].apply(lambda x: round_up(x,0.5))
ns["bin_pc_msa"] = ns["norm_sim_mean_docvecs_pc_msa"].apply(lambda x: round_up(x,0.5))

# %%
ns.loc[ns["bin_pc_msa"] >= 2, ["tp_inv_msa", "tp_primclass", "op_inv_msa", "op_primclass"]].drop_duplicates()
# Out:
#                                                 tp_inv_msa  tp_primclass  \
# index
# 0                                     Clinton Township, MI         296.0
# 14                                    Boise City-Nampa, ID         324.0
# 34                      San Jose-Sunnyvale-Santa Clara, CA         257.0
# 36                                         Reno-Sparks, NV         463.0
# 37                                  Durham-Chapel Hill, NC         514.0
# 47                     Chicago-Joliet-Naperville, IL-IN-WI         510.0
# 50                                 Indianapolis-Carmel, IN         348.0
# 62       New York-Northern New Jersey-Long Island, NY-N...         707.0
# 66                          Boston-Cambridge-Quincy, MA-NH         428.0
# 67       New York-Northern New Jersey-Long Island, NY-N...          15.0
# 81             Philadelphia-Camden-Wilmington, PA-NJ-DE-MD         424.0
# 100                         Boston-Cambridge-Quincy, MA-NH         370.0
# ...
