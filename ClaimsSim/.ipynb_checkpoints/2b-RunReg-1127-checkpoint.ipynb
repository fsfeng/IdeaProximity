# %%
import scipy as sp
import numpy as np
import pandas as pd
import timeit
import re
import json
import pickle
import fastparquet
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.iolib.summary2 as summary2
import logging
import itertools
# Out:
# /homedir/eco/sfeng/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# - Based on: https://sfengc7.stern.nyu.edu:8888/notebooks/patentdiffusion/201808Results/Reg1016/3a-RunReg-1016.ipynb
# - Regression models in: https://sfengc7.stern.nyu.edu:8888/notebooks/patentdiffusion/201808Results/Reg1016/2-RegPrep-1016.ipynb

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig(level=logging.INFO)
logger.addHandler(logging.FileHandler('Logs/reg_{0}.log'.format(datetime.datetime.now().\
                                                            strftime("%Y-%m-%d"), 'a')))
print = logging.info
print('good day to you madam fiona')
print('started')
print(datetime.datetime.now())
# Out:
# INFO:root:good day to you madam fiona
# INFO:root:started
# INFO:root:2018-11-27 16:07:05.027461

# %%
pathdir = "DataStore/2018-11/Reg1127/"
reg_f = "reg_model_1127.pkl"

regs = pickle.load(open(pathdir+reg_f, "rb"))

# %%
# Add list of equations
# Only normed values
regs["model_names"] = regs["model_names"].loc[regs["model_names"].apply(lambda x: x[:2] == "N ")]
# naics_ind = regs["model_names"].loc[regs["model_names"].apply(lambda x: ("Sim PC" in x) or ("Int PC" in x))].index.tolist()
naics_ind = regs["model_names"].index.tolist()
print(len(naics_ind))

regs[("docvecs", "naics_name")] = regs["docvecs"].loc[naics_ind]
# regs[("ldavecs", "naics_name")] = regs["ldavecs"].loc[naics_ind]
# for c in ["num_common_cited", "tp_pct_common_cited"]:
#     regs[(c, "naics_name")] = regs[c].loc[regs[c].index.isin(naics_ind)]

# PC indices
# Exclude Sim PC and Primclass Match
pc_ind = regs["model_names"].loc[regs["model_names"].apply(lambda x: (x[:-2] != "PC") and ("PC M-" not in x))].index.tolist()
print(len(pc_ind))

regs[("docvecs", "primclass")] = regs["docvecs"].loc[regs["docvecs"].index.isin(pc_ind)].dropna()
# regs[("ldavecs", "primclass")] = regs["ldavecs"].loc[regs["ldavecs"].index.isin(pc_ind)].dropna()
# Use whatever is available for num_common_cited
# for c in ["num_common_cited", "tp_pct_common_cited"]:
#     regs[(c, "primclass")] = regs[c].loc[regs[c].index.isin(pc_ind)]

# Where files are located
files = {"naics_name": "DataStore/2018-11/naics_name_sim_claims_1120.parq",
         "primclass": "DataStore/2018-11/primclass_sim_claims_1120.parq",
}
# Out:
# INFO:root:15
# INFO:root:14

# %%
regs[("docvecs", "primclass")].sample(5)
# Out:
# 16    norm_sim_claims_docvecs ~ C(inv_msa_match) + C...
# 27    norm_sim_claims_docvecs ~ C(primclass_match) +...
# 19    norm_sim_claims_docvecs ~ C(inv_msa_match) + C...
# 17    norm_sim_claims_docvecs ~ C(inv_msa_match) + C...
# 28    norm_sim_claims_docvecs ~ C(common_npc_match) ...
# dtype: object

# %%
info_dict = {'$N$':lambda x: "{0:d}".format(int(x.nobs)),
'Adjusted $R^2$':lambda x: "{:.2f}".format(x.rsquared_adj)}
def get_fit(formula, grouped_data, group_col, cov_type = "HC1", return_fit = False):
    summ = []
    tables = {}
    
    # If formula uses mean similarity, use grant year above 1980
    if "mean_sim_" in formula:
        grouped_data = grouped_data.loc[(grouped_data["tp_gyear"] >= 1980)]
    
    # Remove missing values used in formula
    col_used = re.findall('\((.*?)\)',formula)
    # Intersect with grouped_data columns
    col_used = list(set(col_used).intersection(set(list(grouped_data.columns))))
    print(col_used)
    
    grouped_data = grouped_data.dropna(how="any", subset=col_used).copy().reset_index(drop=True)
    
    # Get length of data
    print(("Length of data", len(grouped_data)))
                                    
    # Group and then get results
    grouped_data = grouped_data.groupby(group_col)
    
    for n,g in grouped_data:
        try:
            if cov_type == "HC1":
                fit = smf.ols(formula = formula, data = g, missing="drop").fit(cov_type="HC1")
            else:
                # Drop missing in the grouped data first
                # Cluster uses primary class so must have primary class FE
                cols_used2 = list(set(col_used).intersection(set(list(grouped_data.columns))))+["tp_primclass_FE"]
                g = g.dropna(subset=cols_used2, how="any").copy().reset_index(drop=True)
                fit = smf.ols(formula = formula, data = g).fit(cov_type="cluster",
                                                                              cov_kwds={'groups': g["tp_primclass_FE"]})
            # Get results tables
            tables[n] = fit.summary2().tables
            # Append results
            summ.append(fit)
        except Exception as e:
            print(n)
            logging.exception("Regression error")
            pass
    # Get full results output
    # Dataframe of full results
    res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    
    # Get partial results
    # 1. Get relevant variables from index of full results: UPDATED
    regressors = [v for v in res_no_stars.index.unique() if ("sim_" in v) | ("match" in v) | ("common_" in v)]
    # 2. Make sure regressors come last
    regressors = regressors+["Intercept"]
    # 3. Get results with regressors
    part_res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    part_res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    
    # 4. Get index of where Intercept is and add 2 (to include standard error)
    last_ind = list(part_res_stars.index).index("Intercept")+2
    
    # 5. Get partial results
    part_res_no_stars = pd.concat([part_res_no_stars.iloc[:last_ind], part_res_no_stars.iloc[-2::]])
    part_res_stars = pd.concat([part_res_stars.iloc[:last_ind], part_res_stars.iloc[-2::]])
    
    if return_fit == True:
        return summ, tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars
    else:
        return tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars
    
def get_results(sample, ks, cov = "HC1"):
    rs = fastparquet.ParquetFile(files[sample]).to_pandas()
    try:
        rs = rs.drop(['mean_sim_ldavecs_pc_msa_v',
           'mean_sim_docvecs_pc_msa_v', 'mean_sim_docvecs_pc_v', 'mean_sim_ldavecs_pc_v',
           'norm_mean_sim_ldavecs_pc_msa_v', 'norm_mean_sim_docvecs_pc_msa_v',
           'norm_mean_sim_docvecs_pc_v', 'norm_mean_sim_ldavecs_pc_v'],1)
        
    except:
        pass
    print(rs.columns)
    print(len(rs))
    
    # Drop extreme values
#     print(len(rs))
#     rs = rs.loc[((rs["norm_mean_sim_docvecs_pc_msa"] >= -5) & (rs["norm_mean_sim_docvecs_pc_msa"] <= 5)) | 
#                (rs["norm_mean_sim_docvecs_pc_msa"].isnull())]
#     rs = rs.loc[((rs["norm_mean_sim_docvecs_pc"] >= -5) & (rs["norm_mean_sim_docvecs_pc"] <= 5)) |
#                (rs["norm_mean_sim_docvecs_pc"].isnull())]
#     print(len(rs))
    
    print((ks, sample, "started"))
    print(datetime.datetime.now())
    # 3. Define output
    samp_out = {}
    formulas = list(regs[(ks, sample)])
    formulas_ind = list(regs[(ks, sample)].index)
    for i, j in zip(formulas_ind, formulas):
        print((ks, sample, i, j))
        print(datetime.datetime.now())
        try:
            out = get_fit(j, rs, "year_group", cov, return_fit = False)
            samp_out[i] = {}
            samp_out[i]["model"] = j
            samp_out[i]["tables"] = out[0]
            samp_out[i]["res_no_stars"] = out[1]
            samp_out[i]["res_stars"] = out[2]
            samp_out[i]["part_res_no_stars"] = out[3]
            samp_out[i]["part_res_stars"] = out[4]
        except Exception as e:
            logging.exception("error here")
            pass
        print("finished")
        print(datetime.datetime.now())

    # Define outfile
    o_f = "reg_{0}_{1}_out_{2}_1127.pkl".format(ks, sample, cov)
    pickle.dump(samp_out, open(pathdir+o_f, "wb"))

# %%
samples_l = ["naics_name", "primclass"]
# ks_l = ["tp_pct_common_cited", "docvecs", "ldavecs"]
ks_l = ["docvecs"]

for sample, ks in itertools.product(samples_l, ks_l):
    try:
#         get_results(sample, ks, cov="cluster")
        get_results(sample, ks, cov="HC1")
    except Exception as e:
        logging.exception("error here")
        pass
# Out:
# INFO:root:Index(['tp', 'op', 'sim_claims_docvecs', 'norm_sim_claims_docvecs',
#        'sim_docvecs', 'sim_ldavecs', 'tp_gyear', 'tp_naics_name',
#        'op_naics_name', 'op_primclass', 'op_inv_msa', 'inv_msa_match',
#        'primclass_match', 'norm_sim_ldavecs', 'norm_sim_docvecs', 'year_group',
#        'common_est_inv', 'common_pat_inv', 'lawyer_match', 'num_common_cited',
#        'norm_num_common_cited', 'tp_pct_common_cited',
#        'norm_tp_pct_common_cited', 'common_cited_match', 'common_npc_match',
#        'mean_sim_docvecs_pc', 'mean_sim_docvecs_pc_msa',
#        'norm_mean_sim_docvecs_pc', 'norm_mean_sim_docvecs_pc_msa',
#        'num_common_npc', 'norm_num_common_npc', 'tp_primclass_FE',
#        'tp_inv_msa_FE', 'tp_examiner_FE', 'tp_lawyer_FE', 'examiner_match'],
#       dtype='object')
# INFO:root:1498184
# INFO:root:('docvecs', 'naics_name', 'started')
# INFO:root:2018-11-27 16:07:17.559022
# INFO:root:('docvecs', 'naics_name', 15, 'norm_sim_claims_docvecs ~ C(inv_msa_match) + C(tp_gyear) + C(tp_primclass_FE)')
# INFO:root:2018-11-27 16:07:17.561907
# INFO:root:['inv_msa_match', 'tp_primclass_FE', 'tp_gyear']
# INFO:root:('Length of data', 1498184)
# INFO:root:finished
# INFO:root:2018-11-27 16:08:55.434666
# INFO:root:('docvecs', 'naics_name', 16, 'norm_sim_claims_docvecs ~ C(inv_msa_match) + C(tp_gyear) + C(tp_primclass_FE) + C(common_pat_inv) + C(common_est_inv)')
# INFO:root:2018-11-27 16:08:55.437113
# INFO:root:['common_pat_inv', 'inv_msa_match', 'tp_primclass_FE', 'common_est_inv', 'tp_gyear']
# INFO:root:('Length of data', 1498184)
# INFO:root:finished
# INFO:root:2018-11-27 16:10:53.043277
# INFO:root:('docvecs', 'naics_name', 17, 'norm_sim_claims_docvecs ~ C(inv_msa_match) + C(tp_gyear) + C(tp_primclass_FE) + C(common_pat_inv) + C(common_est_inv) + C(lawyer_match)')
# INFO:root:2018-11-27 16:10:53.045175
# INFO:root:['common_pat_inv', 'inv_msa_match', 'tp_primclass_FE', 'common_est_inv', 'tp_gyear', 'lawyer_match']
# INFO:root:('Length of data', 1498184)
# INFO:root:finished
# INFO:root:2018-11-27 16:12:36.415288
# INFO:root:('docvecs', 'naics_name', 18, 'norm_sim_claims_docvecs ~ C(inv_msa_match) + C(tp_gyear) + C(tp_primclass_FE) + C(common_pat_inv) + C(common_est_inv) + C(lawyer_match) + C(examiner_match)')
# INFO:root:2018-11-27 16:12:36.417540
# INFO:root:['common_pat_inv', 'inv_msa_match', 'tp_primclass_FE', 'examiner_match', 'common_est_inv', 'tp_gyear', 'lawyer_match']
# INFO:root:('Length of data', 1498184)
# INFO:root:finished
# INFO:root:2018-11-27 16:14:25.633700
# INFO:root:('docvecs', 'naics_name', 19, 'norm_sim_claims_docvecs ~ C(inv_msa_match) + C(tp_gyear) + C(tp_primclass_FE) + C(common_pat_inv) + C(common_est_inv) + C(lawyer_match) + C(examiner_match) + C(tp_inv_msa_FE)')
# INFO:root:2018-11-27 16:14:25.635732
# INFO:root:['common_pat_inv', 'inv_msa_match', 'tp_primclass_FE', 'tp_inv_msa_FE', 'examiner_match', 'common_est_inv', 'tp_gyear', 'lawyer_match']
# INFO:root:('Length of data', 1498184)

# %% [markdown]
# ________
# ### Results
# #### HC1

# %%
tab = {}
samples_l = ["naics_name", "primclass"]
# samples_l = ["naics_name"]
ks_l = ["tp_pct_common_cited", "docvecs", "ldavecs", ]
# ks_l = ["tp_pct_common_cited", "docvecs"]

for sample, ks in itertools.product(samples_l, ks_l):
    o_f = "reg_{0}_{1}_out_HC1_1016.pkl".format(ks, sample)

    res = pickle.load(open(pathdir+o_f, "rb"))

    res_out = pd.DataFrame()

    for k in res.keys():
        lks = res[k]["model"].split(" ~ ")[0]

        # Selecting portion of results without intercept
        cdf = res[k]["part_res_stars"].reset_index()
        ic_ind = cdf.loc[cdf["index"] == "Intercept"].index[0]
        # Include N & R^2
        cdf = cdf.iloc[pd.np.r_[0:ic_ind,ic_ind+2:len(cdf)]]
        cdf["Model"] = regs["model_names"][k]
        cdf["Model Num"] = k
        cdf["LKS"] = lks

        res_out = res_out.append(cdf)

    tab[ks, sample] = res_out
    del(res_out)
        
full_tab = tab

# %%
r = pd.DataFrame()
for k,v in tab.items():
    print(k)
    display(v)
    v["samp"] = str(k)
    v = v.reset_index(drop=True)
    r = pd.concat([r,v],axis=0)
# Out:
# INFO:root:('tp_pct_common_cited', 'naics_name')
#        1975-85     1985-95     1995-05     2005-15                       LKS  \
# 0    0.0321***   0.0737***   0.0802***   0.0689***  norm_tp_pct_common_cited
# 1     (0.0056)    (0.0075)    (0.0064)    (0.0050)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.00        0.00        0.00        0.00  norm_tp_pct_common_cited
# 0    0.0345***   0.0693***   0.0742***   0.0626***  norm_tp_pct_common_cited
# 1     (0.0083)    (0.0072)    (0.0061)    (0.0048)  norm_tp_pct_common_cited
# 2    0.0370***   0.0637***   0.0679***   0.0735***  norm_tp_pct_common_cited
# 3     (0.0074)    (0.0063)    (0.0048)    (0.0043)  norm_tp_pct_common_cited
# 6       100251      273455      384521      548046  norm_tp_pct_common_cited
# 7         0.00        0.00        0.00        0.00  norm_tp_pct_common_cited
# 0    0.0194***   0.0476***   0.0500***   0.0168***  norm_tp_pct_common_cited
# 1     (0.0050)    (0.0051)    (0.0044)    (0.0028)  norm_tp_pct_common_cited
# 2    0.0494***   0.0878***   0.0836***   0.0870***  norm_tp_pct_common_cited
# 3     (0.0148)    (0.0113)    (0.0083)    (0.0081)  norm_tp_pct_common_cited
# 4    0.0239***   0.0401***   0.0445***   0.0483***  norm_tp_pct_common_cited
# 5     (0.0060)    (0.0045)    (0.0036)    (0.0034)  norm_tp_pct_common_cited
# 8       100251      273455      384521      548046  norm_tp_pct_common_cited
# 9         0.00        0.01        0.01        0.01  norm_tp_pct_common_cited
# 0    0.0169***   0.0453***   0.0524***   0.0430***  norm_tp_pct_common_cited
# 1     (0.0065)    (0.0061)    (0.0052)    (0.0039)  norm_tp_pct_common_cited
# 2    0.0151***   0.0423***   0.0520***   0.0659***  norm_tp_pct_common_cited
# 3     (0.0052)    (0.0054)    (0.0050)    (0.0056)  norm_tp_pct_common_cited
# 6        78563      219905      335906      495512  norm_tp_pct_common_cited
# 7         0.00        0.00        0.00        0.00  norm_tp_pct_common_cited
# 0     0.0243**   0.0726***   0.0783***   0.0607***  norm_tp_pct_common_cited
# 1     (0.0097)    (0.0096)    (0.0076)    (0.0054)  norm_tp_pct_common_cited
# 2      0.0309*   0.1064***   0.1079***   0.1362***  norm_tp_pct_common_cited
# 3     (0.0188)    (0.0157)    (0.0126)    (0.0153)  norm_tp_pct_common_cited
# 4     0.0073**   0.0133***   0.0212***   0.0274***  norm_tp_pct_common_cited
# 5     (0.0029)    (0.0023)    (0.0024)    (0.0024)  norm_tp_pct_common_cited
# ..         ...         ...         ...         ...                       ...
# 18     -0.0009      0.0085    0.0106**   0.0192***  norm_tp_pct_common_cited
# 19    (0.0047)    (0.0053)    (0.0051)    (0.0049)  norm_tp_pct_common_cited
# 20      0.0005      0.0008      0.0022      0.0021  norm_tp_pct_common_cited
# 21    (0.0020)    (0.0021)    (0.0020)    (0.0021)  norm_tp_pct_common_cited
# 24       78563      219905      335906      495512  norm_tp_pct_common_cited
# 25        0.07        0.13        0.14        0.28  norm_tp_pct_common_cited
# 0    6.5188***  11.5080***  11.1559***  13.5868***  norm_tp_pct_common_cited
# 1     (1.2658)    (1.2087)    (1.0188)    (1.0808)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.09        0.15        0.13        0.16  norm_tp_pct_common_cited
# 0    0.8163***   1.7712***   2.5959***   2.4290***  norm_tp_pct_common_cited
# 1     (0.2022)    (0.2337)    (0.3064)    (0.2780)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.01        0.02        0.02        0.02  norm_tp_pct_common_cited
# 0   16.8788***  18.0922***  13.7026***   8.6885***  norm_tp_pct_common_cited
# 1     (1.2601)    (0.9477)    (0.5947)    (0.3429)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.54        0.48        0.39        0.25  norm_tp_pct_common_cited
# 0    0.1241***   0.2021***   0.1994***   0.1813***  norm_tp_pct_common_cited
# 1     (0.0157)    (0.0175)    (0.0132)    (0.0103)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.00        0.00        0.00        0.00  norm_tp_pct_common_cited
# 0   66.5915***  62.2668***  40.7940***  43.5499***  norm_tp_pct_common_cited
# 1     (0.0168)    (3.2013)    (5.5904)    (3.3094)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.17        0.04        0.09        0.23  norm_tp_pct_common_cited
# 0    0.3739***   0.6658***   0.7550***   1.0393***  norm_tp_pct_common_cited
# 1     (0.0705)    (0.0876)    (0.1103)    (0.1488)  norm_tp_pct_common_cited
# 4       188668      273463      384536      548061  norm_tp_pct_common_cited
# 5         0.01        0.01        0.00        0.01  norm_tp_pct_common_cited
#
#                         Model  Model Num  \
# 0             N PC FE-Year FE         60
# 1             N PC FE-Year FE         60
# 4             N PC FE-Year FE         60
# 5             N PC FE-Year FE         60
# 0              N PC FE-Sim PC         61
# 1              N PC FE-Sim PC         61
# 2              N PC FE-Sim PC         61
# 3              N PC FE-Sim PC         61
# 6              N PC FE-Sim PC         61
# 7              N PC FE-Sim PC         61
# 0              N PC FE-Int PC         62
# 1              N PC FE-Int PC         62
# 2              N PC FE-Int PC         62
# 3              N PC FE-Int PC         62
# 4              N PC FE-Int PC         62
# 5              N PC FE-Int PC         62
# 8              N PC FE-Int PC         62
# 9              N PC FE-Int PC         62
# 0          N PC FE-Sim PC MSA         63
# 1          N PC FE-Sim PC MSA         63
# 2          N PC FE-Sim PC MSA         63
# 3          N PC FE-Sim PC MSA         63
# 6          N PC FE-Sim PC MSA         63
# 7          N PC FE-Sim PC MSA         63
# 0          N PC FE-Int PC MSA         64
# 1          N PC FE-Int PC MSA         64
# 2          N PC FE-Int PC MSA         64
# 3          N PC FE-Int PC MSA         64
# 4          N PC FE-Int PC MSA         64
# 5          N PC FE-Int PC MSA         64
# ..                        ...        ...
# 18  N NonP M-Break Int PC MSA        113
# 19  N NonP M-Break Int PC MSA        113
# 20  N NonP M-Break Int PC MSA        113
# 21  N NonP M-Break Int PC MSA        113
# 24  N NonP M-Break Int PC MSA        113
# 25  N NonP M-Break Int PC MSA        113
# 0                     N Inv M        114
# 1                     N Inv M        114
# 4                     N Inv M        114
# 5                     N Inv M        114
# 0                  N Lawyer M        115
# 1                  N Lawyer M        115
# 4                  N Lawyer M        115
# 5                  N Lawyer M        115
# 0                      N CC M        116
# 1                      N CC M        116
# 4                      N CC M        116
# 5                      N CC M        116
# 0                      N PC M        117
# 1                      N PC M        117
# 4                      N PC M        117
# 5                      N PC M        117
# 0                     N NPC M        118
# 1                     N NPC M        118
# 4                     N NPC M        118
# 5                     N NPC M        118
# 0                N Examiner M        119
# 1                N Examiner M        119
# 4                N Examiner M        119
# 5                N Examiner M        119
#
#                                                 index
# 0                            C(inv_msa_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                            norm_mean_sim_docvecs_pc
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs_pc
# 3
# 4                            norm_mean_sim_docvecs_pc
# 5
# 8                                                 $N$
# 9                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                        norm_mean_sim_docvecs_pc_msa
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...
# 3
# 4                        norm_mean_sim_docvecs_pc_msa
# 5
# ..                                                ...
# 18      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa
# 19
# 20         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa
# 21
# 24                                                $N$
# 25                                     Adjusted $R^2$
# 0                           C(common_pat_inv)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                             C(lawyer_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                       C(common_cited_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                          C(primclass_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                         C(common_npc_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                           C(examiner_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
#
# [804 rows x 8 columns]
# INFO:root:('docvecs', 'naics_name')
#       1975-85    1985-95    1995-05    2005-15               LKS  \
# 0   0.0309***  0.0585***  0.0596***  0.0555***  norm_sim_docvecs
# 1    (0.0053)   (0.0043)   (0.0034)   (0.0030)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.06       0.07       0.08       0.05  norm_sim_docvecs
# 0   0.0293***  0.0375***  0.0335***  0.0300***  norm_sim_docvecs
# 1    (0.0070)   (0.0041)   (0.0033)   (0.0029)  norm_sim_docvecs
# 2   0.2899***  0.3015***  0.2966***  0.3018***  norm_sim_docvecs
# 3    (0.0044)   (0.0027)   (0.0022)   (0.0021)  norm_sim_docvecs
# 6      102330     280954     437386     563865  norm_sim_docvecs
# 7        0.11       0.11       0.12       0.08  norm_sim_docvecs
# 0   0.0267***  0.0331***  0.0300***  0.0228***  norm_sim_docvecs
# 1    (0.0069)   (0.0040)   (0.0032)   (0.0032)  norm_sim_docvecs
# 2      0.0080  0.0159***  0.0111***  0.0135***  norm_sim_docvecs
# 3    (0.0077)   (0.0045)   (0.0034)   (0.0035)  norm_sim_docvecs
# 4   0.2878***  0.2972***  0.2935***  0.2980***  norm_sim_docvecs
# 5    (0.0048)   (0.0029)   (0.0024)   (0.0023)  norm_sim_docvecs
# 8      102330     280954     437386     563865  norm_sim_docvecs
# 9        0.11       0.11       0.12       0.08  norm_sim_docvecs
# 0    0.0200**  0.0322***  0.0250***  0.0223***  norm_sim_docvecs
# 1    (0.0079)   (0.0046)   (0.0035)   (0.0031)  norm_sim_docvecs
# 2   0.1529***  0.1570***  0.1951***  0.2113***  norm_sim_docvecs
# 3    (0.0043)   (0.0026)   (0.0023)   (0.0022)  norm_sim_docvecs
# 6       80414     226512     382447     511077  norm_sim_docvecs
# 7        0.09       0.09       0.10       0.07  norm_sim_docvecs
# 0   0.0265***  0.0427***  0.0334***  0.0285***  norm_sim_docvecs
# 1    (0.0086)   (0.0050)   (0.0038)   (0.0032)  norm_sim_docvecs
# 2   0.0289***  0.0439***  0.0377***  0.0504***  norm_sim_docvecs
# 3    (0.0092)   (0.0053)   (0.0044)   (0.0044)  norm_sim_docvecs
# 4   0.1457***  0.1451***  0.1845***  0.1971***  norm_sim_docvecs
# 5    (0.0049)   (0.0029)   (0.0026)   (0.0025)  norm_sim_docvecs
# ..        ...        ...        ...        ...               ...
# 18  0.1381***  0.1221***  0.1582***  0.1696***  norm_sim_docvecs
# 19   (0.0109)   (0.0065)   (0.0059)   (0.0053)  norm_sim_docvecs
# 20  0.0994***  0.1038***  0.1291***  0.1393***  norm_sim_docvecs
# 21   (0.0072)   (0.0042)   (0.0036)   (0.0038)  norm_sim_docvecs
# 24      80414     226512     382447     511077  norm_sim_docvecs
# 25       0.10       0.10       0.11       0.07  norm_sim_docvecs
# 0   1.2938***  1.4733***  1.3431***  1.2396***  norm_sim_docvecs
# 1    (0.1045)   (0.0727)   (0.0576)   (0.0585)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.07       0.07       0.08       0.05  norm_sim_docvecs
# 0   0.2720***  0.3721***  0.4429***  0.3694***  norm_sim_docvecs
# 1    (0.0366)   (0.0281)   (0.0299)   (0.0276)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.06       0.07       0.08       0.05  norm_sim_docvecs
# 0   1.5134***  1.2575***  1.1010***  0.8388***  norm_sim_docvecs
# 1    (0.0979)   (0.0635)   (0.0397)   (0.0255)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.07       0.07       0.08       0.05  norm_sim_docvecs
# 0   0.4430***  0.4450***  0.4288***  0.3958***  norm_sim_docvecs
# 1    (0.0086)   (0.0066)   (0.0050)   (0.0043)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.08       0.08       0.10       0.06  norm_sim_docvecs
# 0   -0.0000**  2.0351***  1.6240***  1.5914***  norm_sim_docvecs
# 1    (0.0000)   (0.0084)   (0.2233)   (0.1630)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.06       0.07       0.08       0.05  norm_sim_docvecs
# 0   0.4571***  0.4867***  0.4170***  0.4158***  norm_sim_docvecs
# 1    (0.0184)   (0.0165)   (0.0186)   (0.0213)  norm_sim_docvecs
# 4      192773     280962     437405     563881  norm_sim_docvecs
# 5        0.07       0.07       0.08       0.05  norm_sim_docvecs
#
#                         Model  Model Num  \
# 0             N PC FE-Year FE         60
# 1             N PC FE-Year FE         60
# 4             N PC FE-Year FE         60
# 5             N PC FE-Year FE         60
# 0              N PC FE-Sim PC         61
# 1              N PC FE-Sim PC         61
# 2              N PC FE-Sim PC         61
# 3              N PC FE-Sim PC         61
# 6              N PC FE-Sim PC         61
# 7              N PC FE-Sim PC         61
# 0              N PC FE-Int PC         62
# 1              N PC FE-Int PC         62
# 2              N PC FE-Int PC         62
# 3              N PC FE-Int PC         62
# 4              N PC FE-Int PC         62
# 5              N PC FE-Int PC         62
# 8              N PC FE-Int PC         62
# 9              N PC FE-Int PC         62
# 0          N PC FE-Sim PC MSA         63
# 1          N PC FE-Sim PC MSA         63
# 2          N PC FE-Sim PC MSA         63
# 3          N PC FE-Sim PC MSA         63
# 6          N PC FE-Sim PC MSA         63
# 7          N PC FE-Sim PC MSA         63
# 0          N PC FE-Int PC MSA         64
# 1          N PC FE-Int PC MSA         64
# 2          N PC FE-Int PC MSA         64
# 3          N PC FE-Int PC MSA         64
# 4          N PC FE-Int PC MSA         64
# 5          N PC FE-Int PC MSA         64
# ..                        ...        ...
# 18  N NonP M-Break Int PC MSA        113
# 19  N NonP M-Break Int PC MSA        113
# 20  N NonP M-Break Int PC MSA        113
# 21  N NonP M-Break Int PC MSA        113
# 24  N NonP M-Break Int PC MSA        113
# 25  N NonP M-Break Int PC MSA        113
# 0                     N Inv M        114
# 1                     N Inv M        114
# 4                     N Inv M        114
# 5                     N Inv M        114
# 0                  N Lawyer M        115
# 1                  N Lawyer M        115
# 4                  N Lawyer M        115
# 5                  N Lawyer M        115
# 0                      N CC M        116
# 1                      N CC M        116
# 4                      N CC M        116
# 5                      N CC M        116
# 0                      N PC M        117
# 1                      N PC M        117
# 4                      N PC M        117
# 5                      N PC M        117
# 0                     N NPC M        118
# 1                     N NPC M        118
# 4                     N NPC M        118
# 5                     N NPC M        118
# 0                N Examiner M        119
# 1                N Examiner M        119
# 4                N Examiner M        119
# 5                N Examiner M        119
#
#                                                 index
# 0                            C(inv_msa_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                            norm_mean_sim_docvecs_pc
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs_pc
# 3
# 4                            norm_mean_sim_docvecs_pc
# 5
# 8                                                 $N$
# 9                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                        norm_mean_sim_docvecs_pc_msa
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...
# 3
# 4                        norm_mean_sim_docvecs_pc_msa
# 5
# ..                                                ...
# 18      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa
# 19
# 20         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa
# 21
# 24                                                $N$
# 25                                     Adjusted $R^2$
# 0                           C(common_pat_inv)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                             C(lawyer_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                       C(common_cited_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                          C(primclass_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                         C(common_npc_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                           C(examiner_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
#
# [804 rows x 8 columns]
# INFO:root:('ldavecs', 'naics_name')
#       1975-85    1985-95    1995-05    2005-15               LKS  \
# 0   0.0451***  0.0596***  0.0964***  0.0760***  norm_sim_ldavecs
# 1    (0.0050)   (0.0041)   (0.0033)   (0.0030)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.10       0.09       0.12       0.14  norm_sim_ldavecs
# 0   0.0298***  0.0226***  0.0458***  0.0270***  norm_sim_ldavecs
# 1    (0.0061)   (0.0037)   (0.0030)   (0.0027)  norm_sim_ldavecs
# 2   0.4647***  0.4555***  0.4627***  0.4597***  norm_sim_ldavecs
# 3    (0.0032)   (0.0020)   (0.0016)   (0.0014)  norm_sim_ldavecs
# 6      102459     281350     438009     564377  norm_sim_ldavecs
# 7        0.27       0.26       0.29       0.30  norm_sim_ldavecs
# 0   0.0286***  0.0206***  0.0418***  0.0253***  norm_sim_ldavecs
# 1    (0.0058)   (0.0035)   (0.0028)   (0.0025)  norm_sim_ldavecs
# 2      0.0054  0.0100***  0.0183***   0.0060**  norm_sim_ldavecs
# 3    (0.0063)   (0.0038)   (0.0029)   (0.0024)  norm_sim_ldavecs
# 4   0.4634***  0.4530***  0.4578***  0.4580***  norm_sim_ldavecs
# 5    (0.0035)   (0.0022)   (0.0018)   (0.0016)  norm_sim_ldavecs
# 8      102459     281350     438009     564377  norm_sim_ldavecs
# 9        0.27       0.26       0.29       0.30  norm_sim_ldavecs
# 0     -0.0010  -0.0092**  0.0102***    -0.0037  norm_sim_ldavecs
# 1    (0.0070)   (0.0041)   (0.0032)   (0.0029)  norm_sim_ldavecs
# 2   0.4186***  0.4171***  0.4873***  0.5215***  norm_sim_ldavecs
# 3    (0.0044)   (0.0027)   (0.0022)   (0.0021)  norm_sim_ldavecs
# 6       80568     227007     383161     511661  norm_sim_ldavecs
# 7        0.22       0.21       0.26       0.27  norm_sim_ldavecs
# 0      0.0021   -0.0089*  0.0136***    -0.0012  norm_sim_ldavecs
# 1    (0.0079)   (0.0047)   (0.0037)   (0.0032)  norm_sim_ldavecs
# 2      0.0138     0.0014  0.0149***  0.0133***  norm_sim_ldavecs
# 3    (0.0088)   (0.0054)   (0.0042)   (0.0036)  norm_sim_ldavecs
# 4   0.4148***  0.4167***  0.4828***  0.5176***  norm_sim_ldavecs
# 5    (0.0050)   (0.0031)   (0.0025)   (0.0023)  norm_sim_ldavecs
# ..        ...        ...        ...        ...               ...
# 18  0.3974***  0.3944***  0.4519***  0.4738***  norm_sim_ldavecs
# 19   (0.0076)   (0.0048)   (0.0041)   (0.0035)  norm_sim_ldavecs
# 20  0.3725***  0.3669***  0.4280***  0.4864***  norm_sim_ldavecs
# 21   (0.0062)   (0.0038)   (0.0031)   (0.0028)  norm_sim_ldavecs
# 24      80568     227007     383161     511661  norm_sim_ldavecs
# 25       0.23       0.22       0.26       0.28  norm_sim_ldavecs
# 0   1.3972***  1.4431***  1.4813***  1.4406***  norm_sim_ldavecs
# 1    (0.0915)   (0.0674)   (0.0555)   (0.0548)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.10       0.10       0.12       0.14  norm_sim_ldavecs
# 0   0.4548***  0.4783***  0.4686***  0.3893***  norm_sim_ldavecs
# 1    (0.0371)   (0.0284)   (0.0302)   (0.0294)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.10       0.10       0.12       0.14  norm_sim_ldavecs
# 0   1.4903***  1.3951***  1.1754***  0.9425***  norm_sim_ldavecs
# 1    (0.0898)   (0.0570)   (0.0397)   (0.0270)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.10       0.10       0.12       0.15  norm_sim_ldavecs
# 0   0.6444***  0.6479***  0.7138***  0.6537***  norm_sim_ldavecs
# 1    (0.0085)   (0.0066)   (0.0052)   (0.0046)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.13       0.13       0.17       0.18  norm_sim_ldavecs
# 0   3.1732***  2.5632***  1.8665***  1.6993***  norm_sim_ldavecs
# 1    (0.1181)   (0.6085)   (0.2648)   (0.1268)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.10       0.09       0.12       0.14  norm_sim_ldavecs
# 0   0.5623***  0.5839***  0.5947***  0.5915***  norm_sim_ldavecs
# 1    (0.0188)   (0.0167)   (0.0194)   (0.0232)  norm_sim_ldavecs
# 4      193104     281358     438028     564393  norm_sim_ldavecs
# 5        0.11       0.10       0.12       0.14  norm_sim_ldavecs
#
#                         Model  Model Num  \
# 0             N PC FE-Year FE         60
# 1             N PC FE-Year FE         60
# 4             N PC FE-Year FE         60
# 5             N PC FE-Year FE         60
# 0              N PC FE-Sim PC         61
# 1              N PC FE-Sim PC         61
# 2              N PC FE-Sim PC         61
# 3              N PC FE-Sim PC         61
# 6              N PC FE-Sim PC         61
# 7              N PC FE-Sim PC         61
# 0              N PC FE-Int PC         62
# 1              N PC FE-Int PC         62
# 2              N PC FE-Int PC         62
# 3              N PC FE-Int PC         62
# 4              N PC FE-Int PC         62
# 5              N PC FE-Int PC         62
# 8              N PC FE-Int PC         62
# 9              N PC FE-Int PC         62
# 0          N PC FE-Sim PC MSA         63
# 1          N PC FE-Sim PC MSA         63
# 2          N PC FE-Sim PC MSA         63
# 3          N PC FE-Sim PC MSA         63
# 6          N PC FE-Sim PC MSA         63
# 7          N PC FE-Sim PC MSA         63
# 0          N PC FE-Int PC MSA         64
# 1          N PC FE-Int PC MSA         64
# 2          N PC FE-Int PC MSA         64
# 3          N PC FE-Int PC MSA         64
# 4          N PC FE-Int PC MSA         64
# 5          N PC FE-Int PC MSA         64
# ..                        ...        ...
# 18  N NonP M-Break Int PC MSA        113
# 19  N NonP M-Break Int PC MSA        113
# 20  N NonP M-Break Int PC MSA        113
# 21  N NonP M-Break Int PC MSA        113
# 24  N NonP M-Break Int PC MSA        113
# 25  N NonP M-Break Int PC MSA        113
# 0                     N Inv M        114
# 1                     N Inv M        114
# 4                     N Inv M        114
# 5                     N Inv M        114
# 0                  N Lawyer M        115
# 1                  N Lawyer M        115
# 4                  N Lawyer M        115
# 5                  N Lawyer M        115
# 0                      N CC M        116
# 1                      N CC M        116
# 4                      N CC M        116
# 5                      N CC M        116
# 0                      N PC M        117
# 1                      N PC M        117
# 4                      N PC M        117
# 5                      N PC M        117
# 0                     N NPC M        118
# 1                     N NPC M        118
# 4                     N NPC M        118
# 5                     N NPC M        118
# 0                N Examiner M        119
# 1                N Examiner M        119
# 4                N Examiner M        119
# 5                N Examiner M        119
#
#                                                 index
# 0                            C(inv_msa_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                            norm_mean_sim_ldavecs_pc
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs_pc
# 3
# 4                            norm_mean_sim_ldavecs_pc
# 5
# 8                                                 $N$
# 9                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2                        norm_mean_sim_ldavecs_pc_msa
# 3
# 6                                                 $N$
# 7                                      Adjusted $R^2$
# 0                            C(inv_msa_match)[T.True]
# 1
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs...
# 3
# 4                        norm_mean_sim_ldavecs_pc_msa
# 5
# ..                                                ...
# 18      pc_msa_greater_0:norm_mean_sim_ldavecs_pc_msa
# 19
# 20         pc_msa_less_0:norm_mean_sim_ldavecs_pc_msa
# 21
# 24                                                $N$
# 25                                     Adjusted $R^2$
# 0                           C(common_pat_inv)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                             C(lawyer_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                       C(common_cited_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                          C(primclass_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                         C(common_npc_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
# 0                           C(examiner_match)[T.True]
# 1
# 4                                                 $N$
# 5                                      Adjusted $R^2$
#
# [804 rows x 8 columns]
# INFO:root:('tp_pct_common_cited', 'primclass')
#                                                 index     1975-85     1985-95  \
# 0                            C(inv_msa_match)[T.True]   0.1163***   0.1693***
# 1                                                        (0.0097)    (0.0095)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.01        0.01
# 0                            C(inv_msa_match)[T.True]   0.1222***   0.1693***
# 1                                                        (0.0142)    (0.0095)
# 2                            norm_mean_sim_docvecs_pc   0.0378***    0.0302**
# 3                                                        (0.0136)    (0.0122)
# 6                                                 $N$       89062      244412
# 7                                      Adjusted $R^2$        0.01        0.01
# 0                            C(inv_msa_match)[T.True]   0.0917***   0.1374***
# 1                                                        (0.0297)    (0.0189)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs_pc      0.0162     0.0185*
# 3                                                        (0.0158)    (0.0103)
# 4                            norm_mean_sim_docvecs_pc   0.0355***    0.0276**
# 5                                                        (0.0133)    (0.0118)
# 8                                                 $N$       89062      244412
# 9                                      Adjusted $R^2$        0.01        0.01
# 0                            C(inv_msa_match)[T.True]   0.0849***   0.1167***
# 1                                                        (0.0129)    (0.0081)
# 2                        norm_mean_sim_docvecs_pc_msa    0.0164**   0.0213***
# 3                                                        (0.0065)    (0.0038)
# 6                                                 $N$       71443      201254
# 7                                      Adjusted $R^2$        0.00        0.01
# 0                            C(inv_msa_match)[T.True]      0.0229   0.0599***
# 1                                                        (0.0242)    (0.0126)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...   0.0683***   0.0686***
# 3                                                        (0.0246)    (0.0128)
# 4                        norm_mean_sim_docvecs_pc_msa      0.0039   0.0077***
# 5                                                        (0.0045)    (0.0024)
# ..                                                ...         ...         ...
# 18      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa      0.0101     -0.0012
# 19                                                       (0.0063)    (0.0033)
# 20         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa   -0.0170**     0.0090*
# 21                                                       (0.0083)    (0.0048)
# 24                                                $N$       71443      201254
# 25                                     Adjusted $R^2$        0.10        0.15
# 0                           C(common_pat_inv)[T.True]   4.7731***   6.1849***
# 1                                                        (0.3947)    (0.3514)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.09        0.13
# 0                             C(lawyer_match)[T.True]   1.9046***   2.2012***
# 1                                                        (0.1970)    (0.1589)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.03        0.04
# 0                       C(common_cited_match)[T.True]   8.1991***   7.1898***
# 1                                                        (0.2088)    (0.1513)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.57        0.48
# 0                          C(primclass_match)[T.True]  -0.0377***      0.1199
# 1                                                        (0.0027)    (0.0770)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.00        0.00
# 0                         C(common_npc_match)[T.True]  23.4020***  27.2011***
# 1                                                        (4.3883)    (1.4633)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.02        0.07
# 0                           C(examiner_match)[T.True]   0.1064***   0.1278***
# 1                                                        (0.0106)    (0.0111)
# 4                                                 $N$      166703      244415
# 5                                      Adjusted $R^2$        0.00        0.01
#
#               1995-05     2005-15                      Model  Model Num  \
# 0           0.1512***   0.1360***            N PC FE-Year FE         60
# 1            (0.0070)    (0.0057)            N PC FE-Year FE         60
# 4              351637      504227            N PC FE-Year FE         60
# 5                0.01        0.01            N PC FE-Year FE         60
# 0           0.1512***   0.1360***             N PC FE-Sim PC         61
# 1            (0.0070)    (0.0057)             N PC FE-Sim PC         61
# 2             0.0231*     -0.0106             N PC FE-Sim PC         61
# 3            (0.0122)    (0.0141)             N PC FE-Sim PC         61
# 6              351637      504227             N PC FE-Sim PC         61
# 7                0.01        0.01             N PC FE-Sim PC         61
# 0           0.1119***   0.0851***             N PC FE-Int PC         62
# 1            (0.0139)    (0.0130)             N PC FE-Int PC         62
# 2           0.0234***   0.0299***             N PC FE-Int PC         62
# 3            (0.0079)    (0.0076)             N PC FE-Int PC         62
# 4             0.0194*     -0.0155             N PC FE-Int PC         62
# 5            (0.0118)    (0.0140)             N PC FE-Int PC         62
# 8              351637      504227             N PC FE-Int PC         62
# 9                0.01        0.01             N PC FE-Int PC         62
# 0           0.0984***   0.0852***         N PC FE-Sim PC MSA         63
# 1            (0.0056)    (0.0046)         N PC FE-Sim PC MSA         63
# 2           0.0392***   0.0538***         N PC FE-Sim PC MSA         63
# 3            (0.0044)    (0.0046)         N PC FE-Sim PC MSA         63
# 6              311925      461406         N PC FE-Sim PC MSA         63
# 7                0.01        0.01         N PC FE-Sim PC MSA         63
# 0             0.0187*      0.0015         N PC FE-Int PC MSA         64
# 1            (0.0107)    (0.0097)         N PC FE-Int PC MSA         64
# 2           0.1061***   0.1219***         N PC FE-Int PC MSA         64
# 3            (0.0133)    (0.0136)         N PC FE-Int PC MSA         64
# 4           0.0165***   0.0269***         N PC FE-Int PC MSA         64
# 5            (0.0024)    (0.0026)         N PC FE-Int PC MSA         64
# ..                ...         ...                        ...        ...
# 18          0.0106***   0.0163***  N NonP M-Break Int PC MSA        113
# 19           (0.0033)    (0.0036)  N NonP M-Break Int PC MSA        113
# 20          0.0104***   0.0172***  N NonP M-Break Int PC MSA        113
# 21           (0.0035)    (0.0037)  N NonP M-Break Int PC MSA        113
# 24             311925      461406  N NonP M-Break Int PC MSA        113
# 25               0.16        0.29  N NonP M-Break Int PC MSA        113
# 0           6.0772***   8.6271***                    N Inv M        114
# 1            (0.3019)    (0.3382)                    N Inv M        114
# 4              351637      504227                    N Inv M        114
# 5                0.13        0.20                    N Inv M        114
# 0           2.1978***   3.3460***                 N Lawyer M        115
# 1            (0.1629)    (0.1857)                 N Lawyer M        115
# 4              351637      504227                 N Lawyer M        115
# 5                0.03        0.05                 N Lawyer M        115
# 0           5.4580***   4.1736***                     N CC M        116
# 1            (0.1063)    (0.0732)                     N CC M        116
# 4              351637      504227                     N CC M        116
# 5                0.38        0.28                     N CC M        116
# 0      975868064.4148   -0.0143**                     N PC M        117
# 1   (1163482729.3476)    (0.0056)                     N PC M        117
# 4              351637      504227                     N PC M        117
# 5                0.00        0.01                     N PC M        117
# 0          19.9467***  22.8210***                    N NPC M        118
# 1            (1.4715)    (0.8136)                    N NPC M        118
# 4              351637      504227                    N NPC M        118
# 5                0.09        0.20                    N NPC M        118
# 0           0.1501***   0.2126***               N Examiner M        119
# 1            (0.0135)    (0.0175)               N Examiner M        119
# 4              351637      504227               N Examiner M        119
# 5                0.00        0.01               N Examiner M        119
#
#                          LKS
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 8   norm_tp_pct_common_cited
# 9   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# ..                       ...
# 18  norm_tp_pct_common_cited
# 19  norm_tp_pct_common_cited
# 20  norm_tp_pct_common_cited
# 21  norm_tp_pct_common_cited
# 24  norm_tp_pct_common_cited
# 25  norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
#
# [700 rows x 8 columns]
# INFO:root:('docvecs', 'primclass')
#                                                 index     1975-85     1985-95  \
# 0                            C(inv_msa_match)[T.True]   0.0525***   0.0799***
# 1                                                        (0.0064)    (0.0051)
# 4                                                 $N$      170564      251218
# 5                                      Adjusted $R^2$        0.06        0.07
# 0                            C(inv_msa_match)[T.True]   0.0559***   0.0800***
# 1                                                        (0.0089)    (0.0051)
# 2                            norm_mean_sim_docvecs_pc   0.2456***   0.1795***
# 3                                                        (0.0129)    (0.0078)
# 6                                                 $N$       90998      251215
# 7                                      Adjusted $R^2$        0.07        0.07
# 0                            C(inv_msa_match)[T.True]     0.0355*   0.1004***
# 1                                                        (0.0213)    (0.0112)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs_pc      0.0108    -0.0117*
# 3                                                        (0.0111)    (0.0063)
# 4                            norm_mean_sim_docvecs_pc   0.2441***   0.1811***
# 5                                                        (0.0130)    (0.0078)
# 8                                                 $N$       90998      251215
# 9                                      Adjusted $R^2$        0.07        0.07
# 0                            C(inv_msa_match)[T.True]     0.0179*   0.0376***
# 1                                                        (0.0096)    (0.0054)
# 2                        norm_mean_sim_docvecs_pc_msa   0.0582***   0.0601***
# 3                                                        (0.0049)    (0.0030)
# 6                                                 $N$       73175      207260
# 7                                      Adjusted $R^2$        0.07        0.08
# 0                            C(inv_msa_match)[T.True]      0.0117   0.0344***
# 1                                                        (0.0132)    (0.0072)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...      0.0067      0.0038
# 3                                                        (0.0112)    (0.0065)
# 4                        norm_mean_sim_docvecs_pc_msa   0.0570***   0.0594***
# 5                                                        (0.0052)    (0.0032)
# ..                                                ...         ...         ...
# 18      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa   0.0695***   0.0642***
# 19                                                       (0.0075)    (0.0047)
# 20         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa      0.0197   0.0417***
# 21                                                       (0.0124)    (0.0069)
# 24                                                $N$       73175      207260
# 25                                     Adjusted $R^2$        0.08        0.08
# 0                           C(common_pat_inv)[T.True]   1.3944***   1.2562***
# 1                                                        (0.0556)    (0.0445)
# 4                                                 $N$      170564      251218
# 5                                      Adjusted $R^2$        0.07        0.07
# 0                             C(lawyer_match)[T.True]   0.5801***   0.5416***
# 1                                                        (0.0391)    (0.0276)
# 4                                                 $N$      170564      251218
# 5                                      Adjusted $R^2$        0.07        0.07
# 0                       C(common_cited_match)[T.True]   0.9128***   0.8384***
# 1                                                        (0.0339)    (0.0223)
# 4                                                 $N$      170564      251218
# 5                                      Adjusted $R^2$        0.07        0.08
# ...
# 5         0.07        0.05            N PC FE-Year FE         60
# 0    0.0775***   0.0568***             N PC FE-Sim PC         61
# 1     (0.0038)    (0.0032)             N PC FE-Sim PC         61
# 2    0.1702***   0.1592***             N PC FE-Sim PC         61
# 3     (0.0076)    (0.0085)             N PC FE-Sim PC         61
# 6       400729      518334             N PC FE-Sim PC         61
# 7         0.08        0.06             N PC FE-Sim PC         61
# 0    0.0948***   0.0655***             N PC FE-Int PC         62
# 1     (0.0085)    (0.0083)             N PC FE-Int PC         62
# 2    -0.0102**     -0.0050             N PC FE-Int PC         62
# 3     (0.0049)    (0.0047)             N PC FE-Int PC         62
# 4    0.1718***   0.1600***             N PC FE-Int PC         62
# 5     (0.0076)    (0.0086)             N PC FE-Int PC         62
# 8       400729      518334             N PC FE-Int PC         62
# 9         0.08        0.06             N PC FE-Int PC         62
# 0    0.0378***   0.0234***         N PC FE-Sim PC MSA         63
# 1     (0.0040)    (0.0034)         N PC FE-Sim PC MSA         63
# 2    0.0757***   0.0819***         N PC FE-Sim PC MSA         63
# 3     (0.0026)    (0.0026)         N PC FE-Sim PC MSA         63
# 6       355650      475340         N PC FE-Sim PC MSA         63
# 7         0.08        0.06         N PC FE-Sim PC MSA         63
# 0    0.0382***   0.0204***         N PC FE-Int PC MSA         64
# 1     (0.0054)    (0.0047)         N PC FE-Int PC MSA         64
# 2      -0.0005      0.0045         N PC FE-Int PC MSA         64
# 3     (0.0054)    (0.0052)         N PC FE-Int PC MSA         64
# 4    0.0758***   0.0810***         N PC FE-Int PC MSA         64
# 5     (0.0028)    (0.0028)         N PC FE-Int PC MSA         64
# ..         ...         ...                        ...        ...
# 18   0.0919***   0.0946***  N NonP M-Break Int PC MSA        113
# 19    (0.0041)    (0.0040)  N NonP M-Break Int PC MSA        113
# 20   0.0325***   0.0330***  N NonP M-Break Int PC MSA        113
# 21    (0.0061)    (0.0063)  N NonP M-Break Int PC MSA        113
# 24      355650      475340  N NonP M-Break Int PC MSA        113
# 25        0.09        0.06  N NonP M-Break Int PC MSA        113
# 0    1.2003***   1.0512***                    N Inv M        114
# 1     (0.0351)    (0.0359)                    N Inv M        114
# 4       400729      518334                    N Inv M        114
# 5         0.08        0.06                    N Inv M        114
# 0    0.5328***   0.4787***                 N Lawyer M        115
# 1     (0.0268)    (0.0256)                 N Lawyer M        115
# 4       400729      518334                 N Lawyer M        115
# 5         0.08        0.05                 N Lawyer M        115
# 0    0.7199***   0.5610***                     N CC M        116
# 1     (0.0167)    (0.0116)                     N CC M        116
# 4       400729      518334                     N CC M        116
# 5         0.08        0.06                     N CC M        116
# 0   -0.0721***  -0.0532***                     N PC M        117
# 1     (0.0084)    (0.0077)                     N PC M        117
# 4       400729      518334                     N PC M        117
# 5         0.07        0.05                     N PC M        117
# 0    1.4499***   1.5731***                    N NPC M        118
# 1     (0.1885)    (0.1060)                    N NPC M        118
# 4       400729      518334                    N NPC M        118
# 5         0.07        0.05                    N NPC M        118
# 0    0.0752***   0.0733***               N Examiner M        119
# 1     (0.0064)    (0.0069)               N Examiner M        119
# 4       400729      518334               N Examiner M        119
# 5         0.07        0.05               N Examiner M        119
#
#                  LKS
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 8   norm_sim_docvecs
# 9   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# ..               ...
# 18  norm_sim_docvecs
# 19  norm_sim_docvecs
# 20  norm_sim_docvecs
# 21  norm_sim_docvecs
# 24  norm_sim_docvecs
# 25  norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
#
# [700 rows x 8 columns]
# INFO:root:('ldavecs', 'primclass')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0547***  0.0631***
# 1                                                       (0.0057)   (0.0046)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.17
# 0                            C(inv_msa_match)[T.True]  0.0556***  0.0637***
# 1                                                       (0.0078)   (0.0046)
# 2                            norm_mean_sim_ldavecs_pc  0.3786***  0.3218***
# 3                                                       (0.0106)   (0.0072)
# 6                                                 $N$      91102     251504
# 7                                      Adjusted $R^2$       0.19       0.18
# 0                            C(inv_msa_match)[T.True]  0.0669***  0.0728***
# 1                                                       (0.0135)   (0.0077)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs_pc    -0.0072    -0.0061
# 3                                                       (0.0076)   (0.0046)
# 4                            norm_mean_sim_ldavecs_pc  0.3794***  0.3225***
# 5                                                       (0.0106)   (0.0073)
# 8                                                 $N$      91102     251504
# 9                                      Adjusted $R^2$       0.19       0.18
# 0                            C(inv_msa_match)[T.True]     0.0019   0.0116**
# 1                                                       (0.0084)   (0.0049)
# 2                        norm_mean_sim_ldavecs_pc_msa  0.1065***  0.1007***
# 3                                                       (0.0053)   (0.0032)
# 6                                                 $N$      73416     207987
# 7                                      Adjusted $R^2$       0.19       0.18
# 0                            C(inv_msa_match)[T.True]     0.0104   0.0126**
# 1                                                       (0.0111)   (0.0063)
# 2   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs...    -0.0096    -0.0012
# 3                                                       (0.0092)   (0.0055)
# 4                        norm_mean_sim_ldavecs_pc_msa  0.1085***  0.1010***
# 5                                                       (0.0056)   (0.0034)
# ..                                                ...        ...        ...
# 18      pc_msa_greater_0:norm_mean_sim_ldavecs_pc_msa  0.1166***  0.1117***
# 19                                                      (0.0062)   (0.0039)
# 20         pc_msa_less_0:norm_mean_sim_ldavecs_pc_msa  0.0778***  0.0700***
# 21                                                      (0.0095)   (0.0056)
# 24                                                $N$      73416     207987
# 25                                     Adjusted $R^2$       0.20       0.19
# 0                           C(common_pat_inv)[T.True]  0.9872***  1.0534***
# 1                                                       (0.0430)   (0.0340)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.18
# 0                             C(lawyer_match)[T.True]  0.4861***  0.4370***
# 1                                                       (0.0306)   (0.0232)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.17
# 0                       C(common_cited_match)[T.True]  0.7503***  0.7230***
# 1                                                       (0.0268)   (0.0190)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.18
# 0                          C(primclass_match)[T.True]     0.0710  0.0851***
# 1                                                       (0.0787)   (0.0248)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.17
# 0                         C(common_npc_match)[T.True]   1.3406**  1.8249***
# 1                                                       (0.6118)   (0.1460)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.17
# 0                           C(examiner_match)[T.True]  0.0924***  0.0842***
# 1                                                       (0.0062)   (0.0055)
# 4                                                 $N$     170780     251507
# 5                                      Adjusted $R^2$       0.17       0.17
#
#        1995-05     2005-15                      Model  Model Num  \
# 0    0.0612***   0.0427***            N PC FE-Year FE         60
# 1     (0.0036)    (0.0031)            N PC FE-Year FE         60
# 4       401106      518628            N PC FE-Year FE         60
# 5         0.19        0.19            N PC FE-Year FE         60
# 0    0.0619***   0.0422***             N PC FE-Sim PC         61
# 1     (0.0035)    (0.0031)             N PC FE-Sim PC         61
# 2    0.3445***   0.2763***             N PC FE-Sim PC         61
# 3     (0.0070)    (0.0074)             N PC FE-Sim PC         61
# 6       401106      518628             N PC FE-Sim PC         61
# 7         0.20        0.19             N PC FE-Sim PC         61
# 0    0.0783***   0.0600***             N PC FE-Int PC         62
# 1     (0.0058)    (0.0048)             N PC FE-Int PC         62
# 2   -0.0105***  -0.0117***             N PC FE-Int PC         62
# 3     (0.0034)    (0.0028)             N PC FE-Int PC         62
# 4    0.3462***   0.2783***             N PC FE-Int PC         62
# 5     (0.0070)    (0.0074)             N PC FE-Int PC         62
# 8       401106      518628             N PC FE-Int PC         62
# 9         0.20        0.19             N PC FE-Int PC         62
# 0    0.0101***      0.0046         N PC FE-Sim PC MSA         63
# 1     (0.0037)    (0.0032)         N PC FE-Sim PC MSA         63
# 2    0.1260***   0.1335***         N PC FE-Sim PC MSA         63
# 3     (0.0029)    (0.0029)         N PC FE-Sim PC MSA         63
# 6       356521      476078         N PC FE-Sim PC MSA         63
# 7         0.20        0.20         N PC FE-Sim PC MSA         63
# 0    0.0158***      0.0035         N PC FE-Int PC MSA         64
# 1     (0.0048)    (0.0039)         N PC FE-Int PC MSA         64
# 2      -0.0070      0.0015         N PC FE-Int PC MSA         64
# 3     (0.0044)    (0.0039)         N PC FE-Int PC MSA         64
# 4    0.1275***   0.1332***         N PC FE-Int PC MSA         64
# 5     (0.0030)    (0.0030)         N PC FE-Int PC MSA         64
# ..         ...         ...                        ...        ...
# 18   0.1383***   0.1399***  N NonP M-Break Int PC MSA        113
# 19    (0.0034)    (0.0033)  N NonP M-Break Int PC MSA        113
# 20   0.0941***   0.1024***  N NonP M-Break Int PC MSA        113
# 21    (0.0049)    (0.0048)  N NonP M-Break Int PC MSA        113
# 24      356521      476078  N NonP M-Break Int PC MSA        113
# 25        0.21        0.20  N NonP M-Break Int PC MSA        113
# 0    0.9648***   0.8981***                    N Inv M        114
# 1     (0.0273)    (0.0289)                    N Inv M        114
# 4       401106      518628                    N Inv M        114
# 5         0.20        0.19                    N Inv M        114
# 0    0.4310***   0.3741***                 N Lawyer M        115
# 1     (0.0232)    (0.0227)                 N Lawyer M        115
# 4       401106      518628                 N Lawyer M        115
# 5         0.19        0.19                 N Lawyer M        115
# 0    0.5988***   0.4509***                     N CC M        116
# 1     (0.0145)    (0.0106)                     N CC M        116
# 4       401106      518628                     N CC M        116
# 5         0.20        0.19                     N CC M        116
# 0    0.1343***   0.0894***                     N PC M        117
# 1     (0.0083)    (0.0076)                     N PC M        117
# 4       401106      518628                     N PC M        117
# 5         0.19        0.19                     N PC M        117
# 0    1.3838***   1.3055***                    N NPC M        118
# 1     (0.1094)    (0.0715)                    N NPC M        118
# 4       401106      518628                    N NPC M        118
# 5         0.19        0.19                    N NPC M        118
# 0    0.0830***   0.0610***               N Examiner M        119
# 1     (0.0060)    (0.0065)               N Examiner M        119
# 4       401106      518628               N Examiner M        119
# 5         0.19        0.19               N Examiner M        119
#
#                  LKS
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 8   norm_sim_ldavecs
# 9   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# ..               ...
# 18  norm_sim_ldavecs
# 19  norm_sim_ldavecs
# 20  norm_sim_ldavecs
# 21  norm_sim_ldavecs
# 24  norm_sim_ldavecs
# 25  norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
#
# [700 rows x 8 columns]

# %%
r.to_csv(pathdir+"reg_pairs_out_HC1_1016.csv")

# %% [markdown]
# #### Clustered

# %%
tab = {}
samples_l = ["naics_name", "primclass"]
# samples_l = ["naics_name"]
ks_l = ["tp_pct_common_cited", "docvecs", "ldavecs", ]
# ks_l = ["docvecs"]

for sample, ks in itertools.product(samples_l, ks_l):
        o_f = "reg_{0}_{1}_out_cluster_1016.pkl".format(ks, sample)
        
        res = pickle.load(open(pathdir+o_f, "rb"))

        res_out = pd.DataFrame()

        for k in res.keys():
            lks = res[k]["model"].split(" ~ ")[0]
            
            # Selecting portion of results without intercept
            cdf = res[k]["part_res_stars"].reset_index()
            ic_ind = cdf.loc[cdf["index"] == "Intercept"].index[0]
            # Include N & R^2
            cdf = cdf.iloc[pd.np.r_[0:ic_ind,ic_ind+2:len(cdf)]]
            cdf["Model"] = regs["model_names"][k]
            cdf["Model Num"] = k
            cdf["LKS"] = lks
        
            res_out = res_out.append(cdf)
        
        tab[ks, sample] = res_out
        del(res_out)
        
full_tab = tab

# %%
r = pd.DataFrame()
for k,v in tab.items():
    print(k)
    display(v)
    v["samp"] = str(k)
    v = v.reset_index(drop=True)
    r = pd.concat([r,v],axis=0)
# Out:
# INFO:root:('tp_pct_common_cited', 'naics_name')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]     0.0000  0.0004***
# 1                                                       (0.0001)   (0.0001)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.00       0.00
# 0                           C(common_pat_inv)[T.True]     0.0565    0.0392*
# 1                                                       (0.0415)   (0.0229)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.01       0.01
# 0                             C(lawyer_match)[T.True]     0.0054  0.0075***
# 1                                                       (0.0045)   (0.0029)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.00       0.00
# 0                       C(common_cited_match)[T.True]  0.2024***  0.1995***
# 1                                                       (0.0349)   (0.0227)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.55       0.50
# 0                          C(primclass_match)[T.True]  0.0011***  0.0015***
# 1                                                       (0.0003)   (0.0002)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.00       0.00
# 0                            C(inv_msa_match)[T.True]     0.0000  0.0004***
# 1                                                       (0.0001)   (0.0001)
# 2                                 mean_sim_docvecs_pc   0.0097**  0.0114***
# 3                                                       (0.0039)   (0.0018)
# 6                                                 $N$      38445     105898
# 7                                      Adjusted $R^2$       0.00       0.00
# 0                            C(inv_msa_match)[T.True]    -0.0001   -0.0007*
# 1                                                       (0.0003)   (0.0004)
# 2        C(inv_msa_match)[T.True]:mean_sim_docvecs_pc     0.0005   0.0080**
# 3                                                       (0.0026)   (0.0032)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]    -0.0035  0.0173***
# 7                                                       (0.0076)   (0.0059)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...     0.0032  0.0406***
# 9                                                       (0.0094)   (0.0099)
# 10                            C(lawyer_match)[T.True]     0.2787   0.3855**
# 11                                                      (0.2149)   (0.1874)
# 12                       norm_mean_sim_docvecs_pc_msa    0.0096*  0.0112***
# 13                                                      (0.0054)   (0.0041)
# 16                                                $N$      38445     105898
# 17                                     Adjusted $R^2$       0.02       0.01
# 0                            C(common_est_inv)[T.1.0]    -0.0138    0.0141*
# 1                                                       (0.0106)   (0.0077)
# 2                           C(common_pat_inv)[T.True]     3.6313     2.3739
# 3                                                       (2.6885)   (1.5362)
# 4                           C(examiner_match)[T.True]  0.2015***  0.1112***
# 5                                                       (0.0678)   (0.0402)
# 6                            C(inv_msa_match)[T.True]    -0.0078    -0.0189
# 7                                                       (0.0048)   (0.0116)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...     0.0077  0.0803***
# 9                                                       (0.0187)   (0.0250)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...    -0.0037    -0.0112
# 11                                                      (0.0041)   (0.0107)
# 12                            C(lawyer_match)[T.True]     0.2763   0.3786**
# 13                                                      (0.2159)   (0.1872)
# 14      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa    0.0138*   0.0198**
# 15                                                      (0.0078)   (0.0097)
# 16         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa     0.0057   0.0045**
# 17                                                      (0.0040)   (0.0022)
# 20                                                $N$      38445     105898
# 21                                     Adjusted $R^2$       0.02       0.01
#
#        1995-05     2005-15                      Model  Model Num  \
# 0    0.0006***   0.0005***              PC FE-Year FE          0
# 1     (0.0001)    (0.0001)              PC FE-Year FE          0
# 4       185859      327759              PC FE-Year FE          0
# 5         0.00        0.00              PC FE-Year FE          0
# 0    0.0693***   0.0911***                PC FE-Inv M          1
# 1     (0.0180)    (0.0237)                PC FE-Inv M          1
# 4       185859      327759                PC FE-Inv M          1
# 5         0.03        0.04                PC FE-Inv M          1
# 0    0.0097***   0.0064***             PC FE-Lawyer M          2
# 1     (0.0030)    (0.0020)             PC FE-Lawyer M          2
# 4       185859      327759             PC FE-Lawyer M          2
# 5         0.00        0.00             PC FE-Lawyer M          2
# 0    0.1596***   0.0938***                 PC FE-CC M          3
# 1     (0.0113)    (0.0064)                 PC FE-CC M          3
# 4       185859      327759                 PC FE-CC M          3
# 5         0.39        0.26                 PC FE-CC M          3
# 0    0.0018***   0.0017***                 PC FE-PC M          4
# 1     (0.0002)    (0.0003)                 PC FE-PC M          4
# 4       185859      327759                 PC FE-PC M          4
# 5         0.00        0.00                 PC FE-PC M          4
# 0    0.0006***   0.0004***               PC FE-Sim PC          5
# 1     (0.0001)    (0.0001)               PC FE-Sim PC          5
# 2    0.0145***   0.0179***               PC FE-Sim PC          5
# 3     (0.0021)    (0.0030)               PC FE-Sim PC          5
# 6       185859      327759               PC FE-Sim PC          5
# 7         0.00        0.00               PC FE-Sim PC          5
# 0   -0.0012***  -0.0011***               PC FE-Int PC          6
# 1     (0.0004)    (0.0004)               PC FE-Int PC          6
# 2    0.0136***   0.0115***               PC FE-Int PC          6
# 3     (0.0037)    (0.0032)               PC FE-Int PC          6
# ..         ...         ...                        ...        ...
# 6    0.0272***   0.0186***        N Exam M-Int PC MSA        128
# 7     (0.0075)    (0.0054)        N Exam M-Int PC MSA        128
# 8    0.0422***   0.0418***        N Exam M-Int PC MSA        128
# 9     (0.0122)    (0.0116)        N Exam M-Int PC MSA        128
# 10    0.3622**      0.1591        N Exam M-Int PC MSA        128
# 11    (0.1745)    (0.1294)        N Exam M-Int PC MSA        128
# 12   0.0160***   0.0235***        N Exam M-Int PC MSA        128
# 13    (0.0034)    (0.0044)        N Exam M-Int PC MSA        128
# 16      185859      327759        N Exam M-Int PC MSA        128
# 17        0.03        0.04        N Exam M-Int PC MSA        128
# 0       0.0035   0.0117***  N Exam M-Break Int PC MSA        129
# 1     (0.0061)    (0.0039)  N Exam M-Break Int PC MSA        129
# 2    4.4186***   5.9083***  N Exam M-Break Int PC MSA        129
# 3     (1.1985)    (1.5939)  N Exam M-Break Int PC MSA        129
# 4    0.2146***   0.2395***  N Exam M-Break Int PC MSA        129
# 5     (0.0740)    (0.0784)  N Exam M-Break Int PC MSA        129
# 6      -0.0086      0.0002  N Exam M-Break Int PC MSA        129
# 7     (0.0111)    (0.0102)  N Exam M-Break Int PC MSA        129
# 8    0.0853***    0.0644**  N Exam M-Break Int PC MSA        129
# 9     (0.0306)    (0.0263)  N Exam M-Break Int PC MSA        129
# 10     -0.0127      0.0034  N Exam M-Break Int PC MSA        129
# 11    (0.0136)    (0.0123)  N Exam M-Break Int PC MSA        129
# 12    0.3572**      0.1561  N Exam M-Break Int PC MSA        129
# 13    (0.1743)    (0.1292)  N Exam M-Break Int PC MSA        129
# 14   0.0226***   0.0408***  N Exam M-Break Int PC MSA        129
# 15    (0.0058)    (0.0094)  N Exam M-Break Int PC MSA        129
# 16   0.0123***   0.0101***  N Exam M-Break Int PC MSA        129
# 17    (0.0031)    (0.0027)  N Exam M-Break Int PC MSA        129
# 20      185859      327759  N Exam M-Break Int PC MSA        129
# 21        0.03        0.04  N Exam M-Break Int PC MSA        129
#
#                          LKS
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 2        tp_pct_common_cited
# 3        tp_pct_common_cited
# 6        tp_pct_common_cited
# 7        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 2        tp_pct_common_cited
# 3        tp_pct_common_cited
# ..                       ...
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 8   norm_tp_pct_common_cited
# 9   norm_tp_pct_common_cited
# 10  norm_tp_pct_common_cited
# 11  norm_tp_pct_common_cited
# 12  norm_tp_pct_common_cited
# 13  norm_tp_pct_common_cited
# 16  norm_tp_pct_common_cited
# 17  norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 8   norm_tp_pct_common_cited
# 9   norm_tp_pct_common_cited
# 10  norm_tp_pct_common_cited
# 11  norm_tp_pct_common_cited
# 12  norm_tp_pct_common_cited
# 13  norm_tp_pct_common_cited
# 14  norm_tp_pct_common_cited
# 15  norm_tp_pct_common_cited
# 16  norm_tp_pct_common_cited
# 17  norm_tp_pct_common_cited
# 20  norm_tp_pct_common_cited
# 21  norm_tp_pct_common_cited
#
# [820 rows x 8 columns]
# INFO:root:('docvecs', 'naics_name')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0057***  0.0109***
# 1                                                       (0.0018)   (0.0011)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.08       0.08
# 0                           C(common_pat_inv)[T.True]   0.0934**  0.1441***
# 1                                                       (0.0417)   (0.0178)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.08       0.08
# 0                             C(lawyer_match)[T.True]     0.0141  0.0516***
# 1                                                       (0.0157)   (0.0072)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.08       0.08
# 0                       C(common_cited_match)[T.True]  0.1621***  0.1218***
# 1                                                       (0.0225)   (0.0144)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.08       0.08
# 0                          C(primclass_match)[T.True]  0.0544***  0.0573***
# 1                                                       (0.0050)   (0.0055)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.09       0.09
# 0                            C(inv_msa_match)[T.True]    0.0027*  0.0060***
# 1                                                       (0.0016)   (0.0009)
# 2                                 mean_sim_docvecs_pc  0.9262***  0.9633***
# 3                                                       (0.0294)   (0.0130)
# 6                                                 $N$      38445     105898
# 7                                      Adjusted $R^2$       0.12       0.12
# 0                            C(inv_msa_match)[T.True]     0.0027   0.0060**
# 1                                                       (0.0043)   (0.0025)
# 2        C(inv_msa_match)[T.True]:mean_sim_docvecs_pc     0.0003    -0.0000
# 3                                                       (0.0324)   (0.0177)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]     0.0166  0.0415***
# 7                                                       (0.0127)   (0.0073)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...    0.0263*  0.0209***
# 9                                                       (0.0135)   (0.0078)
# 10                            C(lawyer_match)[T.True]    -0.0055  0.2056***
# 11                                                      (0.1071)   (0.0481)
# 12                       norm_mean_sim_docvecs_pc_msa  0.1601***  0.1591***
# 13                                                      (0.0094)   (0.0087)
# 16                                                $N$      38445     105898
# 17                                     Adjusted $R^2$       0.10       0.10
# 0                            C(common_est_inv)[T.1.0]  0.0622***  0.0471***
# 1                                                       (0.0236)   (0.0122)
# 2                           C(common_pat_inv)[T.True]     0.3005  0.6717***
# 3                                                       (0.3345)   (0.1221)
# 4                           C(examiner_match)[T.True]  0.2816***  0.3222***
# 5                                                       (0.0410)   (0.0353)
# 6                            C(inv_msa_match)[T.True]     0.0205    0.0255*
# 7                                                       (0.0196)   (0.0139)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...     0.0182   0.0354**
# 9                                                       (0.0259)   (0.0149)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...     0.0276    -0.0042
# 11                                                      (0.0229)   (0.0175)
# 12                            C(lawyer_match)[T.True]    -0.0115  0.2000***
# 13                                                      (0.1073)   (0.0485)
# 14      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa  0.1903***  0.1808***
# 15                                                      (0.0162)   (0.0174)
# 16         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa  0.1328***  0.1413***
# 17                                                      (0.0119)   (0.0085)
# 20                                                $N$      38445     105898
# 21                                     Adjusted $R^2$       0.10       0.10
#
#       1995-05    2005-15                      Model  Model Num  \
# 0   0.0093***  0.0082***              PC FE-Year FE          0
# 1    (0.0009)   (0.0007)              PC FE-Year FE          0
# 4      185859     327759              PC FE-Year FE          0
# 5        0.09       0.05              PC FE-Year FE          0
# 0   0.1353***  0.1401***                PC FE-Inv M          1
# 1    (0.0145)   (0.0131)                PC FE-Inv M          1
# 4      185859     327759                PC FE-Inv M          1
# 5        0.08       0.05                PC FE-Inv M          1
# 0   0.0538***  0.0408***             PC FE-Lawyer M          2
# 1    (0.0070)   (0.0071)             PC FE-Lawyer M          2
# 4      185859     327759             PC FE-Lawyer M          2
# 5        0.08       0.04             PC FE-Lawyer M          2
# 0   0.1212***  0.0995***                 PC FE-CC M          3
# 1    (0.0082)   (0.0058)                 PC FE-CC M          3
# 4      185859     327759                 PC FE-CC M          3
# 5        0.09       0.05                 PC FE-CC M          3
# 0   0.0559***  0.0523***                 PC FE-PC M          4
# 1    (0.0044)   (0.0038)                 PC FE-PC M          4
# 4      185859     327759                 PC FE-PC M          4
# 5        0.10       0.06                 PC FE-PC M          4
# 0   0.0047***  0.0041***               PC FE-Sim PC          5
# 1    (0.0007)   (0.0006)               PC FE-Sim PC          5
# 2   0.9263***  0.9618***               PC FE-Sim PC          5
# 3    (0.0148)   (0.0098)               PC FE-Sim PC          5
# 6      185859     327759               PC FE-Sim PC          5
# 7        0.13       0.08               PC FE-Sim PC          5
# 0      0.0011    -0.0007               PC FE-Int PC          6
# 1    (0.0037)   (0.0020)               PC FE-Int PC          6
# 2      0.0277   0.0353**               PC FE-Int PC          6
# 3    (0.0306)   (0.0146)               PC FE-Int PC          6
# ..        ...        ...                        ...        ...
# 6   0.0249***  0.0225***        N Exam M-Int PC MSA        128
# 7    (0.0094)   (0.0049)        N Exam M-Int PC MSA        128
# 8    0.0317**  0.0460***        N Exam M-Int PC MSA        128
# 9    (0.0131)   (0.0069)        N Exam M-Int PC MSA        128
# 10  0.2381***  0.1804***        N Exam M-Int PC MSA        128
# 11   (0.0471)   (0.0395)        N Exam M-Int PC MSA        128
# 12  0.2046***  0.2198***        N Exam M-Int PC MSA        128
# 13   (0.0132)   (0.0116)        N Exam M-Int PC MSA        128
# 16     185859     327759        N Exam M-Int PC MSA        128
# 17       0.11       0.07        N Exam M-Int PC MSA        128
# 0   0.0501***  0.0561***  N Exam M-Break Int PC MSA        129
# 1    (0.0087)   (0.0073)  N Exam M-Break Int PC MSA        129
# 2   0.6266***  0.5976***  N Exam M-Break Int PC MSA        129
# 3    (0.1111)   (0.0825)  N Exam M-Break Int PC MSA        129
# 4   0.2357***  0.2122***  N Exam M-Break Int PC MSA        129
# 5    (0.0361)   (0.0317)  N Exam M-Break Int PC MSA        129
# 6   0.0481***  0.0262***  N Exam M-Break Int PC MSA        129
# 7    (0.0102)   (0.0068)  N Exam M-Break Int PC MSA        129
# 8     -0.0032  0.0325***  N Exam M-Break Int PC MSA        129
# 9    (0.0260)   (0.0121)  N Exam M-Break Int PC MSA        129
# 10  0.0633***  0.0482***  N Exam M-Break Int PC MSA        129
# 11   (0.0125)   (0.0121)  N Exam M-Break Int PC MSA        129
# 12  0.2387***  0.1789***  N Exam M-Break Int PC MSA        129
# 13   (0.0468)   (0.0392)  N Exam M-Break Int PC MSA        129
# 14  0.2351***  0.2577***  N Exam M-Break Int PC MSA        129
# 15   (0.0273)   (0.0191)  N Exam M-Break Int PC MSA        129
# 16  0.1812***  0.1889***  N Exam M-Break Int PC MSA        129
# 17   (0.0104)   (0.0117)  N Exam M-Break Int PC MSA        129
# 20     185859     327759  N Exam M-Break Int PC MSA        129
# 21       0.11       0.07  N Exam M-Break Int PC MSA        129
#
#                  LKS
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 2        sim_docvecs
# 3        sim_docvecs
# 6        sim_docvecs
# 7        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 2        sim_docvecs
# 3        sim_docvecs
# ..               ...
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 8   norm_sim_docvecs
# 9   norm_sim_docvecs
# 10  norm_sim_docvecs
# 11  norm_sim_docvecs
# 12  norm_sim_docvecs
# 13  norm_sim_docvecs
# 16  norm_sim_docvecs
# 17  norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 8   norm_sim_docvecs
# 9   norm_sim_docvecs
# 10  norm_sim_docvecs
# 11  norm_sim_docvecs
# 12  norm_sim_docvecs
# 13  norm_sim_docvecs
# 14  norm_sim_docvecs
# 15  norm_sim_docvecs
# 16  norm_sim_docvecs
# 17  norm_sim_docvecs
# 20  norm_sim_docvecs
# 21  norm_sim_docvecs
#
# [820 rows x 8 columns]
# INFO:root:('ldavecs', 'naics_name')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0132***  0.0176***
# 1                                                       (0.0032)   (0.0019)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.14       0.12
# 0                           C(common_pat_inv)[T.True]   0.2204**  0.2625***
# 1                                                       (0.0867)   (0.0346)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.14       0.12
# 0                             C(lawyer_match)[T.True]  0.0788***  0.1118***
# 1                                                       (0.0258)   (0.0134)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.14       0.12
# 0                       C(common_cited_match)[T.True]  0.3420***  0.2780***
# 1                                                       (0.0430)   (0.0252)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.14       0.12
# 0                          C(primclass_match)[T.True]  0.1554***  0.1551***
# 1                                                       (0.0161)   (0.0172)
# 4                                                 $N$      38445     105898
# 5                                      Adjusted $R^2$       0.18       0.16
# 0                            C(inv_msa_match)[T.True]   0.0058**  0.0045***
# 1                                                       (0.0026)   (0.0014)
# 2                                 mean_sim_ldavecs_pc  1.0269***  0.9956***
# 3                                                       (0.0116)   (0.0097)
# 6                                                 $N$      38445     105898
# 7                                      Adjusted $R^2$       0.32       0.29
# 0                            C(inv_msa_match)[T.True]    0.0091*     0.0038
# 1                                                       (0.0046)   (0.0037)
# 2        C(inv_msa_match)[T.True]:mean_sim_ldavecs_pc    -0.0123     0.0024
# 3                                                       (0.0204)   (0.0164)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]    -0.0035    -0.0122
# 7                                                       (0.0137)   (0.0079)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs...     0.0161    0.0168*
# 9                                                       (0.0147)   (0.0089)
# 10                            C(lawyer_match)[T.True]   0.2210**  0.1806***
# 11                                                      (0.1027)   (0.0537)
# 12                       norm_mean_sim_ldavecs_pc_msa  0.4495***  0.4538***
# 13                                                      (0.0190)   (0.0194)
# 16                                                $N$      38445     105898
# 17                                     Adjusted $R^2$       0.27       0.25
# 0                            C(common_est_inv)[T.1.0]  0.0587***  0.0358***
# 1                                                       (0.0191)   (0.0081)
# 2                           C(common_pat_inv)[T.True]     0.1429  0.4023***
# 3                                                       (0.4671)   (0.1489)
# 4                           C(examiner_match)[T.True]  0.2248***  0.2664***
# 5                                                       (0.0425)   (0.0277)
# 6                            C(inv_msa_match)[T.True]    -0.0036  -0.0186**
# 7                                                       (0.0149)   (0.0095)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...     0.0102     0.0205
# 9                                                       (0.0211)   (0.0146)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...     0.0168     0.0029
# 11                                                      (0.0185)   (0.0110)
# 12                            C(lawyer_match)[T.True]   0.2220**  0.1787***
# 13                                                      (0.1028)   (0.0538)
# 14      pc_msa_greater_0:norm_mean_sim_ldavecs_pc_msa  0.4747***  0.4749***
# 15                                                      (0.0234)   (0.0247)
# 16         pc_msa_less_0:norm_mean_sim_ldavecs_pc_msa  0.4220***  0.4326***
# 17                                                      (0.0169)   (0.0150)
# 20                                                $N$      38445     105898
# 21                                     Adjusted $R^2$       0.27       0.25
#
#       1995-05    2005-15                      Model  Model Num  \
# 0   0.0243***  0.0179***              PC FE-Year FE          0
# 1    (0.0017)   (0.0020)              PC FE-Year FE          0
# 4      185859     327759              PC FE-Year FE          0
# 5        0.12       0.14              PC FE-Year FE          0
# 0   0.2570***  0.2765***                PC FE-Inv M          1
# 1    (0.0246)   (0.0219)                PC FE-Inv M          1
# 4      185859     327759                PC FE-Inv M          1
# 5        0.12       0.14                PC FE-Inv M          1
# 0   0.0800***  0.0624***             PC FE-Lawyer M          2
# 1    (0.0094)   (0.0102)             PC FE-Lawyer M          2
# 4      185859     327759             PC FE-Lawyer M          2
# 5        0.12       0.14             PC FE-Lawyer M          2
# 0   0.2264***  0.1913***                 PC FE-CC M          3
# 1    (0.0145)   (0.0187)                 PC FE-CC M          3
# 4      185859     327759                 PC FE-CC M          3
# 5        0.12       0.14                 PC FE-CC M          3
# 0   0.1703***  0.1511***                 PC FE-PC M          4
# 1    (0.0205)   (0.0159)                 PC FE-PC M          4
# 4      185859     327759                 PC FE-PC M          4
# 5        0.17       0.18                 PC FE-PC M          4
# 0   0.0108***  0.0052***               PC FE-Sim PC          5
# 1    (0.0013)   (0.0009)               PC FE-Sim PC          5
# 2   1.0099***  1.0007***               PC FE-Sim PC          5
# 3    (0.0117)   (0.0116)               PC FE-Sim PC          5
# 6      185859     327759               PC FE-Sim PC          5
# 7        0.31       0.30               PC FE-Sim PC          5
# 0      0.0035    0.0030*               PC FE-Int PC          6
# 1    (0.0024)   (0.0017)               PC FE-Int PC          6
# 2   0.0291***     0.0085               PC FE-Int PC          6
# 3    (0.0111)   (0.0073)               PC FE-Int PC          6
# ..        ...        ...                        ...        ...
# 6      0.0100    -0.0068        N Exam M-Int PC MSA        128
# 7    (0.0103)   (0.0043)        N Exam M-Int PC MSA        128
# 8    0.0208**  0.0174***        N Exam M-Int PC MSA        128
# 9    (0.0098)   (0.0043)        N Exam M-Int PC MSA        128
# 10  0.1315***   0.0807**        N Exam M-Int PC MSA        128
# 11   (0.0401)   (0.0337)        N Exam M-Int PC MSA        128
# 12  0.5251***  0.5521***        N Exam M-Int PC MSA        128
# 13   (0.0228)   (0.0170)        N Exam M-Int PC MSA        128
# 16     185859     327759        N Exam M-Int PC MSA        128
# 17       0.28       0.28        N Exam M-Int PC MSA        128
# 0   0.0474***  0.0385***  N Exam M-Break Int PC MSA        129
# 1    (0.0103)   (0.0062)  N Exam M-Break Int PC MSA        129
# 2   0.4405***  0.5191***  N Exam M-Break Int PC MSA        129
# 3    (0.1012)   (0.0759)  N Exam M-Break Int PC MSA        129
# 4   0.2148***  0.1881***  N Exam M-Break Int PC MSA        129
# 5    (0.0302)   (0.0366)  N Exam M-Break Int PC MSA        129
# 6      0.0133  -0.0090**  N Exam M-Break Int PC MSA        129
# 7    (0.0096)   (0.0044)  N Exam M-Break Int PC MSA        129
# 8      0.0075  0.0224***  N Exam M-Break Int PC MSA        129
# 9    (0.0163)   (0.0071)  N Exam M-Break Int PC MSA        129
# 10  0.0258***   0.0121**  N Exam M-Break Int PC MSA        129
# 11   (0.0088)   (0.0054)  N Exam M-Break Int PC MSA        129
# 12  0.1299***   0.0803**  N Exam M-Break Int PC MSA        129
# 13   (0.0404)   (0.0336)  N Exam M-Break Int PC MSA        129
# 14  0.5534***  0.5543***  N Exam M-Break Int PC MSA        129
# 15   (0.0309)   (0.0222)  N Exam M-Break Int PC MSA        129
# 16  0.5007***  0.5498***  N Exam M-Break Int PC MSA        129
# 17   (0.0177)   (0.0145)  N Exam M-Break Int PC MSA        129
# 20     185859     327759  N Exam M-Break Int PC MSA        129
# 21       0.28       0.28  N Exam M-Break Int PC MSA        129
#
#                  LKS
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 2        sim_ldavecs
# 3        sim_ldavecs
# 6        sim_ldavecs
# 7        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 2        sim_ldavecs
# 3        sim_ldavecs
# ..               ...
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 8   norm_sim_ldavecs
# 9   norm_sim_ldavecs
# 10  norm_sim_ldavecs
# 11  norm_sim_ldavecs
# 12  norm_sim_ldavecs
# 13  norm_sim_ldavecs
# 16  norm_sim_ldavecs
# 17  norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 8   norm_sim_ldavecs
# 9   norm_sim_ldavecs
# 10  norm_sim_ldavecs
# 11  norm_sim_ldavecs
# 12  norm_sim_ldavecs
# 13  norm_sim_ldavecs
# 14  norm_sim_ldavecs
# 15  norm_sim_ldavecs
# 16  norm_sim_ldavecs
# 17  norm_sim_ldavecs
# 20  norm_sim_ldavecs
# 21  norm_sim_ldavecs
#
# [820 rows x 8 columns]
# INFO:root:('tp_pct_common_cited', 'primclass')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0014***  0.0019***
# 1                                                       (0.0005)   (0.0003)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.00       0.01
# 0                           C(common_pat_inv)[T.True]   0.0788**  0.0794***
# 1                                                       (0.0338)   (0.0174)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.01       0.02
# 0                             C(lawyer_match)[T.True]   0.0292**  0.0219***
# 1                                                       (0.0124)   (0.0046)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.01       0.01
# 0                       C(common_cited_match)[T.True]  0.2625***  0.1956***
# 1                                                       (0.0168)   (0.0067)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.56       0.51
# 0                          C(primclass_match)[T.True]    -0.0000  0.0033***
# 1                                                       (0.0000)   (0.0001)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.00       0.00
# 0                            C(inv_msa_match)[T.True]  0.0014***  0.0019***
# 1                                                       (0.0005)   (0.0003)
# 2                                 mean_sim_docvecs_pc  0.0179***    -0.0151
# 3                                                       (0.0047)   (0.0160)
# 6                                                 $N$      36511     101363
# 7                                      Adjusted $R^2$       0.00       0.01
# 0                            C(inv_msa_match)[T.True]    -0.0002    0.0027*
# 1                                                       (0.0017)   (0.0014)
# 2        C(inv_msa_match)[T.True]:mean_sim_docvecs_pc     0.0079    -0.0041
# 3                                                       (0.0095)   (0.0069)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]    -0.0268     0.0156
# 7                                                       (0.0215)   (0.0139)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...   0.0419**     0.0132
# 9                                                       (0.0188)   (0.0135)
# 10                            C(lawyer_match)[T.True]    0.6565*  0.3786***
# 11                                                      (0.3374)   (0.1284)
# 12                       norm_mean_sim_docvecs_pc_msa     0.0031     0.0042
# 13                                                      (0.0063)   (0.0038)
# 16                                                $N$      36511     101363
# 17                                     Adjusted $R^2$       0.02       0.02
# 0                            C(common_est_inv)[T.1.0]    -0.0096  0.0281***
# 1                                                       (0.0204)   (0.0101)
# 2                           C(common_pat_inv)[T.True]   2.2110**  2.2339***
# 3                                                       (1.0061)   (0.5460)
# 4                           C(examiner_match)[T.True]  0.0815***  0.0570***
# 5                                                       (0.0183)   (0.0123)
# 6                            C(inv_msa_match)[T.True]    -0.0251     0.0067
# 7                                                       (0.0243)   (0.0163)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...    0.0387*     0.0209
# 9                                                       (0.0209)   (0.0155)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...    -0.0038    -0.0486
# 11                                                      (0.0394)   (0.0723)
# 12                            C(lawyer_match)[T.True]    0.6546*  0.3780***
# 13                                                      (0.3371)   (0.1284)
# 14      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa     0.0117    -0.0005
# 15                                                      (0.0122)   (0.0054)
# 16         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa    -0.0184  0.0154***
# 17                                                      (0.0175)   (0.0053)
# 20                                                $N$      36511     101363
# 21                                     Adjusted $R^2$       0.02       0.02
#
#       1995-05    2005-15                      Model  Model Num  \
# 0   0.0019***  0.0016***              PC FE-Year FE          0
# 1    (0.0002)   (0.0002)              PC FE-Year FE          0
# 4      176538     308704              PC FE-Year FE          0
# 5        0.01       0.01              PC FE-Year FE          0
# 0   0.0993***  0.1295***                PC FE-Inv M          1
# 1    (0.0133)   (0.0155)                PC FE-Inv M          1
# 4      176538     308704                PC FE-Inv M          1
# 5        0.04       0.06                PC FE-Inv M          1
# 0   0.0241***  0.0327***             PC FE-Lawyer M          2
# 1    (0.0045)   (0.0047)             PC FE-Lawyer M          2
# 4      176538     308704             PC FE-Lawyer M          2
# 5        0.01       0.02             PC FE-Lawyer M          2
# 0   0.1406***  0.1038***                 PC FE-CC M          3
# 1    (0.0045)   (0.0038)                 PC FE-CC M          3
# 4      176538     308704                 PC FE-CC M          3
# 5        0.42       0.29                 PC FE-CC M          3
# 0   0.0008***  0.0008***                 PC FE-PC M          4
# 1    (0.0001)   (0.0001)                 PC FE-PC M          4
# 4      176538     308704                 PC FE-PC M          4
# 5        0.01       0.01                 PC FE-PC M          4
# 0   0.0019***  0.0016***               PC FE-Sim PC          5
# 1    (0.0002)   (0.0002)               PC FE-Sim PC          5
# 2      0.0026     0.0192               PC FE-Sim PC          5
# 3    (0.0112)   (0.0233)               PC FE-Sim PC          5
# 6      176538     308704               PC FE-Sim PC          5
# 7        0.01       0.01               PC FE-Sim PC          5
# 0    0.0023**     0.0005               PC FE-Int PC          6
# 1    (0.0011)   (0.0010)               PC FE-Int PC          6
# 2     -0.0019     0.0059               PC FE-Int PC          6
# 3    (0.0059)   (0.0055)               PC FE-Int PC          6
# ..        ...        ...                        ...        ...
# 6     -0.0069    -0.0036        N Exam M-Int PC MSA        128
# 7    (0.0123)   (0.0097)        N Exam M-Int PC MSA        128
# 8    0.0353**    0.0221*        N Exam M-Int PC MSA        128
# 9    (0.0151)   (0.0133)        N Exam M-Int PC MSA        128
# 10  0.4230***  0.6447***        N Exam M-Int PC MSA        128
# 11   (0.1183)   (0.1206)        N Exam M-Int PC MSA        128
# 12  0.0103***  0.0225***        N Exam M-Int PC MSA        128
# 13   (0.0031)   (0.0050)        N Exam M-Int PC MSA        128
# 16     176538     308704        N Exam M-Int PC MSA        128
# 17       0.05       0.06        N Exam M-Int PC MSA        128
# 0    0.0107**    0.0089*  N Exam M-Break Int PC MSA        129
# 1    (0.0054)   (0.0045)  N Exam M-Break Int PC MSA        129
# 2   2.9357***  3.8294***  N Exam M-Break Int PC MSA        129
# 3    (0.4057)   (0.4787)  N Exam M-Break Int PC MSA        129
# 4   0.0503***  0.0651***  N Exam M-Break Int PC MSA        129
# 5    (0.0120)   (0.0133)  N Exam M-Break Int PC MSA        129
# 6     -0.0148    -0.0049  N Exam M-Break Int PC MSA        129
# 7    (0.0143)   (0.0105)  N Exam M-Break Int PC MSA        129
# 8    0.0427**     0.0219  N Exam M-Break Int PC MSA        129
# 9    (0.0174)   (0.0144)  N Exam M-Break Int PC MSA        129
# 10    -0.0606    -0.0579  N Exam M-Break Int PC MSA        129
# 11   (0.0382)   (0.0687)  N Exam M-Break Int PC MSA        129
# 12  0.4219***  0.6436***  N Exam M-Break Int PC MSA        129
# 13   (0.1182)   (0.1205)  N Exam M-Break Int PC MSA        129
# 14     0.0077  0.0289***  N Exam M-Break Int PC MSA        129
# 15   (0.0050)   (0.0079)  N Exam M-Break Int PC MSA        129
# 16  0.0165***     0.0072  N Exam M-Break Int PC MSA        129
# 17   (0.0038)   (0.0050)  N Exam M-Break Int PC MSA        129
# 20     176538     308704  N Exam M-Break Int PC MSA        129
# 21       0.05       0.06  N Exam M-Break Int PC MSA        129
#
#                          LKS
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 4        tp_pct_common_cited
# 5        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 2        tp_pct_common_cited
# 3        tp_pct_common_cited
# 6        tp_pct_common_cited
# 7        tp_pct_common_cited
# 0        tp_pct_common_cited
# 1        tp_pct_common_cited
# 2        tp_pct_common_cited
# 3        tp_pct_common_cited
# ..                       ...
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 8   norm_tp_pct_common_cited
# 9   norm_tp_pct_common_cited
# 10  norm_tp_pct_common_cited
# 11  norm_tp_pct_common_cited
# 12  norm_tp_pct_common_cited
# 13  norm_tp_pct_common_cited
# 16  norm_tp_pct_common_cited
# 17  norm_tp_pct_common_cited
# 0   norm_tp_pct_common_cited
# 1   norm_tp_pct_common_cited
# 2   norm_tp_pct_common_cited
# 3   norm_tp_pct_common_cited
# 4   norm_tp_pct_common_cited
# 5   norm_tp_pct_common_cited
# 6   norm_tp_pct_common_cited
# 7   norm_tp_pct_common_cited
# 8   norm_tp_pct_common_cited
# 9   norm_tp_pct_common_cited
# 10  norm_tp_pct_common_cited
# 11  norm_tp_pct_common_cited
# 12  norm_tp_pct_common_cited
# 13  norm_tp_pct_common_cited
# 14  norm_tp_pct_common_cited
# 15  norm_tp_pct_common_cited
# 16  norm_tp_pct_common_cited
# 17  norm_tp_pct_common_cited
# 20  norm_tp_pct_common_cited
# 21  norm_tp_pct_common_cited
#
# [820 rows x 8 columns]
# INFO:root:('docvecs', 'primclass')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0066***  0.0100***
# 1                                                       (0.0023)   (0.0013)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.07       0.08
# 0                           C(common_pat_inv)[T.True]  0.1333***  0.1273***
# 1                                                       (0.0266)   (0.0152)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.07       0.08
# 0                             C(lawyer_match)[T.True]  0.0466***  0.0548***
# 1                                                       (0.0174)   (0.0061)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.07       0.08
# 0                       C(common_cited_match)[T.True]  0.0958***  0.0927***
# 1                                                       (0.0102)   (0.0056)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.07       0.08
# 0                          C(primclass_match)[T.True]  0.1322***  0.0858***
# 1                                                       (0.0000)   (0.0009)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.07       0.08
# 0                            C(inv_msa_match)[T.True]  0.0064***  0.0100***
# 1                                                       (0.0023)   (0.0013)
# 2                                 mean_sim_docvecs_pc  0.6067***  0.4556***
# 3                                                       (0.1567)   (0.1582)
# 6                                                 $N$      36511     101363
# 7                                      Adjusted $R^2$       0.07       0.08
# 0                            C(inv_msa_match)[T.True]    -0.0041   0.0175**
# 1                                                       (0.0125)   (0.0086)
# 2        C(inv_msa_match)[T.True]:mean_sim_docvecs_pc     0.0531    -0.0395
# 3                                                       (0.0644)   (0.0477)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]    -0.0091  0.0359***
# 7                                                       (0.0223)   (0.0133)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...     0.0126    -0.0124
# 9                                                       (0.0170)   (0.0162)
# 10                            C(lawyer_match)[T.True]     0.1730  0.2347***
# 11                                                      (0.1183)   (0.0427)
# 12                       norm_mean_sim_docvecs_pc_msa  0.0709***  0.0708***
# 13                                                      (0.0087)   (0.0074)
# 16                                                $N$      36511     101363
# 17                                     Adjusted $R^2$       0.08       0.08
# 0                            C(common_est_inv)[T.1.0]     0.0346  0.0574***
# 1                                                       (0.0227)   (0.0105)
# 2                           C(common_pat_inv)[T.True]  0.7995***  0.6902***
# 3                                                       (0.1838)   (0.1124)
# 4                           C(examiner_match)[T.True]  0.1261***  0.0919***
# 5                                                       (0.0189)   (0.0139)
# 6                            C(inv_msa_match)[T.True]    -0.0105   0.0391**
# 7                                                       (0.0232)   (0.0156)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...     0.0099    -0.0174
# 9                                                       (0.0188)   (0.0187)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...    -0.1290    -0.0414
# 11                                                      (0.0880)   (0.0529)
# 12                            C(lawyer_match)[T.True]     0.1684  0.2333***
# 13                                                      (0.1180)   (0.0429)
# 14      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa  0.0871***  0.0815***
# 15                                                      (0.0137)   (0.0105)
# 16         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa     0.0305  0.0466***
# 17                                                      (0.0228)   (0.0124)
# 20                                                $N$      36511     101363
# 21                                     Adjusted $R^2$       0.08       0.08
#
# ...
# 4       176538     308704              PC FE-Year FE          0
# 5         0.08       0.06              PC FE-Year FE          0
# 0    0.1191***  0.1133***                PC FE-Inv M          1
# 1     (0.0120)   (0.0083)                PC FE-Inv M          1
# 4       176538     308704                PC FE-Inv M          1
# 5         0.08       0.06                PC FE-Inv M          1
# 0    0.0468***  0.0416***             PC FE-Lawyer M          2
# 1     (0.0077)   (0.0062)             PC FE-Lawyer M          2
# 4       176538     308704             PC FE-Lawyer M          2
# 5         0.08       0.06             PC FE-Lawyer M          2
# 0    0.0876***  0.0653***                 PC FE-CC M          3
# 1     (0.0042)   (0.0031)                 PC FE-CC M          3
# 4       176538     308704                 PC FE-CC M          3
# 5         0.08       0.06                 PC FE-CC M          3
# 0    0.0846***  0.0864***                 PC FE-PC M          4
# 1     (0.0007)   (0.0004)                 PC FE-PC M          4
# 4       176538     308704                 PC FE-PC M          4
# 5         0.08       0.05                 PC FE-PC M          4
# 0    0.0108***  0.0072***               PC FE-Sim PC          5
# 1     (0.0010)   (0.0008)               PC FE-Sim PC          5
# 2      0.3939*  0.4314***               PC FE-Sim PC          5
# 3     (0.2120)   (0.1451)               PC FE-Sim PC          5
# 6       176538     308704               PC FE-Sim PC          5
# 7         0.08       0.06               PC FE-Sim PC          5
# 0    0.0203***  0.0169***               PC FE-Int PC          6
# 1     (0.0043)   (0.0050)               PC FE-Int PC          6
# 2    -0.0512**   -0.0528*               PC FE-Int PC          6
# 3     (0.0231)   (0.0270)               PC FE-Int PC          6
# ..         ...        ...                        ...        ...
# 6    0.0430***  0.0215***        N Exam M-Int PC MSA        128
# 7     (0.0095)   (0.0070)        N Exam M-Int PC MSA        128
# 8      -0.0142    -0.0100        N Exam M-Int PC MSA        128
# 9     (0.0089)   (0.0088)        N Exam M-Int PC MSA        128
# 10   0.1988***  0.1903***        N Exam M-Int PC MSA        128
# 11    (0.0531)   (0.0386)        N Exam M-Int PC MSA        128
# 12   0.0871***  0.0967***        N Exam M-Int PC MSA        128
# 13    (0.0100)   (0.0082)        N Exam M-Int PC MSA        128
# 16      176538     308704        N Exam M-Int PC MSA        128
# 17        0.08       0.06        N Exam M-Int PC MSA        128
# 0    0.0497***  0.0501***  N Exam M-Break Int PC MSA        129
# 1     (0.0097)   (0.0073)  N Exam M-Break Int PC MSA        129
# 2    0.7035***  0.6631***  N Exam M-Break Int PC MSA        129
# 3     (0.0845)   (0.0580)  N Exam M-Break Int PC MSA        129
# 4    0.0607***  0.0608***  N Exam M-Break Int PC MSA        129
# 5     (0.0133)   (0.0112)  N Exam M-Break Int PC MSA        129
# 6    0.0543***  0.0292***  N Exam M-Break Int PC MSA        129
# 7     (0.0093)   (0.0078)  N Exam M-Break Int PC MSA        129
# 8   -0.0290***  -0.0222**  N Exam M-Break Int PC MSA        129
# 9     (0.0097)   (0.0105)  N Exam M-Break Int PC MSA        129
# 10      0.0179     0.0128  N Exam M-Break Int PC MSA        129
# 11    (0.0388)   (0.0407)  N Exam M-Break Int PC MSA        129
# 12   0.1979***  0.1897***  N Exam M-Break Int PC MSA        129
# 13    (0.0533)   (0.0384)  N Exam M-Break Int PC MSA        129
# 14   0.1069***  0.1153***  N Exam M-Break Int PC MSA        129
# 15    (0.0148)   (0.0117)  N Exam M-Break Int PC MSA        129
# 16   0.0419***  0.0498***  N Exam M-Break Int PC MSA        129
# 17    (0.0150)   (0.0117)  N Exam M-Break Int PC MSA        129
# 20      176538     308704  N Exam M-Break Int PC MSA        129
# 21        0.08       0.06  N Exam M-Break Int PC MSA        129
#
#                  LKS
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 4        sim_docvecs
# 5        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 2        sim_docvecs
# 3        sim_docvecs
# 6        sim_docvecs
# 7        sim_docvecs
# 0        sim_docvecs
# 1        sim_docvecs
# 2        sim_docvecs
# 3        sim_docvecs
# ..               ...
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 8   norm_sim_docvecs
# 9   norm_sim_docvecs
# 10  norm_sim_docvecs
# 11  norm_sim_docvecs
# 12  norm_sim_docvecs
# 13  norm_sim_docvecs
# 16  norm_sim_docvecs
# 17  norm_sim_docvecs
# 0   norm_sim_docvecs
# 1   norm_sim_docvecs
# 2   norm_sim_docvecs
# 3   norm_sim_docvecs
# 4   norm_sim_docvecs
# 5   norm_sim_docvecs
# 6   norm_sim_docvecs
# 7   norm_sim_docvecs
# 8   norm_sim_docvecs
# 9   norm_sim_docvecs
# 10  norm_sim_docvecs
# 11  norm_sim_docvecs
# 12  norm_sim_docvecs
# 13  norm_sim_docvecs
# 14  norm_sim_docvecs
# 15  norm_sim_docvecs
# 16  norm_sim_docvecs
# 17  norm_sim_docvecs
# 20  norm_sim_docvecs
# 21  norm_sim_docvecs
#
# [820 rows x 8 columns]
# INFO:root:('ldavecs', 'primclass')
#                                                 index    1975-85    1985-95  \
# 0                            C(inv_msa_match)[T.True]  0.0096***  0.0133***
# 1                                                       (0.0032)   (0.0025)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.21       0.20
# 0                           C(common_pat_inv)[T.True]  0.1804***  0.1942***
# 1                                                       (0.0322)   (0.0179)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.22       0.20
# 0                             C(lawyer_match)[T.True]  0.0670***  0.0620***
# 1                                                       (0.0165)   (0.0107)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.21       0.20
# 0                       C(common_cited_match)[T.True]  0.1529***  0.1425***
# 1                                                       (0.0172)   (0.0088)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.22       0.21
# 0                          C(primclass_match)[T.True]  0.2468***  0.2204***
# 1                                                       (0.0000)   (0.0015)
# 4                                                 $N$      36511     101363
# 5                                      Adjusted $R^2$       0.21       0.20
# 0                            C(inv_msa_match)[T.True]  0.0094***  0.0135***
# 1                                                       (0.0032)   (0.0025)
# 2                                 mean_sim_ldavecs_pc  0.8605***  0.6948***
# 3                                                       (0.0682)   (0.1400)
# 6                                                 $N$      36511     101363
# 7                                      Adjusted $R^2$       0.22       0.21
# 0                            C(inv_msa_match)[T.True]     0.0144  0.0282***
# 1                                                       (0.0115)   (0.0072)
# 2        C(inv_msa_match)[T.True]:mean_sim_ldavecs_pc    -0.0124   -0.0372*
# 3                                                       (0.0286)   (0.0192)
# ..                                                ...        ...        ...
# 6                            C(inv_msa_match)[T.True]    -0.0138     0.0027
# 7                                                       (0.0252)   (0.0132)
# 8   C(inv_msa_match)[T.True]:norm_mean_sim_ldavecs...    -0.0058    -0.0019
# 9                                                       (0.0160)   (0.0102)
# 10                            C(lawyer_match)[T.True]   0.1528**   0.1003**
# 11                                                      (0.0625)   (0.0456)
# 12                       norm_mean_sim_ldavecs_pc_msa  0.1463***  0.1234***
# 13                                                      (0.0255)   (0.0177)
# 16                                                $N$      36511     101363
# 17                                     Adjusted $R^2$       0.22       0.21
# 0                            C(common_est_inv)[T.1.0]     0.0008  0.0470***
# 1                                                       (0.0167)   (0.0108)
# 2                           C(common_pat_inv)[T.True]  0.5923***  0.6292***
# 3                                                       (0.1357)   (0.0699)
# 4                           C(examiner_match)[T.True]  0.1105***  0.1081***
# 5                                                       (0.0201)   (0.0155)
# 6                            C(inv_msa_match)[T.True]    -0.0145     0.0031
# 7                                                       (0.0252)   (0.0132)
# 8   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...    -0.0063    -0.0048
# 9                                                       (0.0163)   (0.0103)
# 10  C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...    -0.0868   -0.0432*
# 11                                                      (0.0593)   (0.0260)
# 12                            C(lawyer_match)[T.True]   0.1514**   0.0990**
# 13                                                      (0.0630)   (0.0458)
# 14      pc_msa_greater_0:norm_mean_sim_ldavecs_pc_msa  0.1547***  0.1349***
# 15                                                      (0.0273)   (0.0181)
# 16         pc_msa_less_0:norm_mean_sim_ldavecs_pc_msa  0.1207***  0.0893***
# 17                                                      (0.0219)   (0.0178)
# 20                                                $N$      36511     101363
# 21                                     Adjusted $R^2$       0.22       0.21
#
#        1995-05    2005-15                      Model  Model Num  \
# 0    0.0120***  0.0088***              PC FE-Year FE          0
# 1     (0.0016)   (0.0016)              PC FE-Year FE          0
# 4       176538     308704              PC FE-Year FE          0
# 5         0.21       0.19              PC FE-Year FE          0
# 0    0.1677***  0.1575***                PC FE-Inv M          1
# 1     (0.0140)   (0.0134)                PC FE-Inv M          1
# 4       176538     308704                PC FE-Inv M          1
# 5         0.21       0.19                PC FE-Inv M          1
# 0    0.0599***  0.0529***             PC FE-Lawyer M          2
# 1     (0.0106)   (0.0087)             PC FE-Lawyer M          2
# 4       176538     308704             PC FE-Lawyer M          2
# 5         0.21       0.19             PC FE-Lawyer M          2
# 0    0.1278***  0.0943***                 PC FE-CC M          3
# 1     (0.0067)   (0.0052)                 PC FE-CC M          3
# 4       176538     308704                 PC FE-CC M          3
# 5         0.21       0.20                 PC FE-CC M          3
# 0    0.2160***  0.2086***                 PC FE-PC M          4
# 1     (0.0017)   (0.0007)                 PC FE-PC M          4
# 4       176538     308704                 PC FE-PC M          4
# 5         0.20       0.19                 PC FE-PC M          4
# 0    0.0121***  0.0087***               PC FE-Sim PC          5
# 1     (0.0016)   (0.0016)               PC FE-Sim PC          5
# 2    0.7816***  0.5894***               PC FE-Sim PC          5
# 3     (0.1284)   (0.1815)               PC FE-Sim PC          5
# 6       176538     308704               PC FE-Sim PC          5
# 7         0.21       0.20               PC FE-Sim PC          5
# 0    0.0246***  0.0185***               PC FE-Int PC          6
# 1     (0.0052)   (0.0051)               PC FE-Int PC          6
# 2   -0.0316***  -0.0257**               PC FE-Int PC          6
# 3     (0.0119)   (0.0127)               PC FE-Int PC          6
# ..         ...        ...                        ...        ...
# 6      -0.0051    -0.0107        N Exam M-Int PC MSA        128
# 7     (0.0095)   (0.0080)        N Exam M-Int PC MSA        128
# 8      -0.0003     0.0098        N Exam M-Int PC MSA        128
# 9     (0.0072)   (0.0072)        N Exam M-Int PC MSA        128
# 10   0.1258***  0.1264***        N Exam M-Int PC MSA        128
# 11    (0.0421)   (0.0309)        N Exam M-Int PC MSA        128
# 12   0.1564***  0.1604***        N Exam M-Int PC MSA        128
# 13    (0.0150)   (0.0117)        N Exam M-Int PC MSA        128
# 16      176538     308704        N Exam M-Int PC MSA        128
# 17        0.21       0.20        N Exam M-Int PC MSA        128
# 0    0.0437***  0.0459***  N Exam M-Break Int PC MSA        129
# 1     (0.0095)   (0.0081)  N Exam M-Break Int PC MSA        129
# 2    0.5373***  0.4938***  N Exam M-Break Int PC MSA        129
# 3     (0.0569)   (0.0487)  N Exam M-Break Int PC MSA        129
# 4    0.0904***  0.0629***  N Exam M-Break Int PC MSA        129
# 5     (0.0132)   (0.0126)  N Exam M-Break Int PC MSA        129
# 6      -0.0034    -0.0102  N Exam M-Break Int PC MSA        129
# 7     (0.0094)   (0.0079)  N Exam M-Break Int PC MSA        129
# 8      -0.0049     0.0078  N Exam M-Break Int PC MSA        129
# 9     (0.0076)   (0.0070)  N Exam M-Break Int PC MSA        129
# 10     -0.0190    -0.0270  N Exam M-Break Int PC MSA        129
# 11    (0.0357)   (0.0243)  N Exam M-Break Int PC MSA        129
# 12   0.1260***  0.1258***  N Exam M-Break Int PC MSA        129
# 13    (0.0420)   (0.0308)  N Exam M-Break Int PC MSA        129
# 14   0.1664***  0.1674***  N Exam M-Break Int PC MSA        129
# 15    (0.0161)   (0.0127)  N Exam M-Break Int PC MSA        129
# 16   0.1228***  0.1369***  N Exam M-Break Int PC MSA        129
# 17    (0.0135)   (0.0106)  N Exam M-Break Int PC MSA        129
# 20      176538     308704  N Exam M-Break Int PC MSA        129
# 21        0.21       0.20  N Exam M-Break Int PC MSA        129
#
#                  LKS
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 4        sim_ldavecs
# 5        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 2        sim_ldavecs
# 3        sim_ldavecs
# 6        sim_ldavecs
# 7        sim_ldavecs
# 0        sim_ldavecs
# 1        sim_ldavecs
# 2        sim_ldavecs
# 3        sim_ldavecs
# ..               ...
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 8   norm_sim_ldavecs
# 9   norm_sim_ldavecs
# 10  norm_sim_ldavecs
# 11  norm_sim_ldavecs
# 12  norm_sim_ldavecs
# 13  norm_sim_ldavecs
# 16  norm_sim_ldavecs
# 17  norm_sim_ldavecs
# 0   norm_sim_ldavecs
# 1   norm_sim_ldavecs
# 2   norm_sim_ldavecs
# 3   norm_sim_ldavecs
# 4   norm_sim_ldavecs
# 5   norm_sim_ldavecs
# 6   norm_sim_ldavecs
# 7   norm_sim_ldavecs
# 8   norm_sim_ldavecs
# 9   norm_sim_ldavecs
# 10  norm_sim_ldavecs
# 11  norm_sim_ldavecs
# 12  norm_sim_ldavecs
# 13  norm_sim_ldavecs
# 14  norm_sim_ldavecs
# 15  norm_sim_ldavecs
# 16  norm_sim_ldavecs
# 17  norm_sim_ldavecs
# 20  norm_sim_ldavecs
# 21  norm_sim_ldavecs
#
# [820 rows x 8 columns]

# %%
r.to_csv(pathdir+"reg_pairs_out_cluster_1016.csv")
