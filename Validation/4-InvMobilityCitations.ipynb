# %%
import numpy as np
import scipy as sp
import pandas as pd
import timeit
import datetime
import time
import pprint
import itertools
import pickle
import sklearn
import dask
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
import fastparquet
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import h5py
import collections
import dask
import dask.dataframe as dd
# Out:
# /homedir/eco/sfeng/bigdata/python/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Inventor mobility citations taken from https://sfengc7.stern.nyu.edu:8888/notebooks/patentdiffusion/201808Results/StrategicNonCitations/1c-InventorMobilityCitationsAnalysis-0904.ipynb

# %%
c_dict = pickle.load(open("DataStore/2018-06/col_names_dict.pkl", "rb"))
ip = pd.read_pickle("DataStore/2018-07/inv_move_pats_0712.pkl")
ip = dict(zip(ip["patent"], ip["inv_asg_rank"]))
mdc = fastparquet.ParquetFile("DataStore/2018-08/inv_mob_local_cite_sim_0904.parq").to_pandas()
mdc["tp_asg_rank"] = mdc["tp"].map(ip)
mdc["op_asg_rank"] = mdc["op"].map(ip)

#TP Pct of Common Cites
mdc["tp_pct_common_cites"] = mdc["num_common_cites"]/mdc["tp_num_cites"]

# Primary class match
pdf = fastparquet.ParquetFile("RawData/Cleaned/patent_loc_unique_us_0628.parq").to_pandas(["patent", "primclass"])
mdc["tp_primclass"] = mdc["tp"].map(dict(zip(pdf["patent"], pdf["primclass"])))
mdc["op_primclass"] = mdc["op"].map(dict(zip(pdf["patent"], pdf["primclass"])))
mdc["primclass_match"] = (mdc["tp_primclass"] == mdc["op_primclass"])

# Bins
import math

def sim_bin(x, a):
    try:
        return round(round(x / a) * a, -int(math.floor(math.log10(a))))
    except:
        return np.nan
    
mdc["bin_sim_ldavecs"] = mdc["sim_ldavecs"].apply(lambda x: sim_bin(x, 0.1))
mdc["bin_sim_docvecs"] = mdc["sim_docvecs"].apply(lambda x: sim_bin(x, 0.1))

# Year group
def get_year_group_10(x):
    if x in range(1975,1985):
        yg = "1975-85"
    elif x in range(1985,1995):
        yg = "1985-95"
    elif x in range(1995, 2005):
        yg = "1995-05"
    elif x in range(2005,2015):
        yg = "2005-15"
    else:
        yg = np.nan
    return yg

mdc["year_group"] = mdc["tp_appyear"].apply(get_year_group_10)

# %%
# Only want to compare first to first, and first to second firm: same as 1b
print(len(mdc))
i2 = mdc.loc[((mdc["tp_asg_rank"] == 0) & (mdc["op_asg_rank"] == 0)) |
                       ((mdc["tp_asg_rank"] == 0) & (mdc["op_asg_rank"] == 1))].copy()
print(len(i2))

# Firm change
i2["firm_change"] = i2["op_asg_rank"].apply(lambda x: "Before" if x == 0 else "After")
# Out:
# 571068
# 329575

# %%
i2.head()
# Out:
#             op       tp inventor_id                            tp_asg  \
# index
# 0      3930283  3930282   3930282-1  6d92f55ba3875e01b5554b98c65c929a
# 1      4041572  3930283   3930282-1  6d92f55ba3875e01b5554b98c65c929a
# 2      4016624  3930283   3930282-1  6d92f55ba3875e01b5554b98c65c929a
# 3      4102014  3930283   3930282-1  6d92f55ba3875e01b5554b98c65c929a
# 4      4477942  3930283   3930282-1  6d92f55ba3875e01b5554b98c65c929a
#
#                                  op_asg  asg_match  op_cites_tp  sim_ldavecs  \
# index
# 0      6d92f55ba3875e01b5554b98c65c929a       True        False     0.546727
# 1      6d92f55ba3875e01b5554b98c65c929a       True        False     0.378731
# 2      6d92f55ba3875e01b5554b98c65c929a       True        False     0.410078
# 3      6d92f55ba3875e01b5554b98c65c929a       True         True     0.678831
# 4      6d92f55ba3875e01b5554b98c65c929a       True        False     0.566891
#
#        sim_docvecs     tp_inv_msa     ...      bin_sim_ldavecs  \
# index                                 ...
# 0         0.519405  Lancaster, PA     ...                  0.5
# 1         0.250033  Lancaster, PA     ...                  0.4
# 2         0.497906  Lancaster, PA     ...                  0.4
# 3         0.264625  Lancaster, PA     ...                  0.7
# 4         0.438904  Lancaster, PA     ...                  0.6
#
#        bin_sim_docvecs  tp_appyear  op_appyear  tp_pct_common_cites  \
# index
# 0                  0.5      1974.0      1974.0                0.375
# 1                  0.3      1974.0      1976.0                0.000
# 2                  0.5      1974.0      1975.0                0.000
# 3                  0.3      1974.0      1977.0                0.000
# 4                  0.4      1974.0      1983.0                0.000
#
#        tp_primclass  op_primclass  primclass_match  year_group  firm_change
# index
# 0             452.0         452.0             True         NaN       Before
# 1             452.0         452.0             True         NaN       Before
# 2             452.0         452.0             True         NaN       Before
# 3             452.0         452.0             True         NaN       Before
# 4             452.0         452.0             True         NaN       Before
#
# [5 rows x 33 columns]

# %%
i2.columns
# Out:
# Index(['op', 'tp', 'inventor_id', 'tp_asg', 'op_asg', 'asg_match',
#        'op_cites_tp', 'sim_ldavecs', 'sim_docvecs', 'tp_inv_msa', 'op_inv_msa',
#        'msa_change', 'tp_num_cites', 'op_num_cites', 'num_common_cites',
#        'tp_num_inv_msa_cites', 'op_num_inv_msa_cites', 'ncc_tp_inv_msa',
#        'ncc_other_msa', 'tp_pct_inv_msa_cites', 'op_pct_inv_msa_cites',
#        'tp_asg_rank', 'op_asg_rank', 'bin_sim_ldavecs', 'bin_sim_docvecs',
#        'tp_appyear', 'op_appyear', 'tp_pct_common_cites', 'tp_primclass',
#        'op_primclass', 'primclass_match', 'year_group', 'firm_change'],
#       dtype='object')

# %%
i2[["sim_docvecs", "tp_pct_common_cites"]].corr()
# Out:
#                      sim_docvecs  tp_pct_common_cites
# sim_docvecs             1.000000             0.382942
# tp_pct_common_cites     0.382942             1.000000

# %%
sl = 0.3
display(i2.loc[(i2["firm_change"] == "After") & (i2["sim_docvecs"] > sl), "tp_pct_common_cites"].describe())
display(i2.loc[(i2["firm_change"] == "Before") & (i2["sim_docvecs"] > sl), "tp_pct_common_cites"].describe())
# Out:
# count    34260.000000
# mean         0.099856
# std          0.263909
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: tp_pct_common_cites, dtype: float64
# count    91191.000000
# mean         0.236587
# std          0.377381
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.375000
# max          1.000000
# Name: tp_pct_common_cites, dtype: float64

# %% [markdown]
# ________
# ### Example of inventor moving and citing less of the same patents

# %%
pdf = fastparquet.ParquetFile("RawData/Cleaned/patent_loc_unique_us_0628.parq").to_pandas(["patent", "title"])
pdf = dict(zip(pdf["patent"], pdf["title"]))

# %%
i2["tp_title"] = i2["tp"].map(pdf)
i2["op_title"] = i2["op"].map(pdf)
s1 = 0.6
ia = i2.loc[(i2["firm_change"] == "After") & (i2["sim_docvecs"] > sl)]
ib = i2.loc[(i2["firm_change"] == "Before") & (i2["sim_docvecs"] > sl)]

invs = list(set(ia["inventor_id"]).intersection(ib["inventor_id"]))
ia = ia.loc[ia["inventor_id"].isin(invs) & (ia["tp_pct_common_cites"] < 0.25), ["op", "tp", "op_title", "tp_title", "inventor_id", "tp_pct_common_cites", "sim_docvecs"]]
ib = ib.loc[ib["inventor_id"].isin(invs) & ib["tp"].isin(ia["tp"]) & (ib["tp_pct_common_cites"] > 0.5),
["op", "tp", "op_title", "tp_title", "inventor_id", "tp_pct_common_cites", "sim_docvecs"]]

# %%
ib.sample(20)
# Out:
#              op       tp                                           op_title  \
# index
# 663606  8521140  7440772  System and method for communicating media content
# 351921  5543514  5530123                           Water-soluble sapphyrins
# 97898   4564036  4549561         Coin sorting system with controllable stop
# 253468  6968736  6516664                        Rain sensor mounting system
# 512357  7120334  6965716  Optical resonator formed in a planar optical w...
# 255952  7916043  6678614                       Vehicle communication system
# 478547  6721101  6490094                                        Lens arrays
# 107814  5228934  5152101  Method of forming a flower pot or flower pot c...
# 456094  6655684  6149154  Device and method for forming and delivering h...
# 345679  5072127  4882498         Engineered video inspecting lighting array
# 258888  8543330  6909361                   Driver assist system for vehicle
# 253360  7918570  6642851  Vehicular interior rearview information mirror...
# 498650  7228305  6484199  Rating system for streaming media playback system
# 438678  7835989  5559549       Electronic book alternative delivery systems
# 420795  6953467  5496345  Apparatus and method for developing an anatomi...
# 519844  7713806  7015082  Structures and methods for manufacturing of di...
# 177810  6416743  6068832  Aerosol formulations of albuterol and 1,1,1,2-...
# 665913  8131373  8126559  Baroreflex stimulation synchronized to circadi...
# 75893   4211327  4007839                           Stack and nest container
# 413512  7033572  6083477  Non-antigenic toxin-conjugate and fusion prote...
#
#                                                  tp_title inventor_id  \
# index
# 663606                            Audio system and method   7187947-2
# 351921                     Sapphyrin chelator derivatives   4935498-1
# 97898                               Coin handling machine   4086928-1
# 253468             Rain sensor mount for use in a vehicle   4712879-1
# 512357  Amplitude and phase control in distributed opt...   6678429-2
# 255952                    Navigation system for a vehicle   4712879-1
# 478547                            High acuity lens system   6021826-1
# 107814   Flower pot or flower pot cover with pleated base   4989396-3
# 456094  Device and method for forming hands of randoml...   5695189-2
# 345679      Pulsed-array video inspection lighting system   4882498-1
# 258888                      Wireless communication system   4712879-1
# 253360  Interior rearview mirror system incorporating ...   4712879-1
# 498650  Streaming media search and playback system for...   6389467-1
# 438678                 Television program delivery system   5559549-1
# 420795  Expansible tunneling apparatus for creating an...   5403336-1
# 519844                        High mobility CMOS circuits   6881635-5
# 177810  Chlorofluorocarbon-free mometasone furoate aer...   4328213-3
# 665913  Neural stimulation with avoidance of inappropr...   7194313-1
# 75893                 Three-level full slide-on container   4007839-1
# 413512  Non-antigenic toxin-conjugate and fusion prote...   5364612-1
#
#         tp_pct_common_cites  sim_docvecs
# index
# 663606             0.915966     0.340214
# 351921             0.800000     0.483777
# 97898              1.000000     0.568338
# 253468             1.000000     0.788389
# 512357             1.000000     0.325154
# 255952             0.666667     0.504686
# 478547             0.914894     0.476767
# 107814             0.600000     0.437064
# 456094             1.000000     0.828247
# 345679             1.000000     0.531724
# 258888             0.568182     0.469806
# 253360             1.000000     0.546088
# 498650             1.000000     0.519864
# 438678             0.966102     0.351334
# 420795             0.984848     0.382248
# 519844             0.955224     0.415350
# 177810             0.600000     0.567331
# 665913             0.718750     0.380438
# 75893              0.666667     0.456624
# 413512             1.000000     0.742606

# %%
ia.loc[(ia["tp"] == 4549561), ]
# Out:
#             op       tp                                   op_title  \
# index
# 97902  5297986  4549561  Coin sorting apparatus with rotating disc
#
#                     tp_title inventor_id  tp_pct_common_cites  sim_docvecs
# index
# 97902  Coin handling machine   4086928-1                0.125     0.597223

# %%
display(i2.loc[97898, ["op", "tp", "op_title", "tp_title", "inventor_id", "tp_pct_common_cites", "sim_docvecs"]].tolist())
display(i2.loc[97902, ["op", "tp", "op_title", "tp_title", "inventor_id", "tp_pct_common_cites", "sim_docvecs"]].tolist())
# Out:
# [4564036,
#  4549561,
#  'Coin sorting system with controllable stop',
#  'Coin handling machine',
#  '4086928-1',
#  1.0,
#  0.5683375445603968]
# [5297986,
#  4549561,
#  'Coin sorting apparatus with rotating disc',
#  'Coin handling machine',
#  '4086928-1',
#  0.125,
#  0.5972225316551744]
