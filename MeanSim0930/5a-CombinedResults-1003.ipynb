# %%
import scipy as sp
import numpy as np
import pandas as pd
import timeit
import re
import json
import pickle
import fastparquet
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.iolib.summary2 as summary2

# %%
pathdir = "DataStore/2018-10/Reg0930/"
reg_f = "reg_model_1002.pkl"

regs = pickle.load(open(pathdir+reg_f, "rb"))

# Model names to equations
regs["model_names_eqn"] = dict(zip(regs["model_names"].tolist(), regs["model_names"].index.tolist()))

# %%
# JTH Rep
jr = pd.read_csv("DataStore/2018-07-P3/JTHReg0727/JTH_res_out_0726.csv",index_col=0)

# FE results (0930 - uses full dataset) and Sim results (1003 - uses only those with sim pc, sim pc msa values)
rr = pd.read_csv("DataStore/2018-10/Reg0930/reg_pairs_out_0930.csv",index_col=0)
rr2 = pd.read_csv("DataStore/2018-10/Reg0930/reg_pairs_out_1003.csv",index_col=0)
rr = rr.loc[~rr["Model"].isin(rr2["Model"])].append(rr2, ignore_index=True)

# Use reg_model_1002 to assign model numbers
rr["Model Num"] = rr["Model"].map(regs["model_names_eqn"])

# Get rid of models without a number (squared ones excluded from analysis)
print(len(rr))
rr = rr.loc[rr["Model Num"].notnull()]
print(len(rr))
rr["samp"] = rr["samp"].apply(eval)
rr = pd.concat([jr,rr],axis=0)
# Reset index
rr = rr.reset_index(drop=True)
# Integer model number
rr["Model Num"] = rr["Model Num"].astype(int)
# Out:
# 5122
# 1492

# %%
rr["id"] = list(zip(rr["samp"], rr["Model Num"]))
rr["id"] = rr["id"].astype(str)

# KS dict
ksd = rr[["id", "LKS"]].drop_duplicates()
ksd = dict(zip(ksd["id"], ksd["LKS"]))

# Sample dict
sd = rr[["id", "samp"]].drop_duplicates()
sd = dict(zip(sd["id"], sd["samp"]))

# %%
rr.head()
# Out:
#      1975-85    1985-95    1995-05    2005-15            LKS  \
# 0  0.0530***  0.0624***  0.0646***  0.0740***  perc_match_10
# 1   (0.0016)   (0.0011)   (0.0009)   (0.0012)  perc_match_10
# 2      58647     107358     185154     154619  perc_match_10
# 3       0.02       0.03       0.03       0.02  perc_match_10
# 4  0.0523***  0.0616***  0.0642***  0.0729***  perc_match_10
#
#                           Model  Model Num              index     samp  \
# 0  Perc Match Targ MSA, Year FE          0  $I(MSA \, Match)$  JTH Rep
# 1  Perc Match Targ MSA, Year FE          0                NaN  JTH Rep
# 2  Perc Match Targ MSA, Year FE          0                $N$  JTH Rep
# 3  Perc Match Targ MSA, Year FE          0     Adjusted $R^2$  JTH Rep
# 4    Perc Match Targ MSA, PC FE          1  $I(MSA \, Match)$  JTH Rep
#
#                id
# 0  ('JTH Rep', 0)
# 1  ('JTH Rep', 0)
# 2  ('JTH Rep', 0)
# 3  ('JTH Rep', 0)
# 4  ('JTH Rep', 1)

# %% [markdown]
# ### 1. Results with Year FE and PC Controls

# %%
repl1 = pickle.load(open("DataStore/2018-07-P3/reg_names_dict.pkl", "rb"))
# repl2 = {k: "\multicolumn{2}{c}{"+v+"}" if len(v)>1 else v for k,v in repl1.items() }

# %%
# Index by each table: Norm/Raw, KS, Sample
tab_ind = {}
tab_ind[("raw", "pct_cite", "JTH", "No FE")] = ("JTH Rep", 0)
tab_ind[("norm", "pct_cite", "JTH", "No FE")] = ("JTH Rep", 2)
tab_ind[("raw", "sim_cite", "JTH", "No FE")] = ("JTH Targ Sim", 4)
tab_ind[("norm", "sim_cite", "JTH", "No FE")] = ("JTH Targ Sim", 6)

tab_ind[("raw", "pct_cite", "JTH", "PC FE")] = ("JTH Rep", 1)
tab_ind[("norm", "pct_cite", "JTH", "PC FE")] = ("JTH Rep", 3)
tab_ind[("raw", "sim_cite", "JTH", "PC FE")] = ("JTH Targ Sim", 5)
tab_ind[("norm", "sim_cite", "JTH", "PC FE")] = ("JTH Targ Sim", 7)

for samp in ["naics_name", "primclass"]:
    if samp == "naics_name":
#         mods = ["No FE", "PC FE", "All FE", "Inv M-PC FE", "Lawyer M-PC FE", "PC M-PC FE", "CC M-PC FE"]
        mods = ["No FE", "PC FE", "All FE"]
    else:
        mods = ["No FE", "PC FE", "Inv FE"]
#     for dm in ["docvecs", "ldavecs", "tp_pct_common_cited"]:
    for dm in ["docvecs", "tp_pct_common_cited"]:
        for mod in mods:
            tab_ind[("raw", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"][mod])
            tab_ind[("norm", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"]["N "+mod])

# %% [markdown]
# #### 1.1 Results by year

# %%
# Results by year
ygs = ["index", "1975-85", "1985-95", "1995-05", "2005-15"]
tabp = {}
for k in tab_ind.keys():
    
    i = str(tab_ind[k])
    mod = rr.loc[(rr["id"] == i), ["Model", "Model Num", "samp"]]\
    .drop_duplicates().values[0]
    
    if "JTH" in k:
#         ygs = ["index", "1975-85", "1985-95", "1995-05",]
        ygs = ["index", "1975-85", "1985-95", "1995-05", "2005-15"]
    else:
        ygs = ["index", "1975-85", "1985-95", "1995-05", "2005-15"]
        
    # Select appropriate years
    tab = rr.loc[(rr["id"] == i), ygs].fillna("").set_index("index")

    # Add other columns
    if "No FE" in k:
        tab.loc["Year FE"] = [True]*len(tab.columns)
        tab.loc["PC FE"] = [False]*len(tab.columns)
    else:
        tab.loc["Year FE"] = [True]*len(tab.columns)
        tab.loc["PC FE"] = [True]*len(tab.columns)

#     # Pandas tables
    tab = tab.reset_index()
    # Replace "index"
    tab = tab.rename(columns={"index":""})
    # Replace everything else
    tab = tab.replace(repl1).copy()

    tabp[k] = tab
tab_f = tabp

# %%
for k,v in tab_f.items():
    if (k[0] == "norm"):
        print("\n"+str(k)+"\n"+"\n")
        ncols = len(v.columns)
        with pd.option_context("max_colwidth", 1000):
            print(v.to_latex(index=False,escape=False, column_format="lccc"))
# Out:
# ('norm', 'pct_cite', 'JTH', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.2448*** &  0.2881*** &  0.2983*** &  0.3417*** \\
#                    &   (0.0074) &   (0.0052) &   (0.0041) &   (0.0054) \\
#                $N$ &      58647 &     107358 &     185154 &     154619 \\
#     Adjusted $R^2$ &       0.02 &       0.03 &       0.03 &       0.02 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'sim_cite', 'JTH', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &   1985-95 &   1995-05 &   2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0469*** &    0.0154 &   -0.0047 &    0.0157 \\
#                    &   (0.0145) &  (0.0097) &  (0.0067) &  (0.0108) \\
#                $N$ &      38541 &     69612 &    122217 &     52710 \\
#     Adjusted $R^2$ &       0.00 &      0.00 &      0.00 &      0.00 \\
#            Year FE &       True &      True &      True &      True \\
#              PC FE &      False &     False &     False &     False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'pct_cite', 'JTH', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.2416*** &  0.2846*** &  0.2966*** &  0.3365*** \\
#                    &   (0.0073) &   (0.0051) &   (0.0041) &   (0.0054) \\
#                $N$ &      58647 &     107358 &     185154 &     154619 \\
#     Adjusted $R^2$ &       0.03 &       0.05 &       0.05 &       0.05 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'sim_cite', 'JTH', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &   1985-95 &   1995-05 &   2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0444*** &    0.0158 &    0.0064 &   0.0178* \\
#                    &   (0.0145) &  (0.0097) &  (0.0066) &  (0.0108) \\
#                $N$ &      38541 &     69612 &    122217 &     52710 \\
#     Adjusted $R^2$ &       0.03 &      0.03 &      0.04 &      0.04 \\
#            Year FE &       True &      True &      True &      True \\
#              PC FE &       True &      True &      True &      True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0185*** &  0.0521*** &  0.0576*** &  0.0562*** \\
#                    &   (0.0054) &   (0.0044) &   (0.0035) &   (0.0031) \\
#                $N$ &     192841 &     281222 &     437685 &     569252 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0323*** &  0.0605*** &  0.0610*** &  0.0571*** \\
#                    &   (0.0053) &   (0.0043) &   (0.0034) &   (0.0030) \\
#                $N$ &     192841 &     281222 &     437685 &     569252 \\
#     Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.06 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Firm\,Shared\,Inv)$ &  0.0748*** &  0.0480*** &  0.0524*** &  0.0652*** \\
#                         &   (0.0163) &   (0.0088) &   (0.0054) &   (0.0039) \\
#         $I(Inv\,Match)$ &    0.4186* &  0.6915*** &  0.7630*** &  0.7836*** \\
#                         &   (0.2299) &   (0.1221) &   (0.0819) &   (0.0781) \\
#       $I(MSA \, Match)$ &   0.0209** &  0.0515*** &  0.0448*** &  0.0390*** \\
#                         &   (0.0095) &   (0.0066) &   (0.0047) &   (0.0037) \\
#  $I(lawyer_i=lawyer_j)$ &     0.0782 &  0.2094*** &  0.2559*** &  0.2127*** \\
#                         &   (0.0828) &   (0.0444) &   (0.0393) &   (0.0328) \\
#   $I(Primclass\,Match)$ &  0.3962*** &  0.4137*** &  0.4019*** &  0.3833*** \\
#                         &   (0.0143) &   (0.0099) &   (0.0067) &   (0.0052) \\
#                     $N$ &      68395 &     129715 &     236674 &     371561 \\
#          Adjusted $R^2$ &       0.10 &       0.10 &       0.11 &       0.08 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'naics_name', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0318*** &  0.0769*** &  0.0869*** &  0.0710*** \\
#                    &   (0.0056) &   (0.0076) &   (0.0067) &   (0.0051) \\
#                $N$ &     188734 &     273714 &     384782 &     552981 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'naics_name', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0327*** &  0.0777*** &  0.0875*** &  0.0725*** \\
#                    &   (0.0056) &   (0.0076) &   (0.0068) &   (0.0051) \\
#                $N$ &     188734 &     273714 &     384782 &     552981 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'naics_name', 'All FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Firm\,Shared\,Inv)$ &    -0.0055 &   0.0171** &     0.0050 &  0.0147*** \\
#                         &   (0.0080) &   (0.0085) &   (0.0068) &   (0.0037) \\
#         $I(Inv\,Match)$ &     1.8271 &   3.1690** &  7.3118*** &  6.4742*** \\
#                         &   (1.4424) &   (1.4468) &   (1.3633) &   (1.1645) \\
#       $I(MSA \, Match)$ &     0.0002 &   0.0127** &  0.0190*** &  0.0170*** \\
#                         &   (0.0049) &   (0.0049) &   (0.0048) &   (0.0032) \\
#  $I(lawyer_i=lawyer_j)$ &     0.1324 &   0.4092** &  0.5509*** &   0.3415** \\
#                         &   (0.1206) &   (0.1847) &   (0.2104) &   (0.1602) \\
#   $I(Primclass\,Match)$ &  0.0692*** &  0.0913*** &  0.1079*** &  0.0956*** \\
#                         &   (0.0154) &   (0.0127) &   (0.0113) &   (0.0071) \\
#                     $N$ &      66014 &     124513 &     207295 &     356709 \\
#          Adjusted $R^2$ &       0.01 &       0.02 &       0.06 &       0.05 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0486*** &  0.0781*** &  0.0836*** &  0.0600*** \\
#                    &   (0.0066) &   (0.0052) &   (0.0039) &   (0.0033) \\
#                $N$ &     170882 &     252174 &     401623 &     529686 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0527*** &  0.0798*** &  0.0787*** &  0.0573*** \\
#                    &   (0.0064) &   (0.0050) &   (0.0038) &   (0.0032) \\
#                $N$ &     170882 &     252174 &     401623 &     529686 \\
#     Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.07 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Firm\,Shared\,Inv)$ &     0.0157 &  0.0673*** &  0.0536*** &  0.0604*** \\
#                         &   (0.0158) &   (0.0083) &   (0.0053) &   (0.0038) \\
#         $I(Inv\,Match)$ &  1.0227*** &  0.8423*** &  0.8453*** &  0.7662*** \\
#                         &   (0.1359) &   (0.0857) &   (0.0578) &   (0.0467) \\
#       $I(MSA \, Match)$ &  0.0412*** &  0.0634*** &  0.0701*** &  0.0488*** \\
#                         &   (0.0113) &   (0.0076) &   (0.0051) &   (0.0039) \\
#                     $N$ &      63460 &     122354 &     222970 &     351138 \\
#          Adjusted $R^2$ &       0.07 &       0.08 &       0.08 &       0.08 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'primclass', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.1138*** &  0.1685*** &  0.1459*** &  0.1281*** \\
#                    &   (0.0096) &   (0.0093) &   (0.0068) &   (0.0054) \\
#                $N$ &     167005 &     245355 &     352428 &     514322 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'primclass', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.1188*** &  0.1755*** &  0.1524*** &  0.1379*** \\
#                    &   (0.0097) &   (0.0095) &   (0.0070) &   (0.0056) \\
#                $N$ &     167005 &     245355 &     352428 &     514322 \\
#     Adjusted $R^2$ &       0.01 &       0.01 &       0.01 &       0.01 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'tp_pct_common_cited', 'primclass', 'Inv FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Firm\,Shared\,Inv)$ &     0.0247 &  0.0326*** &  0.0173*** &  0.0144*** \\
#                         &   (0.0185) &   (0.0095) &   (0.0049) &   (0.0033) \\
#         $I(Inv\,Match)$ &  2.7133*** &  2.6359*** &  3.5445*** &  4.4244*** \\
#                         &   (0.8056) &   (0.4813) &   (0.3985) &   (0.3923) \\
#       $I(MSA \, Match)$ &   0.0209** &  0.0432*** &  0.0344*** &  0.0272*** \\
#                         &   (0.0098) &   (0.0074) &   (0.0045) &   (0.0032) \\
#                     $N$ &      61067 &     117334 &     194733 &     336711 \\
#          Adjusted $R^2$ &       0.02 &       0.03 &       0.06 &       0.07 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}

# %%
for k,v in tab_f.items():
    if (k[0] == "raw"):
        print("\n"+str(k)+"\n"+"\n")
        ncols = len(v.columns)
        with pd.option_context("max_colwidth", 1000):
            print(v.to_latex(index=False,escape=False, column_format="lccc"))
# Out:
# ('raw', 'pct_cite', 'JTH', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0530*** &  0.0624*** &  0.0646*** \\
#                    &   (0.0016) &   (0.0011) &   (0.0009) \\
#                $N$ &      58647 &     107358 &     185154 \\
#     Adjusted $R^2$ &       0.02 &       0.03 &       0.03 \\
#            Year FE &       True &       True &       True \\
#              PC FE &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'sim_cite', 'JTH', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0543*** &  0.0468*** &  0.0408*** \\
#                    &   (0.0021) &   (0.0014) &   (0.0010) \\
#                $N$ &      38541 &      69612 &     122217 \\
#     Adjusted $R^2$ &       0.02 &       0.02 &       0.02 \\
#            Year FE &       True &       True &       True \\
#              PC FE &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'pct_cite', 'JTH', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0523*** &  0.0616*** &  0.0642*** \\
#                    &   (0.0016) &   (0.0011) &   (0.0009) \\
#                $N$ &      58647 &     107358 &     185154 \\
#     Adjusted $R^2$ &       0.03 &       0.05 &       0.05 \\
#            Year FE &       True &       True &       True \\
#              PC FE &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'sim_cite', 'JTH', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0540*** &  0.0469*** &  0.0422*** \\
#                    &   (0.0021) &   (0.0014) &   (0.0010) \\
#                $N$ &      38541 &      69612 &     122217 \\
#     Adjusted $R^2$ &       0.05 &       0.05 &       0.06 \\
#            Year FE &       True &       True &       True \\
#              PC FE &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0025*** &  0.0070*** &  0.0078*** &  0.0076*** \\
#                    &   (0.0007) &   (0.0006) &   (0.0005) &   (0.0004) \\
#                $N$ &     192841 &     281222 &     437685 &     569252 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0044*** &  0.0082*** &  0.0082*** &  0.0077*** \\
#                    &   (0.0007) &   (0.0006) &   (0.0005) &   (0.0004) \\
#                $N$ &     192841 &     281222 &     437685 &     569252 \\
#     Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.06 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'Inv M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                  &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Inv\,Match)$ &  0.1727*** &  0.2053*** &  0.1865*** &  0.1710*** \\
#                  &   (0.0141) &   (0.0096) &   (0.0076) &   (0.0076) \\
#              $N$ &     192841 &     281222 &     437685 &     569252 \\
#   Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.06 \\
#          Year FE &       True &       True &       True &       True \\
#            PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'Lawyer M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(lawyer_i=lawyer_j)$ &  0.0383*** &  0.0514*** &  0.0612*** &  0.0509*** \\
#                         &   (0.0049) &   (0.0038) &   (0.0040) &   (0.0037) \\
#                     $N$ &     192841 &     281222 &     437685 &     569252 \\
#          Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.06 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'PC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                        &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Primclass\,Match)$ &  0.0596*** &  0.0601*** &  0.0579*** &  0.0546*** \\
#                        &   (0.0012) &   (0.0009) &   (0.0007) &   (0.0006) \\
#                    $N$ &     192841 &     281222 &     437685 &     569252 \\
#         Adjusted $R^2$ &       0.08 &       0.09 &       0.10 &       0.07 \\
#                Year FE &       True &       True &       True &       True \\
#                  PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'CC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                           &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Common Cited \geq 1)$ &  0.2037*** &  0.1738*** &  0.1505*** &  0.1132*** \\
#                           &   (0.0130) &   (0.0086) &   (0.0054) &   (0.0034) \\
#                       $N$ &     192841 &     281222 &     437685 &     569252 \\
#            Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.06 \\
#                   Year FE &       True &       True &       True &       True \\
#                     PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0069*** &  0.0119*** &  0.0219*** &  0.0204*** \\
#                    &   (0.0012) &   (0.0009) &   (0.0008) &   (0.0007) \\
#                $N$ &     193173 &     281625 &     438317 &     570099 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0103*** &  0.0138*** &  0.0217*** &  0.0178*** \\
#                    &   (0.0011) &   (0.0009) &   (0.0007) &   (0.0007) \\
#                $N$ &     193173 &     281625 &     438317 &     570099 \\
#     Adjusted $R^2$ &       0.11 &       0.10 &       0.12 &       0.15 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'Inv M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                  &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Inv\,Match)$ &  0.3075*** &  0.3268*** &  0.3348*** &  0.3364*** \\
#                  &   (0.0202) &   (0.0146) &   (0.0120) &   (0.0120) \\
#              $N$ &     193173 &     281625 &     438317 &     570099 \\
#   Adjusted $R^2$ &       0.11 &       0.10 &       0.12 &       0.15 \\
#          Year FE &       True &       True &       True &       True \\
#            PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'Lawyer M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(lawyer_i=lawyer_j)$ &  0.1022*** &  0.1077*** &  0.1053*** &  0.0896*** \\
#                         &   (0.0082) &   (0.0063) &   (0.0067) &   (0.0065) \\
#                     $N$ &     193173 &     281625 &     438317 &     570099 \\
#          Adjusted $R^2$ &       0.11 &       0.10 &       0.12 &       0.15 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'PC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                        &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Primclass\,Match)$ &  0.1426*** &  0.1441*** &  0.1585*** &  0.1547*** \\
#                        &   (0.0019) &   (0.0015) &   (0.0012) &   (0.0010) \\
#                    $N$ &     193173 &     281625 &     438317 &     570099 \\
#         Adjusted $R^2$ &       0.14 &       0.14 &       0.17 &       0.19 \\
#                Year FE &       True &       True &       True &       True \\
#                  PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'naics_name', 'CC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                           &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Common Cited \geq 1)$ &  0.3288*** &  0.3137*** &  0.2630*** &  0.2114*** \\
#                           &   (0.0198) &   (0.0126) &   (0.0088) &   (0.0060) \\
#                       $N$ &     193173 &     281625 &     438317 &     570099 \\
#            Adjusted $R^2$ &       0.11 &       0.10 &       0.12 &       0.15 \\
#                   Year FE &       True &       True &       True &       True \\
#                     PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0005*** &  0.0012*** &  0.0013*** &  0.0011*** \\
#                    &   (0.0001) &   (0.0001) &   (0.0001) &   (0.0001) \\
#                $N$ &     188734 &     273714 &     384782 &     552981 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0005*** &  0.0012*** &  0.0013*** &  0.0011*** \\
#                    &   (0.0001) &   (0.0001) &   (0.0001) &   (0.0001) \\
#                $N$ &     188734 &     273714 &     384782 &     552981 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'Inv M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                  &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Inv\,Match)$ &  0.0966*** &  0.1697*** &  0.1772*** &  0.2031*** \\
#                  &   (0.0188) &   (0.0171) &   (0.0152) &   (0.0156) \\
#              $N$ &     188734 &     273714 &     384782 &     552981 \\
#   Adjusted $R^2$ &       0.08 &       0.15 &       0.15 &       0.16 \\
#          Year FE &       True &       True &       True &       True \\
#            PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'Lawyer M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(lawyer_i=lawyer_j)$ &  0.0122*** &  0.0279*** &  0.0434*** &  0.0393*** \\
#                         &   (0.0030) &   (0.0036) &   (0.0049) &   (0.0043) \\
#                     $N$ &     188734 &     273714 &     384782 &     552981 \\
#          Adjusted $R^2$ &       0.01 &       0.02 &       0.03 &       0.02 \\
#                 Year FE &       True &       True &       True &       True \\
#                   PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'PC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                        &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Primclass\,Match)$ &  0.0019*** &  0.0032*** &  0.0032*** &  0.0028*** \\
#                        &   (0.0002) &   (0.0003) &   (0.0002) &   (0.0002) \\
#                    $N$ &     188734 &     273714 &     384782 &     552981 \\
#         Adjusted $R^2$ &       0.00 &       0.01 &       0.00 &       0.01 \\
#                Year FE &       True &       True &       True &       True \\
#                  PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'naics_name', 'CC M-PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                           &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(Common Cited \geq 1)$ &  0.2539*** &  0.2724*** &  0.2143*** &  0.1340*** \\
#                           &   (0.0188) &   (0.0140) &   (0.0092) &   (0.0052) \\
#                       $N$ &     188734 &     273714 &     384782 &     552981 \\
#            Adjusted $R^2$ &       0.55 &       0.48 &       0.39 &       0.26 \\
#                   Year FE &       True &       True &       True &       True \\
#                     PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'primclass', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0067*** &  0.0108*** &  0.0116*** &  0.0083*** \\
#                    &   (0.0009) &   (0.0007) &   (0.0005) &   (0.0005) \\
#                $N$ &     170882 &     252174 &     401623 &     529686 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'primclass', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0073*** &  0.0111*** &  0.0109*** &  0.0079*** \\
#                    &   (0.0009) &   (0.0007) &   (0.0005) &   (0.0004) \\
#                $N$ &     170882 &     252174 &     401623 &     529686 \\
#     Adjusted $R^2$ &       0.07 &       0.07 &       0.08 &       0.07 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'primclass', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0104*** &  0.0126*** &  0.0177*** &  0.0154*** \\
#                    &   (0.0015) &   (0.0012) &   (0.0010) &   (0.0008) \\
#                $N$ &     171099 &     252478 &     402006 &     530245 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'ldavecs', 'primclass', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0139*** &  0.0158*** &  0.0153*** &  0.0106*** \\
#                    &   (0.0014) &   (0.0011) &   (0.0009) &   (0.0007) \\
#                $N$ &     171099 &     252478 &     402006 &     530245 \\
#     Adjusted $R^2$ &       0.18 &       0.18 &       0.20 &       0.20 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'primclass', 'No FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0037*** &  0.0054*** &  0.0047*** &  0.0041*** \\
#                    &   (0.0003) &   (0.0003) &   (0.0002) &   (0.0002) \\
#                $N$ &     167005 &     245355 &     352428 &     514322 \\
#     Adjusted $R^2$ &       0.00 &       0.00 &       0.00 &       0.00 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &      False &      False &      False &      False \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'tp_pct_common_cited', 'primclass', 'PC FE')
#
#
# \begin{tabular}{lccc}
# \toprule
#                    &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#  $I(MSA \, Match)$ &  0.0038*** &  0.0056*** &  0.0049*** &  0.0044*** \\
#                    &   (0.0003) &   (0.0003) &   (0.0002) &   (0.0002) \\
#                $N$ &     167005 &     245355 &     352428 &     514322 \\
#     Adjusted $R^2$ &       0.01 &       0.01 &       0.01 &       0.01 \\
#            Year FE &       True &       True &       True &       True \\
#              PC FE &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### 2. Results with Field Sim

# %%
repl1 = pickle.load(open("DataStore/2018-07-P3/reg_names_dict.pkl", "rb"))
dms = ["docvecs", "ldavecs", "tp_pct_common_cited"]
dms = ["docvecs"]
# repl2 = {k: "\multicolumn{2}{c}{"+v+"}" if len(v)>1 else v for k,v in repl1.items() }
            
# Add names for standard errors
ygs = ["index", "1975-85", "1985-95", "1995-05", "2005-15"]
rr2 = rr.copy()
se_index = rr2[ygs+["index"]].loc[rr2["index"].isnull()].index
above_var = rr2.loc[se_index-1, "index"].tolist()
rr2.loc[se_index, "index"] = ["(s.e.) "+v for v in above_var]

# %% [markdown]
# #### 2.1 Results by year

# %%
# Index by each table: Norm/Raw, KS, Sample
tab_ind = {}
for samp in ["naics_name", "primclass"]:
    mods_all = ["All FE-Sim PC", "All FE-Sim PC MSA", "All FE-Int PC", "All FE-Int PC MSA",
               "All FE-Sim PC MSA-Cb", "All FE-Int PC MSA-Add Cb", "All FE-Int PC MSA-Int Cb",
                "Inv FE-Sim PC MSA", "Inv FE-Int PC MSA",
               "Inv FE-Sim PC MSA-Cb", "Inv FE-Int PC MSA-Add Cb", "Inv FE-Int PC MSA-Int Cb",
               "Inv FE-Break Int PC MSA"]
    if samp == "naics_name":
        mods = mods_all[:7]
    else:
        mods = mods_all[7:]
    for dm in dms:
        for mod in mods:
            tab_ind[("raw", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"][mod])
            tab_ind[("norm", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"]["N "+mod])

tab_ind_yr = tab_ind

# %%
tab_no_c = {}
tab_c = {}
no_c_ind = ["C(common_est_inv)[T.1.0]", "C(common_pat_inv)[T.True]", "C(lawyer_match)[T.True]"]
no_c_ind = no_c_ind+["(s.e.) "+c for c in no_c_ind]

for k in tab_ind_yr.keys():
    
    i = str(tab_ind_yr[k])
    
    mod = rr2.loc[(rr2["id"] == i), ["Model", "Model Num", "samp"]]\
.drop_duplicates().values[0]

    tab = rr2.loc[(rr2["id"] == i), ygs].fillna("").set_index("index")

    # Add other columns
    tab.loc["Year FE"] = [True]*len(tab.columns)
    tab.loc["PC FE"] = [True]*len(tab.columns)

    if ("All FE" in k[3]) or ("Inv FE" in k[3]):
        tab.loc["Inv & Lawyer Match"] = [True]*len(tab.columns)
    else:
        tab.loc["Inv & Lawyer Match"] = [False]*len(tab.columns)

    # Create gaps
    tab = tab.fillna("").reset_index()

    #1. Create table without controls
    tab2 = tab.copy()
    tab2 = tab2.loc[~(tab2["index"].isin(no_c_ind))].reset_index(drop=True)
    # Get rid of se labels
    tab2.loc[tab2["index"].apply(lambda x: "(s.e.)" in x), "index"] = ""
    tab2 = tab2.rename(columns={"index":""})
    tab2 = tab2.replace(repl1).copy()

    tab_no_c[k] = tab2

    #2. Original tables with controls
    # Get rid of se labels
    tab.loc[tab["index"].apply(lambda x: "(s.e.)" in x), "index"] = ""
    tab = tab.rename(columns={"index":""})

    # Pandas tables
    tab = tab.replace(repl1).copy()
    tab_c[k] = tab
tab_c_yr = tab_c
tab_no_c_yr = tab_no_c

# %%
for k,v in tab_no_c_yr.items():
    if (k[0]=='norm') & (k[1]=='docvecs'):
        print(k)
        display(v)
# Out:
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC')
#                                   1975-85    1985-95    1995-05    2005-15
# 0            $I(MSA \, Match)$     0.0170  0.0390***  0.0300***  0.0274***
# 1                                (0.0120)   (0.0070)   (0.0048)   (0.0038)
# 2        $I(Primclass\,Match)$     0.0133   0.0274**  0.0236***   0.0140**
# 3                                (0.0221)   (0.0128)   (0.0088)   (0.0069)
# 4   $sim_{DV}(pc_{i}, pc_{j})$  0.2805***  0.2913***  0.2816***  0.2932***
# 5                                (0.0090)   (0.0055)   (0.0040)   (0.0036)
# 6                          $N$      40323     110982     215861     344313
# 7               Adjusted $R^2$       0.12       0.13       0.13       0.08
# 8                      Year FE       True       True       True       True
# 9                        PC FE       True       True       True       True
# 10          Inv & Lawyer Match       True       True       True       True
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA')
#                                               1975-85    1985-95    1995-05  \
# 0                        $I(MSA \, Match)$     0.0109  0.0353***  0.0187***
# 1                                            (0.0121)   (0.0071)   (0.0048)
# 2                    $I(Primclass\,Match)$  0.2881***  0.3074***  0.2630***
# 3                                            (0.0191)   (0.0110)   (0.0074)
# 4   $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.1259***  0.1259***  0.1643***
# 5                                            (0.0070)   (0.0041)   (0.0035)
# 6                                      $N$      40323     110982     215861
# 7                           Adjusted $R^2$       0.11       0.11       0.12
# 8                                  Year FE       True       True       True
# 9                                    PC FE       True       True       True
# 10                      Inv & Lawyer Match       True       True       True
#
#       2005-15
# 0   0.0170***
# 1    (0.0038)
# 2   0.2373***
# 3    (0.0058)
# 4   0.1830***
# 5    (0.0031)
# 6      344313
# 7        0.08
# 8        True
# 9        True
# 10       True
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC')
#                                             1975-85    1985-95    1995-05  \
# 0                      $I(MSA \, Match)$     0.0178  0.0415***  0.0277***
# 1                                          (0.0120)   (0.0069)   (0.0048)
# 2   $I_{MSA} * sim_{DV}(pc_{i}, pc_{j})$    -0.0012    -0.0045     0.0050
# 3                                          (0.0116)   (0.0067)   (0.0047)
# 4                  $I(Primclass\,Match)$     0.0133   0.0277**  0.0232***
# 5                                          (0.0221)   (0.0128)   (0.0088)
# 6             $sim_{DV}(pc_{i}, pc_{j})$  0.2808***  0.2925***  0.2804***
# 7                                          (0.0095)   (0.0057)   (0.0042)
# 8                                    $N$      40323     110982     215861
# 9                         Adjusted $R^2$       0.12       0.13       0.13
# 10                               Year FE       True       True       True
# 11                                 PC FE       True       True       True
# 12                    Inv & Lawyer Match       True       True       True
#
#       2005-15
# 0   0.0222***
# 1    (0.0043)
# 2     0.0085*
# 3    (0.0045)
# 4     0.0135*
# 5    (0.0069)
# 6   0.2908***
# 7    (0.0039)
# 8      344313
# 9        0.08
# 10       True
# 11       True
# 12       True
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA')
#                                                         1975-85    1985-95  \
# 0                                  $I(MSA \, Match)$     0.0114  0.0357***
# 1                                                      (0.0124)   (0.0073)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$     0.0064     0.0040
# 3                                                      (0.0136)   (0.0079)
# 4                              $I(Primclass\,Match)$  0.2871***  0.3068***
# 5                                                      (0.0191)   (0.0110)
# 6             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.1245***  0.1250***
# 7                                                      (0.0076)   (0.0045)
# 8                                                $N$      40323     110982
# 9                                     Adjusted $R^2$       0.11       0.11
# 10                                           Year FE       True       True
# 11                                             PC FE       True       True
# 12                                Inv & Lawyer Match       True       True
#
#       1995-05    2005-15
# 0   0.0202***  0.0194***
# 1    (0.0051)   (0.0039)
# 2     0.0103*  0.0261***
# 3    (0.0061)   (0.0057)
# 4   0.2618***  0.2345***
# 5    (0.0075)   (0.0058)
# 6   0.1618***  0.1764***
# 7    (0.0038)   (0.0034)
# 8      215861     344313
# 9        0.12       0.08
# 10       True       True
# 11       True       True
# 12       True       True
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA-Cb')
#                                                  1975-85     1985-95  \
# 0                          $I(MSA \, Match)$      0.0091   0.0324***
# 1                                               (0.0121)    (0.0070)
# 2                      $I(Primclass\,Match)$   0.2670***   0.2899***
# 3                                               (0.0192)    (0.0111)
# 4     $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$   0.1831***   0.1743***
# 5                                               (0.0095)    (0.0054)
# 6   $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0111***  -0.0094***
# 7                                               (0.0015)    (0.0008)
# 8                                        $N$       40323      110982
# 9                             Adjusted $R^2$        0.11        0.11
# 10                                   Year FE        True        True
# 11                                     PC FE        True        True
# 12                        Inv & Lawyer Match        True        True
#
#        1995-05     2005-15
# 0    0.0153***   0.0141***
# 1     (0.0048)    (0.0038)
# 2    0.2416***   0.2152***
# 3     (0.0076)    (0.0059)
# 4    0.2189***   0.2338***
# 5     (0.0045)    (0.0039)
# 6   -0.0123***  -0.0120***
# 7     (0.0007)    (0.0007)
# 8       215861      344313
# 9         0.12        0.08
# 10        True        True
# 11        True        True
# 12        True        True
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA-Add Cb')
#                                                          1975-85     1985-95  \
# 0                                  $I(MSA \, Match)$      0.0094   0.0328***
# 1                                                       (0.0124)    (0.0072)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$      0.0031      0.0042
# 3                                                       (0.0136)    (0.0078)
# 4                              $I(Primclass\,Match)$   0.2666***   0.2893***
# 5                                                       (0.0193)    (0.0111)
# 6             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$   0.1825***   0.1733***
# 7                                                       (0.0100)    (0.0058)
# 8           $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0111***  -0.0094***
# 9                                                       (0.0015)    (0.0008)
# 10                                               $N$       40323      110982
# 11                                    Adjusted $R^2$        0.11        0.11
# 12                                           Year FE        True        True
# 13                                             PC FE        True        True
# 14                                Inv & Lawyer Match        True        True
#
#        1995-05     2005-15
# 0    0.0168***   0.0167***
# 1     (0.0051)    (0.0039)
# 2      0.0104*   0.0275***
# 3     (0.0061)    (0.0057)
# 4    0.2403***   0.2122***
# 5     (0.0076)    (0.0059)
# 6    0.2164***   0.2271***
# 7     (0.0047)    (0.0042)
# 8   -0.0123***  -0.0120***
# 9     (0.0007)    (0.0007)
# 10      215861      344313
# 11        0.12        0.08
# 12        True        True
# 13        True        True
# 14        True        True
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA-Int Cb')
#                                                           1975-85     1985-95  \
# 0                                   $I(MSA \, Match)$      0.0100   0.0343***
# 1                                                        (0.0126)    (0.0074)
# 2    $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$      0.0077      0.0145
# 3                                                        (0.0188)    (0.0103)
# 4   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j}...     -0.0011     -0.0024
# 5                                                        (0.0037)    (0.0017)
# 6                               $I(Primclass\,Match)$   0.2667***   0.2895***
# 7                                                        (0.0193)    (0.0111)
# 8              $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$   0.1815***   0.1705***
# 9                                                        (0.0103)    (0.0060)
# 10           $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0109***  -0.0088***
# 11                                                       (0.0016)    (0.0009)
# 12                                                $N$       40323      110982
# 13                                     Adjusted $R^2$        0.11        0.11
# 14                                            Year FE        True        True
# 15                                              PC FE        True        True
# 16                                 Inv & Lawyer Match        True        True
#
#        1995-05     2005-15
# 0    0.0179***   0.0155***
# 1     (0.0052)    (0.0040)
# 2     0.0164**   0.0196***
# 3     (0.0077)    (0.0070)
# 4      -0.0017      0.0023
# 5     (0.0015)    (0.0015)
# 6    0.2403***   0.2122***
# 7     (0.0076)    (0.0059)
# 8    0.2148***   0.2292***
# 9     (0.0049)    (0.0044)
# 10  -0.0119***  -0.0127***
# 11    (0.0008)    (0.0008)
# 12      215861      344313
# 13        0.12        0.08
# 14        True        True
# 15        True        True
# 16        True        True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA')
#                                              1975-85    1985-95    1995-05  \
# 0                       $I(MSA \, Match)$     0.0100  0.0248***  0.0316***
# 1                                           (0.0143)   (0.0081)   (0.0054)
# 2  $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.0654***  0.0652***  0.0826***
# 3                                           (0.0075)   (0.0045)   (0.0038)
# 4                                     $N$      38324     106152     205248
# 5                          Adjusted $R^2$       0.08       0.08       0.09
# 6                                 Year FE       True       True       True
# 7                                   PC FE       True       True       True
# 8                      Inv & Lawyer Match       True       True       True
#
#      2005-15
# 0  0.0157***
# 1   (0.0041)
# 2  0.0935***
# 3   (0.0035)
# 4     324142
# 5       0.06
# 6       True
# 7       True
# 8       True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA')
#                                                         1975-85    1985-95  \
# 0                                  $I(MSA \, Match)$    -0.0047  0.0353***
# 1                                                      (0.0213)   (0.0112)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$     0.0145    -0.0116
# 3                                                      (0.0175)   (0.0099)
# 4             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.0632***  0.0671***
# 5                                                      (0.0079)   (0.0048)
# 6                                                $N$      38324     106152
# 7                                     Adjusted $R^2$       0.08       0.08
# 8                                            Year FE       True       True
# 9                                              PC FE       True       True
# 10                                Inv & Lawyer Match       True       True
#
#       1995-05    2005-15
# 0   0.0413***  0.0216***
# 1    (0.0075)   (0.0058)
# 2     -0.0123    -0.0087
# 3    (0.0077)   (0.0068)
# 4   0.0849***  0.0953***
# 5    (0.0041)   (0.0038)
# 6      205248     324142
# 7        0.09       0.06
# 8        True       True
# 9        True       True
# 10       True       True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA-Cb')
#                                                 1975-85     1985-95  \
# 0                          $I(MSA \, Match)$     0.0065   0.0214***
# 1                                              (0.0144)    (0.0082)
# 2     $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.0863***   0.0828***
# 3                                              (0.0103)    (0.0062)
# 4   $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0031**  -0.0026***
# 5                                              (0.0012)    (0.0007)
# 6                                        $N$      38324      106152
# 7                             Adjusted $R^2$       0.08        0.08
# 8                                    Year FE       True        True
# 9                                      PC FE       True        True
# 10                        Inv & Lawyer Match       True        True
#
#        1995-05     2005-15
# 0    0.0278***   0.0126***
# 1     (0.0054)    (0.0041)
# 2    0.1037***   0.1135***
# 3     (0.0050)    (0.0046)
# 4   -0.0034***  -0.0033***
# 5     (0.0006)    (0.0005)
# 6       205248      324142
# 7         0.09        0.06
# 8         True        True
# 9         True        True
# 10        True        True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA-Add Cb')
#                                                          1975-85     1985-95  \
# 0                                  $I(MSA \, Match)$     -0.0210    0.0248**
# 1                                                       (0.0218)    (0.0115)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$      0.0267     -0.0037
# 3                                                       (0.0179)    (0.0101)
# 4             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$   0.0850***   0.0831***
# 5                                                       (0.0104)    (0.0062)
# 6           $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0035***  -0.0026***
# 7                                                       (0.0012)    (0.0007)
# 8                                                $N$       38324      106152
# 9                                     Adjusted $R^2$        0.08        0.08
# 10                                           Year FE        True        True
# 11                                             PC FE        True        True
# 12                                Inv & Lawyer Match        True        True
#
#        1995-05     2005-15
# 0    0.0298***    0.0128**
# 1     (0.0078)    (0.0060)
# 2      -0.0024     -0.0003
# 3     (0.0080)    (0.0070)
# 4    0.1039***   0.1135***
# 5     (0.0051)    (0.0046)
# 6   -0.0034***  -0.0033***
# 7     (0.0006)    (0.0006)
# 8       205248      324142
# 9         0.09        0.06
# 10        True        True
# 11        True        True
# 12        True        True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA-Int Cb')
#                                                          1975-85     1985-95  \
# 0                                   $I(MSA \, Match)$    -0.0296    0.0305**
# 1                                                       (0.0241)    (0.0123)
# 2    $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$     0.0412     -0.0146
# 3                                                       (0.0266)    (0.0144)
# 4   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j}...    -0.0018      0.0015
# 5                                                       (0.0028)    (0.0016)
# 6              $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.0826***   0.0851***
# 7                                                       (0.0108)    (0.0065)
# 8            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$  -0.0030**  -0.0030***
# 9                                                       (0.0014)    (0.0009)
# 10                                                $N$      38324      106152
# 11                                     Adjusted $R^2$       0.08        0.08
# 12                                            Year FE       True        True
# 13                                              PC FE       True        True
# 14                                 Inv & Lawyer Match       True        True
#
#        1995-05     2005-15
# 0    0.0276***      0.0097
# 1     (0.0083)    (0.0065)
# 2       0.0021      0.0064
# 3     (0.0106)    (0.0092)
# 4      -0.0007     -0.0010
# 5     (0.0012)    (0.0011)
# 6    0.1030***   0.1121***
# 7     (0.0053)    (0.0049)
# 8   -0.0032***  -0.0029***
# 9     (0.0008)    (0.0007)
# 10      205248      324142
# 11        0.09        0.06
# 12        True        True
# 13        True        True
# 14        True        True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Break Int PC MSA')
#                                                          1975-85    1985-95  \
# 0                                   $I(MSA \, Match)$    -0.0085  0.0390***
# 1                                                       (0.0235)   (0.0128)
# 2   $I_{MSA} * I(sim_{DV,pc,MSA}>0)*sim_{DV}(pc_{i...     0.0142    -0.0167
# 3                                                       (0.0196)   (0.0114)
# 4   $I_{MSA} * I(sim_{DV,pc,MSA} \leq 0)*sim_{DV}(...   -0.1366*    -0.0299
# 5                                                       (0.0791)   (0.0470)
# 6   $I(sim_{DV,pc,MSA}>0)*sim_{DV}(pc_{i,MSA_i}, p...  0.0764***  0.0769***
# 7                                                       (0.0109)   (0.0067)
# 8   $I(sim_{DV,pc,MSA} \leq 0)*sim_{DV}(pc_{i,MSA_...    0.0301*  0.0446***
# 9                                                       (0.0183)   (0.0105)
# 10                                                $N$      38324     106152
# 11                                     Adjusted $R^2$       0.08       0.08
# 12                                            Year FE       True       True
# 13                                              PC FE       True       True
# 14                                 Inv & Lawyer Match       True       True
#
#        1995-05     2005-15
# 0    0.0524***   0.0295***
# 1     (0.0085)    (0.0063)
# 2   -0.0267***  -0.0212***
# 3     (0.0089)    (0.0075)
# 4       0.0202      0.0118
# 5     (0.0422)    (0.0406)
# 6    0.1042***   0.1148***
# 7     (0.0057)    (0.0051)
# 8    0.0402***   0.0456***
# 9     (0.0088)    (0.0084)
# 10      205248      324142
# 11        0.09        0.06
# 12        True        True
# 13        True        True
# 14        True        True

# %%
for k,v in tab_no_c_yr.items():
    if (k[0]=='norm') & (k[1]=='docvecs'):
        print("\n"+str(k)+"\n"+"\n")
        ncols = len(v.columns)
        with pd.option_context("max_colwidth", 1000):
            print(v.to_latex(index=False,escape=False, column_format="lcccc"))
# Out:
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                             &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#           $I(MSA \, Match)$ &     0.0170 &  0.0390*** &  0.0300*** &  0.0274*** \\
#                             &   (0.0120) &   (0.0070) &   (0.0048) &   (0.0038) \\
#       $I(Primclass\,Match)$ &     0.0133 &   0.0274** &  0.0236*** &   0.0140** \\
#                             &   (0.0221) &   (0.0128) &   (0.0088) &   (0.0069) \\
#  $sim_{DV}(pc_{i}, pc_{j})$ &  0.2805*** &  0.2913*** &  0.2816*** &  0.2932*** \\
#                             &   (0.0090) &   (0.0055) &   (0.0040) &   (0.0036) \\
#                         $N$ &      40323 &     110982 &     215861 &     344313 \\
#              Adjusted $R^2$ &       0.12 &       0.13 &       0.13 &       0.08 \\
#                     Year FE &       True &       True &       True &       True \\
#                       PC FE &       True &       True &       True &       True \\
#          Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                       $I(MSA \, Match)$ &     0.0109 &  0.0353*** &  0.0187*** &  0.0170*** \\
#                                         &   (0.0121) &   (0.0071) &   (0.0048) &   (0.0038) \\
#                   $I(Primclass\,Match)$ &  0.2881*** &  0.3074*** &  0.2630*** &  0.2373*** \\
#                                         &   (0.0191) &   (0.0110) &   (0.0074) &   (0.0058) \\
#  $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.1259*** &  0.1259*** &  0.1643*** &  0.1830*** \\
#                                         &   (0.0070) &   (0.0041) &   (0.0035) &   (0.0031) \\
#                                     $N$ &      40323 &     110982 &     215861 &     344313 \\
#                          Adjusted $R^2$ &       0.11 &       0.11 &       0.12 &       0.08 \\
#                                 Year FE &       True &       True &       True &       True \\
#                                   PC FE &       True &       True &       True &       True \\
#                      Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                       &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                     $I(MSA \, Match)$ &     0.0178 &  0.0415*** &  0.0277*** &  0.0222*** \\
#                                       &   (0.0120) &   (0.0069) &   (0.0048) &   (0.0043) \\
#  $I_{MSA} * sim_{DV}(pc_{i}, pc_{j})$ &    -0.0012 &    -0.0045 &     0.0050 &    0.0085* \\
#                                       &   (0.0116) &   (0.0067) &   (0.0047) &   (0.0045) \\
#                 $I(Primclass\,Match)$ &     0.0133 &   0.0277** &  0.0232*** &    0.0135* \\
#                                       &   (0.0221) &   (0.0128) &   (0.0088) &   (0.0069) \\
#            $sim_{DV}(pc_{i}, pc_{j})$ &  0.2808*** &  0.2925*** &  0.2804*** &  0.2908*** \\
#                                       &   (0.0095) &   (0.0057) &   (0.0042) &   (0.0039) \\
#                                   $N$ &      40323 &     110982 &     215861 &     344313 \\
#                        Adjusted $R^2$ &       0.12 &       0.13 &       0.13 &       0.08 \\
#                               Year FE &       True &       True &       True &       True \\
#                                 PC FE &       True &       True &       True &       True \\
#                    Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                   &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     0.0114 &  0.0357*** &  0.0202*** &  0.0194*** \\
#                                                   &   (0.0124) &   (0.0073) &   (0.0051) &   (0.0039) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &     0.0064 &     0.0040 &    0.0103* &  0.0261*** \\
#                                                   &   (0.0136) &   (0.0079) &   (0.0061) &   (0.0057) \\
#                             $I(Primclass\,Match)$ &  0.2871*** &  0.3068*** &  0.2618*** &  0.2345*** \\
#                                                   &   (0.0191) &   (0.0110) &   (0.0075) &   (0.0058) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.1245*** &  0.1250*** &  0.1618*** &  0.1764*** \\
#                                                   &   (0.0076) &   (0.0045) &   (0.0038) &   (0.0034) \\
#                                               $N$ &      40323 &     110982 &     215861 &     344313 \\
#                                    Adjusted $R^2$ &       0.11 &       0.11 &       0.12 &       0.08 \\
#                                           Year FE &       True &       True &       True &       True \\
#                                             PC FE &       True &       True &       True &       True \\
#                                Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA-Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                           &     1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                         $I(MSA \, Match)$ &      0.0091 &   0.0324*** &   0.0153*** &   0.0141*** \\
#                                           &    (0.0121) &    (0.0070) &    (0.0048) &    (0.0038) \\
#                     $I(Primclass\,Match)$ &   0.2670*** &   0.2899*** &   0.2416*** &   0.2152*** \\
#                                           &    (0.0192) &    (0.0111) &    (0.0076) &    (0.0059) \\
#    $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &   0.1831*** &   0.1743*** &   0.2189*** &   0.2338*** \\
#                                           &    (0.0095) &    (0.0054) &    (0.0045) &    (0.0039) \\
#  $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0111*** &  -0.0094*** &  -0.0123*** &  -0.0120*** \\
#                                           &    (0.0015) &    (0.0008) &    (0.0007) &    (0.0007) \\
#                                       $N$ &       40323 &      110982 &      215861 &      344313 \\
#                            Adjusted $R^2$ &        0.11 &        0.11 &        0.12 &        0.08 \\
#                                   Year FE &        True &        True &        True &        True \\
#                                     PC FE &        True &        True &        True &        True \\
#                        Inv & Lawyer Match &        True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA-Add Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                   &     1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &      0.0094 &   0.0328*** &   0.0168*** &   0.0167*** \\
#                                                   &    (0.0124) &    (0.0072) &    (0.0051) &    (0.0039) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &      0.0031 &      0.0042 &     0.0104* &   0.0275*** \\
#                                                   &    (0.0136) &    (0.0078) &    (0.0061) &    (0.0057) \\
#                             $I(Primclass\,Match)$ &   0.2666*** &   0.2893*** &   0.2403*** &   0.2122*** \\
#                                                   &    (0.0193) &    (0.0111) &    (0.0076) &    (0.0059) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &   0.1825*** &   0.1733*** &   0.2164*** &   0.2271*** \\
#                                                   &    (0.0100) &    (0.0058) &    (0.0047) &    (0.0042) \\
#          $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0111*** &  -0.0094*** &  -0.0123*** &  -0.0120*** \\
#                                                   &    (0.0015) &    (0.0008) &    (0.0007) &    (0.0007) \\
#                                               $N$ &       40323 &      110982 &      215861 &      344313 \\
#                                    Adjusted $R^2$ &        0.11 &        0.11 &        0.12 &        0.08 \\
#                                           Year FE &        True &        True &        True &        True \\
#                                             PC FE &        True &        True &        True &        True \\
#                                Inv & Lawyer Match &        True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Int PC MSA-Int Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                     &     1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                                   $I(MSA \, Match)$ &      0.0100 &   0.0343*** &   0.0179*** &   0.0155*** \\
#                                                     &    (0.0126) &    (0.0074) &    (0.0052) &    (0.0040) \\
#    $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &      0.0077 &      0.0145 &    0.0164** &   0.0196*** \\
#                                                     &    (0.0188) &    (0.0103) &    (0.0077) &    (0.0070) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &     -0.0011 &     -0.0024 &     -0.0017 &      0.0023 \\
#                                                     &    (0.0037) &    (0.0017) &    (0.0015) &    (0.0015) \\
#                               $I(Primclass\,Match)$ &   0.2667*** &   0.2895*** &   0.2403*** &   0.2122*** \\
#                                                     &    (0.0193) &    (0.0111) &    (0.0076) &    (0.0059) \\
#              $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &   0.1815*** &   0.1705*** &   0.2148*** &   0.2292*** \\
#                                                     &    (0.0103) &    (0.0060) &    (0.0049) &    (0.0044) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0109*** &  -0.0088*** &  -0.0119*** &  -0.0127*** \\
#                                                     &    (0.0016) &    (0.0009) &    (0.0008) &    (0.0008) \\
#                                                 $N$ &       40323 &      110982 &      215861 &      344313 \\
#                                      Adjusted $R^2$ &        0.11 &        0.11 &        0.12 &        0.08 \\
#                                             Year FE &        True &        True &        True &        True \\
#                                               PC FE &        True &        True &        True &        True \\
#                                  Inv & Lawyer Match &        True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                         &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                       $I(MSA \, Match)$ &     0.0100 &  0.0248*** &  0.0316*** &  0.0157*** \\
#                                         &   (0.0143) &   (0.0081) &   (0.0054) &   (0.0041) \\
#  $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0654*** &  0.0652*** &  0.0826*** &  0.0935*** \\
#                                         &   (0.0075) &   (0.0045) &   (0.0038) &   (0.0035) \\
#                                     $N$ &      38324 &     106152 &     205248 &     324142 \\
#                          Adjusted $R^2$ &       0.08 &       0.08 &       0.09 &       0.06 \\
#                                 Year FE &       True &       True &       True &       True \\
#                                   PC FE &       True &       True &       True &       True \\
#                      Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                   &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &    -0.0047 &  0.0353*** &  0.0413*** &  0.0216*** \\
#                                                   &   (0.0213) &   (0.0112) &   (0.0075) &   (0.0058) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &     0.0145 &    -0.0116 &    -0.0123 &    -0.0087 \\
#                                                   &   (0.0175) &   (0.0099) &   (0.0077) &   (0.0068) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0632*** &  0.0671*** &  0.0849*** &  0.0953*** \\
#                                                   &   (0.0079) &   (0.0048) &   (0.0041) &   (0.0038) \\
#                                               $N$ &      38324 &     106152 &     205248 &     324142 \\
#                                    Adjusted $R^2$ &       0.08 &       0.08 &       0.09 &       0.06 \\
#                                           Year FE &       True &       True &       True &       True \\
#                                             PC FE &       True &       True &       True &       True \\
#                                Inv & Lawyer Match &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA-Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                           &    1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                         $I(MSA \, Match)$ &     0.0065 &   0.0214*** &   0.0278*** &   0.0126*** \\
#                                           &   (0.0144) &    (0.0082) &    (0.0054) &    (0.0041) \\
#    $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0863*** &   0.0828*** &   0.1037*** &   0.1135*** \\
#                                           &   (0.0103) &    (0.0062) &    (0.0050) &    (0.0046) \\
#  $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0031** &  -0.0026*** &  -0.0034*** &  -0.0033*** \\
#                                           &   (0.0012) &    (0.0007) &    (0.0006) &    (0.0005) \\
#                                       $N$ &      38324 &      106152 &      205248 &      324142 \\
#                            Adjusted $R^2$ &       0.08 &        0.08 &        0.09 &        0.06 \\
#                                   Year FE &       True &        True &        True &        True \\
#                                     PC FE &       True &        True &        True &        True \\
#                        Inv & Lawyer Match &       True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA-Add Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                   &     1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     -0.0210 &    0.0248** &   0.0298*** &    0.0128** \\
#                                                   &    (0.0218) &    (0.0115) &    (0.0078) &    (0.0060) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &      0.0267 &     -0.0037 &     -0.0024 &     -0.0003 \\
#                                                   &    (0.0179) &    (0.0101) &    (0.0080) &    (0.0070) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &   0.0850*** &   0.0831*** &   0.1039*** &   0.1135*** \\
#                                                   &    (0.0104) &    (0.0062) &    (0.0051) &    (0.0046) \\
#          $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0035*** &  -0.0026*** &  -0.0034*** &  -0.0033*** \\
#                                                   &    (0.0012) &    (0.0007) &    (0.0006) &    (0.0006) \\
#                                               $N$ &       38324 &      106152 &      205248 &      324142 \\
#                                    Adjusted $R^2$ &        0.08 &        0.08 &        0.09 &        0.06 \\
#                                           Year FE &        True &        True &        True &        True \\
#                                             PC FE &        True &        True &        True &        True \\
#                                Inv & Lawyer Match &        True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Int PC MSA-Int Cb')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                     &    1975-85 &     1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                                   $I(MSA \, Match)$ &    -0.0296 &    0.0305** &   0.0276*** &      0.0097 \\
#                                                     &   (0.0241) &    (0.0123) &    (0.0083) &    (0.0065) \\
#    $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &     0.0412 &     -0.0146 &      0.0021 &      0.0064 \\
#                                                     &   (0.0266) &    (0.0144) &    (0.0106) &    (0.0092) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &    -0.0018 &      0.0015 &     -0.0007 &     -0.0010 \\
#                                                     &   (0.0028) &    (0.0016) &    (0.0012) &    (0.0011) \\
#              $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0826*** &   0.0851*** &   0.1030*** &   0.1121*** \\
#                                                     &   (0.0108) &    (0.0065) &    (0.0053) &    (0.0049) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})^3$ &  -0.0030** &  -0.0030*** &  -0.0032*** &  -0.0029*** \\
#                                                     &   (0.0014) &    (0.0009) &    (0.0008) &    (0.0007) \\
#                                                 $N$ &      38324 &      106152 &      205248 &      324142 \\
#                                      Adjusted $R^2$ &       0.08 &        0.08 &        0.09 &        0.06 \\
#                                             Year FE &       True &        True &        True &        True \\
#                                               PC FE &       True &        True &        True &        True \\
#                                  Inv & Lawyer Match &       True &        True &        True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Break Int PC MSA')
#
#
# \begin{tabular}{lcccc}
# \toprule
#                                                                             &    1975-85 &    1985-95 &     1995-05 &     2005-15 \\
# \midrule
#                                                           $I(MSA \, Match)$ &    -0.0085 &  0.0390*** &   0.0524*** &   0.0295*** \\
#                                                                             &   (0.0235) &   (0.0128) &    (0.0085) &    (0.0063) \\
#       $I_{MSA} * I(sim_{DV,pc,MSA}>0)*sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &     0.0142 &    -0.0167 &  -0.0267*** &  -0.0212*** \\
#                                                                             &   (0.0196) &   (0.0114) &    (0.0089) &    (0.0075) \\
#  $I_{MSA} * I(sim_{DV,pc,MSA} \leq 0)*sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &   -0.1366* &    -0.0299 &      0.0202 &      0.0118 \\
#                                                                             &   (0.0791) &   (0.0470) &    (0.0422) &    (0.0406) \\
#                 $I(sim_{DV,pc,MSA}>0)*sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0764*** &  0.0769*** &   0.1042*** &   0.1148*** \\
#                                                                             &   (0.0109) &   (0.0067) &    (0.0057) &    (0.0051) \\
#            $I(sim_{DV,pc,MSA} \leq 0)*sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &    0.0301* &  0.0446*** &   0.0402*** &   0.0456*** \\
#                                                                             &   (0.0183) &   (0.0105) &    (0.0088) &    (0.0084) \\
#                                                                         $N$ &      38324 &     106152 &      205248 &      324142 \\
#                                                              Adjusted $R^2$ &       0.08 &       0.08 &        0.09 &        0.06 \\
#                                                                     Year FE &       True &       True &        True &        True \\
#                                                                       PC FE &       True &       True &        True &        True \\
#                                                          Inv & Lawyer Match &       True &       True &        True &        True \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### 2.2 Collected results

# %%
# Index by each table: Norm/Raw, KS, Sample
tab_ind = {}
for samp in ["naics_name", "primclass"]:
    mods_all = ["All FE-Sim PC", "All FE-Int PC", "All FE-Sim PC MSA", "All FE-Int PC MSA",
               "Inv FE-Sim PC MSA", "Inv FE-Int PC MSA"]
    if samp == "naics_name":
        mods = mods_all[:4]
    else:
        mods = mods_all[4:]
    mods_n = dict(zip(mods_all, range(1,len(mods_all)+1)))
#     for dm in ["docvecs", "ldavecs", "tp_pct_common_cited"]:
    for dm in dms:
        for mod in mods:
            tab_ind[("raw", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"][mod])
            tab_ind[("norm", dm, samp, mod)] = ((dm, samp), regs["model_names_eqn"]["N "+mod])

tab_ind_collected = tab_ind

# %%
tab_no_c = {}
no_c_ind = ["C(common_est_inv)[T.1.0]", "C(common_pat_inv)[T.True]", "C(lawyer_match)[T.True]",
            "C(primclass_match)[T.True]"]
no_c_ind = no_c_ind+["(s.e.) "+c for c in no_c_ind]

for k in tab_ind_collected.keys():
    
    i = str(tab_ind_collected[k])
    
    mod = rr2.loc[(rr2["id"] == i), ["Model", "Model Num", "samp"]]\
.drop_duplicates().values[0]

    tab = rr2.loc[(rr2["id"] == i), ygs].fillna("").set_index("index")

    # Add other columns
    tab.loc["Year FE"] = [True]*len(tab.columns)
    tab.loc["PC FE"] = [True]*len(tab.columns)

    if ("All FE" in k[3]) or ("Inv FE" in k[3]):
        tab.loc["Inv \& Lawyer Match"] = [True]*len(tab.columns)
    else:
        tab.loc["Inv \& Lawyer Match"] = [False]*len(tab.columns)

    # Create gaps
    tab = tab.fillna("").reset_index()

    #1. Create table without controls
    tab2 = tab.copy()
    tab2 = tab2.loc[~(tab2["index"].isin(no_c_ind))]
    # Set back index
    tab2 = tab2.set_index("index")
    
#     #
#     # Get rid of se labels
#     tab2.loc[tab2["index"].apply(lambda x: "(s.e.)" in x), "index"] = ""
#     tab2 = tab2.rename(columns={"index":""})
#     tab2 = tab2.replace(repl1).copy()

    tab_no_c[k] = tab2


tab_collected = tab_no_c

# %%
tab_col = {}
tab_col["norm"] = {}
tab_col["raw"] = {}

# %%
keys = {}
keys["norm"] = [i for i in list(tab_collected.keys()) if "norm" in i]
keys["raw"] = [i for i in list(tab_collected.keys()) if "raw" in i]
for m in keys.keys():
    for i,k in enumerate(keys[m]):
        # If group matches m, and is even
        if (m in k) & (i % 2) == 0:
            # Existing index order
            ind1 = tab_collected[keys[m][i+1]].index

            # First table
            a = tab_collected[keys[m][i]].copy()
            a.columns = pd.MultiIndex.from_product([["({0})".format(mods_n[keys[m][i][3]])], a.columns.tolist()])
            b = tab_collected[keys[m][i+1]].copy()
            b.columns = pd.MultiIndex.from_product([["({0})".format(mods_n[keys[m][i+1][3]])], b.columns.tolist()])
            tab2 = pd.concat([a, b], axis=1)
            tab2 = tab2.reindex(ind1)

            # Fill nan
            tab2 = tab2.fillna("").copy()

            # Get rid of se labels
            tab2.index = ["" if "(s.e.)" in x else x for x in tab2.index ]
            # Rename index
            tab2.index.name = "$KS="+repl1[k[1]][1::]
            # Get rid of se labels
            tab2 = tab2.reset_index(col_level=1)

            tab2 = tab2.replace(repl1).copy()

            tab_col[m][k] = tab2

# %%
m = "norm"
for k,v in tab_col[m].items():
    print(k)
    display(v)
# Out:
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC')
#                                                 (1)                        \
#                       $KS=sim_{DV}(i,j)$    1975-85    1985-95    1995-05
# 0                      $I(MSA \, Match)$     0.0170  0.0390***  0.0300***
# 1                                          (0.0120)   (0.0070)   (0.0048)
# 2   $I_{MSA} * sim_{DV}(pc_{i}, pc_{j})$
# 3
# 4             $sim_{DV}(pc_{i}, pc_{j})$  0.2805***  0.2913***  0.2816***
# 5                                          (0.0090)   (0.0055)   (0.0040)
# 6                                    $N$      40323     110982     215861
# 7                         Adjusted $R^2$       0.12       0.13       0.13
# 8                                Year FE       True       True       True
# 9                                  PC FE       True       True       True
# 10                   Inv \& Lawyer Match       True       True       True
#
#                      (2)
#       2005-15    1975-85    1985-95    1995-05    2005-15
# 0   0.0274***     0.0178  0.0415***  0.0277***  0.0222***
# 1    (0.0038)   (0.0120)   (0.0069)   (0.0048)   (0.0043)
# 2                -0.0012    -0.0045     0.0050    0.0085*
# 3               (0.0116)   (0.0067)   (0.0047)   (0.0045)
# 4   0.2932***  0.2808***  0.2925***  0.2804***  0.2908***
# 5    (0.0036)   (0.0095)   (0.0057)   (0.0042)   (0.0039)
# 6      344313      40323     110982     215861     344313
# 7        0.08       0.12       0.13       0.13       0.08
# 8        True       True       True       True       True
# 9        True       True       True       True       True
# 10       True       True       True       True       True
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA')
#                                                             (3)             \
#                                   $KS=sim_{DV}(i,j)$    1975-85    1985-95
# 0                                  $I(MSA \, Match)$     0.0109  0.0353***
# 1                                                      (0.0121)   (0.0071)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$
# 3
# 4             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.1259***  0.1259***
# 5                                                      (0.0070)   (0.0041)
# 6                                                $N$      40323     110982
# 7                                     Adjusted $R^2$       0.11       0.11
# 8                                            Year FE       True       True
# 9                                              PC FE       True       True
# 10                               Inv \& Lawyer Match       True       True
#
#                                 (4)
#       1995-05    2005-15    1975-85    1985-95    1995-05    2005-15
# 0   0.0187***  0.0170***     0.0114  0.0357***  0.0202***  0.0194***
# 1    (0.0048)   (0.0038)   (0.0124)   (0.0073)   (0.0051)   (0.0039)
# 2                            0.0064     0.0040    0.0103*  0.0261***
# 3                          (0.0136)   (0.0079)   (0.0061)   (0.0057)
# 4   0.1643***  0.1830***  0.1245***  0.1250***  0.1618***  0.1764***
# 5    (0.0035)   (0.0031)   (0.0076)   (0.0045)   (0.0038)   (0.0034)
# 6      215861     344313      40323     110982     215861     344313
# 7        0.12       0.08       0.11       0.11       0.12       0.08
# 8        True       True       True       True       True       True
# 9        True       True       True       True       True       True
# 10       True       True       True       True       True       True
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA')
#                                                             (5)             \
#                                   $KS=sim_{DV}(i,j)$    1975-85    1985-95
# 0                                  $I(MSA \, Match)$     0.0100  0.0248***
# 1                                                      (0.0143)   (0.0081)
# 2   $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$
# 3
# 4             $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$  0.0654***  0.0652***
# 5                                                      (0.0075)   (0.0045)
# 6                                                $N$      38324     106152
# 7                                     Adjusted $R^2$       0.08       0.08
# 8                                            Year FE       True       True
# 9                                              PC FE       True       True
# 10                               Inv \& Lawyer Match       True       True
#
#                                 (6)
#       1995-05    2005-15    1975-85    1985-95    1995-05    2005-15
# 0   0.0316***  0.0157***    -0.0047  0.0353***  0.0413***  0.0216***
# 1    (0.0054)   (0.0041)   (0.0213)   (0.0112)   (0.0075)   (0.0058)
# 2                            0.0145    -0.0116    -0.0123    -0.0087
# 3                          (0.0175)   (0.0099)   (0.0077)   (0.0068)
# 4   0.0826***  0.0935***  0.0632***  0.0671***  0.0849***  0.0953***
# 5    (0.0038)   (0.0035)   (0.0079)   (0.0048)   (0.0041)   (0.0038)
# 6      205248     324142      38324     106152     205248     324142
# 7        0.09       0.06       0.08       0.08       0.09       0.06
# 8        True       True       True       True       True       True
# 9        True       True       True       True       True       True
# 10       True       True       True       True       True       True

# %%
m = "norm"
for k,v in tab_col[m].items():
    print("\n"+str(k)+"\n"+"\n")
    with pd.option_context("max_colwidth", 1000):
        print(v.to_latex(index=False,escape=False, column_format="l|cccc|cccc", multicolumn_format="c"))
# Out:
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                       & \multicolumn{4}{c}{(1)} & \multicolumn{4}{c}{(2)} \\
#                    $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                     $I(MSA \, Match)$ &     0.0170 &  0.0390*** &  0.0300*** &  0.0274*** &     0.0178 &  0.0415*** &  0.0277*** &  0.0222*** \\
#                                       &   (0.0120) &   (0.0070) &   (0.0048) &   (0.0038) &   (0.0120) &   (0.0069) &   (0.0048) &   (0.0043) \\
#  $I_{MSA} * sim_{DV}(pc_{i}, pc_{j})$ &            &            &            &            &    -0.0012 &    -0.0045 &     0.0050 &    0.0085* \\
#                                       &            &            &            &            &   (0.0116) &   (0.0067) &   (0.0047) &   (0.0045) \\
#            $sim_{DV}(pc_{i}, pc_{j})$ &  0.2805*** &  0.2913*** &  0.2816*** &  0.2932*** &  0.2808*** &  0.2925*** &  0.2804*** &  0.2908*** \\
#                                       &   (0.0090) &   (0.0055) &   (0.0040) &   (0.0036) &   (0.0095) &   (0.0057) &   (0.0042) &   (0.0039) \\
#                                   $N$ &      40323 &     110982 &     215861 &     344313 &      40323 &     110982 &     215861 &     344313 \\
#                        Adjusted $R^2$ &       0.12 &       0.13 &       0.13 &       0.08 &       0.12 &       0.13 &       0.13 &       0.08 \\
#                               Year FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                                 PC FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                   Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'naics_name', 'All FE-Sim PC MSA')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                                   & \multicolumn{4}{c}{(3)} & \multicolumn{4}{c}{(4)} \\
#                                $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     0.0109 &  0.0353*** &  0.0187*** &  0.0170*** &     0.0114 &  0.0357*** &  0.0202*** &  0.0194*** \\
#                                                   &   (0.0121) &   (0.0071) &   (0.0048) &   (0.0038) &   (0.0124) &   (0.0073) &   (0.0051) &   (0.0039) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &            &            &            &            &     0.0064 &     0.0040 &    0.0103* &  0.0261*** \\
#                                                   &            &            &            &            &   (0.0136) &   (0.0079) &   (0.0061) &   (0.0057) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.1259*** &  0.1259*** &  0.1643*** &  0.1830*** &  0.1245*** &  0.1250*** &  0.1618*** &  0.1764*** \\
#                                                   &   (0.0070) &   (0.0041) &   (0.0035) &   (0.0031) &   (0.0076) &   (0.0045) &   (0.0038) &   (0.0034) \\
#                                               $N$ &      40323 &     110982 &     215861 &     344313 &      40323 &     110982 &     215861 &     344313 \\
#                                    Adjusted $R^2$ &       0.11 &       0.11 &       0.12 &       0.08 &       0.11 &       0.11 &       0.12 &       0.08 \\
#                                           Year FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                                             PC FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                               Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('norm', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                                   & \multicolumn{4}{c}{(5)} & \multicolumn{4}{c}{(6)} \\
#                                $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     0.0100 &  0.0248*** &  0.0316*** &  0.0157*** &    -0.0047 &  0.0353*** &  0.0413*** &  0.0216*** \\
#                                                   &   (0.0143) &   (0.0081) &   (0.0054) &   (0.0041) &   (0.0213) &   (0.0112) &   (0.0075) &   (0.0058) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &            &            &            &            &     0.0145 &    -0.0116 &    -0.0123 &    -0.0087 \\
#                                                   &            &            &            &            &   (0.0175) &   (0.0099) &   (0.0077) &   (0.0068) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.0654*** &  0.0652*** &  0.0826*** &  0.0935*** &  0.0632*** &  0.0671*** &  0.0849*** &  0.0953*** \\
#                                                   &   (0.0075) &   (0.0045) &   (0.0038) &   (0.0035) &   (0.0079) &   (0.0048) &   (0.0041) &   (0.0038) \\
#                                               $N$ &      38324 &     106152 &     205248 &     324142 &      38324 &     106152 &     205248 &     324142 \\
#                                    Adjusted $R^2$ &       0.08 &       0.08 &       0.09 &       0.06 &       0.08 &       0.08 &       0.09 &       0.06 \\
#                                           Year FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                                             PC FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                               Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}

# %%
m = "raw"
for k,v in tab_col[m].items():
    print("\n"+str(k)+"\n"+"\n")
    with pd.option_context("max_colwidth", 1000):
        print(v.to_latex(index=False,escape=False, column_format="l|cccc|cccc", multicolumn_format="c"))
# Out:
# ('raw', 'docvecs', 'naics_name', 'All FE-Sim PC')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                       & \multicolumn{4}{c}{(1)} & \multicolumn{4}{c}{(2)} \\
#                    $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                     $I(MSA \, Match)$ &     0.0023 &  0.0053*** &  0.0041*** &  0.0037*** &     0.0028 &  0.0072*** &     0.0020 &    -0.0000 \\
#                                       &   (0.0016) &   (0.0009) &   (0.0006) &   (0.0005) &   (0.0049) &   (0.0027) &   (0.0019) &   (0.0020) \\
#  $I_{MSA} * sim_{DV}(pc_{i}, pc_{j})$ &            &            &            &            &    -0.0038 &    -0.0141 &     0.0158 &    0.0270* \\
#                                       &            &            &            &            &   (0.0367) &   (0.0211) &   (0.0149) &   (0.0144) \\
#                 $I(Primclass\,Match)$ &     0.0018 &   0.0037** &  0.0032*** &   0.0019** &     0.0018 &   0.0037** &  0.0031*** &    0.0018* \\
#                                       &   (0.0030) &   (0.0017) &   (0.0012) &   (0.0009) &   (0.0030) &   (0.0017) &   (0.0012) &   (0.0009) \\
#            $sim_{DV}(pc_{i}, pc_{j})$ &  0.8893*** &  0.9236*** &  0.8929*** &  0.9294*** &  0.8902*** &  0.9273*** &  0.8888*** &  0.9220*** \\
#                                       &   (0.0286) &   (0.0173) &   (0.0126) &   (0.0116) &   (0.0301) &   (0.0182) &   (0.0132) &   (0.0122) \\
#                                   $N$ &      40323 &     110982 &     215861 &     344313 &      40323 &     110982 &     215861 &     344313 \\
#                        Adjusted $R^2$ &       0.12 &       0.13 &       0.13 &       0.08 &       0.12 &       0.13 &       0.13 &       0.08 \\
#                               Year FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                                 PC FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                   Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'naics_name', 'All FE-Sim PC MSA')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                                   & \multicolumn{4}{c}{(3)} & \multicolumn{4}{c}{(4)} \\
#                                $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &     2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     0.0015 &  0.0048*** &  0.0025*** &  0.0023*** &    -0.0002 &    0.0038* &    -0.0000 &  -0.0043*** \\
#                                                   &   (0.0016) &   (0.0010) &   (0.0007) &   (0.0005) &   (0.0035) &   (0.0020) &   (0.0015) &    (0.0015) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &            &            &            &            &     0.0113 &     0.0070 &    0.0181* &   0.0461*** \\
#                                                   &            &            &            &            &   (0.0241) &   (0.0139) &   (0.0108) &    (0.0101) \\
#                             $I(Primclass\,Match)$ &  0.0389*** &  0.0415*** &  0.0355*** &  0.0320*** &  0.0388*** &  0.0414*** &  0.0353*** &   0.0317*** \\
#                                                   &   (0.0026) &   (0.0015) &   (0.0010) &   (0.0008) &   (0.0026) &   (0.0015) &   (0.0010) &    (0.0008) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.2227*** &  0.2227*** &  0.2907*** &  0.3238*** &  0.2203*** &  0.2211*** &  0.2863*** &   0.3122*** \\
#                                                   &   (0.0123) &   (0.0073) &   (0.0061) &   (0.0055) &   (0.0135) &   (0.0080) &   (0.0067) &    (0.0061) \\
#                                               $N$ &      40323 &     110982 &     215861 &     344313 &      40323 &     110982 &     215861 &      344313 \\
#                                    Adjusted $R^2$ &       0.11 &       0.11 &       0.12 &       0.08 &       0.11 &       0.11 &       0.12 &        0.08 \\
#                                           Year FE &       True &       True &       True &       True &       True &       True &       True &        True \\
#                                             PC FE &       True &       True &       True &       True &       True &       True &       True &        True \\
#                               Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &        True \\
# \bottomrule
# \end{tabular}
#
#
# ('raw', 'docvecs', 'primclass', 'Inv FE-Sim PC MSA')
#
#
# \begin{tabular}{l|cccc|cccc}
# \toprule
#                                                   & \multicolumn{4}{c}{(5)} & \multicolumn{4}{c}{(6)} \\
#                                $KS=sim_{DV}(i,j)$ &    1975-85 &    1985-95 &    1995-05 &    2005-15 &    1975-85 &    1985-95 &    1995-05 &    2005-15 \\
# \midrule
#                                 $I(MSA \, Match)$ &     0.0014 &  0.0034*** &  0.0044*** &  0.0022*** &    -0.0046 &   0.0081** &  0.0091*** &   0.0054** \\
#                                                   &   (0.0020) &   (0.0011) &   (0.0008) &   (0.0006) &   (0.0072) &   (0.0039) &   (0.0029) &   (0.0025) \\
#  $I_{MSA} * sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &            &            &            &            &     0.0264 &    -0.0210 &    -0.0224 &    -0.0158 \\
#                                                   &            &            &            &            &   (0.0317) &   (0.0179) &   (0.0140) &   (0.0123) \\
#            $sim_{DV}(pc_{i,MSA_i}, pc_{j,MSA_j})$ &  0.1188*** &  0.1183*** &  0.1500*** &  0.1698*** &  0.1148*** &  0.1218*** &  0.1542*** &  0.1730*** \\
#                                                   &   (0.0136) &   (0.0082) &   (0.0069) &   (0.0064) &   (0.0144) &   (0.0087) &   (0.0075) &   (0.0069) \\
#                                               $N$ &      38324 &     106152 &     205248 &     324142 &      38324 &     106152 &     205248 &     324142 \\
#                                    Adjusted $R^2$ &       0.08 &       0.08 &       0.09 &       0.06 &       0.08 &       0.08 &       0.09 &       0.06 \\
#                                           Year FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                                             PC FE &       True &       True &       True &       True &       True &       True &       True &       True \\
#                               Inv \& Lawyer Match &       True &       True &       True &       True &       True &       True &       True &       True \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### 2.3 Localization estimate by model for norm, docvecs

# %%
local_est = pd.DataFrame()
for k,v in tab_no_c_yr.items():
    if (k[0] == "norm") & (k[1] == "docvecs"):
        v2 = v.loc[[0,1]]
        v2[""] = mods_n[k[3]]
        v2["var"] = ["est", "se"]
        v2["Model Name"] = k[3]
        local_est = local_est.append(v2, ignore_index=True)
        
local_est = local_est.sort_values(["", "var"]).reset_index(drop=True).drop("var",1)
local_est[""] = local_est[""].apply(lambda x: "({0})".format(x))
local_est.loc[list(range(1,len(local_est),2)), ""] = ""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-34aef88f6a68> in <module>()
#       3     if (k[0] == "norm") & (k[1] == "docvecs"):
#       4         v2 = v.loc[[0,1]]
# ----> 5         v2[""] = mods_n[k[3]]
#       6         v2["var"] = ["est", "se"]
#       7         v2["Model Name"] = k[3]
#
# KeyError: 'All FE-Sim PC MSA-Cb'

# %%
local_est
# Out:
#              1975-85     1985-95     1995-05     2005-15  \
# 0    (1)     0.0209*   0.0407***   0.0334***   0.0287***
# 1           (0.0112)    (0.0066)    (0.0046)    (0.0037)
# 2    (2)     0.0207*   0.0404***   0.0333***   0.0287***
# 3           (0.0112)    (0.0066)    (0.0046)    (0.0037)
# 4    (3)  -0.0480***   -0.0183**  -0.0328***  -0.0224***
# 5           (0.0124)    (0.0072)    (0.0049)    (0.0039)
# 6    (4)  -0.0599***  -0.0344***  -0.0491***  -0.0381***
# 7           (0.0125)    (0.0073)    (0.0050)    (0.0039)
# 8    (5)     0.0208*   0.0401***   0.0319***   0.0219***
# 9           (0.0111)    (0.0065)    (0.0046)    (0.0038)
# 10   (6)     0.0206*   0.0398***   0.0319***   0.0222***
# 11          (0.0111)    (0.0065)    (0.0046)    (0.0038)
# 12   (7)  -0.0479***   -0.0176**  -0.0326***  -0.0276***
# 13          (0.0123)    (0.0072)    (0.0049)    (0.0042)
# 14   (8)  -0.0620***  -0.0360***  -0.0430***  -0.0278***
# 15          (0.0126)    (0.0074)    (0.0049)    (0.0042)
# 16   (9)     0.0210*   0.0406***   0.0333***   0.0286***
# 17          (0.0112)    (0.0066)    (0.0046)    (0.0037)
# 18  (10)     0.0210*   0.0405***   0.0335***   0.0287***
# 19          (0.0112)    (0.0066)    (0.0046)    (0.0037)
# 20  (11)     -0.0103   0.0206***      0.0059     0.0071*
# 21          (0.0122)    (0.0071)    (0.0049)    (0.0038)
# 22  (12)     -0.0142    0.0158**      0.0002      0.0003
# 23          (0.0122)    (0.0071)    (0.0049)    (0.0039)
# 24  (13)  -0.0550***  -0.0258***  -0.0387***  -0.0338***
# 25          (0.0127)    (0.0075)    (0.0051)    (0.0041)
# 26  (14)  -0.0547***  -0.0247***  -0.0341***  -0.0297***
# 27          (0.0127)    (0.0075)    (0.0051)    (0.0041)
#
#                        Model Name
# 0                   All FE-Sim PC
# 1                   All FE-Sim PC
# 2                All FE-Sim PC Qd
# 3                All FE-Sim PC Qd
# 4               All FE-Sim PC MSA
# 5               All FE-Sim PC MSA
# 6            All FE-Sim PC MSA Qd
# 7            All FE-Sim PC MSA Qd
# 8                   All FE-Int PC
# 9                   All FE-Int PC
# 10           All FE-Int PC-Add Qd
# 11           All FE-Int PC-Add Qd
# 12              All FE-Int PC MSA
# 13              All FE-Int PC MSA
# 14       All FE-Int PC MSA-Add Qd
# 15       All FE-Int PC MSA-Add Qd
# 16             All FE-PC M-Sim PC
# 17             All FE-PC M-Sim PC
# 18          All FE-PC M-Sim PC Qd
# 19          All FE-PC M-Sim PC Qd
# 20         All FE-PC M-Sim PC MSA
# 21         All FE-PC M-Sim PC MSA
# 22      All FE-PC M-Sim PC MSA Qd
# 23      All FE-PC M-Sim PC MSA Qd
# 24     All FE-PC MSA M-Sim PC MSA
# 25     All FE-PC MSA M-Sim PC MSA
# 26  All FE-PC MSA M-Sim PC MSA Qd
# 27  All FE-PC MSA M-Sim PC MSA Qd
