# %%
import scipy as sp
import numpy as np
import pandas as pd
import timeit
import re
import json
import pickle
import fastparquet
import os
os.chdir('/mnt/t48/bighomes-active/sfeng/patentdiffusion/')
seed = 3
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.iolib.summary2 as summary2
import logging
import itertools
# Out:
# /homedir/eco/sfeng/bigdata/python/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# In this regression:
# - Remove all primary class match observations and compare only similarity across patents from different technology fields

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig(level=logging.INFO)
logger.addHandler(logging.FileHandler('Logs/reg_{0}.log'.format(datetime.datetime.now().\
                                                            strftime("%Y-%m-%d"), 'a')))
print = logging.info
print('good day to you madam fiona')
print('started')
print(datetime.datetime.now())
# Out:
# INFO:root:good day to you madam fiona
# INFO:root:started
# INFO:root:2018-10-07 12:04:08.377995

# %%
pathdir = "DataStore/2018-10/Reg0930/"
reg_f = "reg_model_1002.pkl"

regs = pickle.load(open(pathdir+reg_f, "rb"))

# %%
# Add list of equations
# Drop Inv FE
naics_ind = regs["model_names"].loc[regs["model_names"].apply(lambda x: ("Sim PC" in x) or ("Int PC" in x))].index.tolist()
print(len(naics_ind))

regs[("docvecs", "naics_name")] = regs["docvecs"].loc[naics_ind]
regs[("ldavecs", "naics_name")] = regs["ldavecs"].loc[naics_ind]
for c in ["num_common_cited", "tp_pct_common_cited"]:
    regs[(c, "naics_name")] = regs[c].loc[regs[c].index.isin(naics_ind)]

# PC indices
# PC MSA not including Primclass Match
pc_msa_ind = regs["model_names"].loc[regs["model_names"].apply(lambda x: ("PC MSA" in x) & ("All FE" not in x))].index.tolist()

# Combine
pc_ind = pc_msa_ind
print(len(pc_ind))

regs[("docvecs", "primclass")] = regs["docvecs"].loc[regs["docvecs"].index.isin(pc_ind)].dropna()
regs[("ldavecs", "primclass")] = regs["ldavecs"].loc[regs["ldavecs"].index.isin(pc_ind)].dropna()
# Use whatever is available for num_common_cited
for c in ["num_common_cited", "tp_pct_common_cited"]:
    regs[(c, "primclass")] = regs[c].loc[regs[c].index.isin(pc_ind)]

# Where files are located
files = {"naics_name": "DataStore/2018-10/Reg0930/naics_name_all_1004.parq",
         "primclass": "DataStore/2018-10/Reg0930/primclass_all_1004.parq",
}
# Out:
# INFO:root:32
# INFO:root:12

# %%
info_dict = {'$N$':lambda x: "{0:d}".format(int(x.nobs)),
'Adjusted $R^2$':lambda x: "{:.2f}".format(x.rsquared_adj)}
def get_fit(formula, grouped_data, group_col, cov_type, return_fit = False):
    summ = []
    tables = {}
    
    # If formula uses mean similarity, use grant year above 1980
    if "mean_sim_" in formula:
        grouped_data = grouped_data.loc[(grouped_data["tp_gyear"] >= 1980)]
    
    # Remove missing values used in formula
    col_used = re.findall('\((.*?)\)',formula)
    # Intersect with grouped_data columns
    col_used = list(set(col_used).intersection(set(list(grouped_data.columns))))
    grouped_data = grouped_data.dropna(how="any", subset=col_used)
                                    # Should take care of gyear > 1980 issues
    
    # Group and then get results
    grouped_data = grouped_data.groupby(group_col)
    
    for n,g in grouped_data:
        try:
            fit = smf.ols(formula = formula, data = g, missing="drop").fit(cov_type=cov_type)
            # Get results tables
            tables[n] = fit.summary2().tables
            # Append results
            summ.append(fit)
        except Exception as e:
            print(n)
            logging.exception("Regression error")
            pass
    # Get full results output
    # Dataframe of full results
    res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict).tables[0]
    
    # Get partial results
    # 1. Get relevant variables from index of full results: UPDATED
    regressors = [v for v in res_no_stars.index.unique() if ("sim_" in v) | ("match" in v) | ("common_" in v)]
    # 2. Make sure regressors come last
    regressors = regressors+["Intercept"]
    # 3. Get results with regressors
    part_res_no_stars = summary2.summary_col(summ, stars = False, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    part_res_stars = summary2.summary_col(summ, stars = True, \
    model_names = ["{0}".format(n) for n in tables.keys()],\
        info_dict = info_dict, regressor_order = regressors).tables[0]
    
    # 4. Get index of where Intercept is and add 2 (to include standard error)
    last_ind = list(part_res_stars.index).index("Intercept")+2
    
    # 5. Get partial results
    part_res_no_stars = pd.concat([part_res_no_stars.iloc[:last_ind], part_res_no_stars.iloc[-2::]])
    part_res_stars = pd.concat([part_res_stars.iloc[:last_ind], part_res_stars.iloc[-2::]])
    
    if return_fit == True:
        return summ, tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars
    else:
        return tables, res_no_stars, res_stars, part_res_no_stars, part_res_stars
    
def get_results(sample, ks):
    rs = fastparquet.ParquetFile(files[sample]).to_pandas()
    try:
        rs = rs.drop(['mean_sim_ldavecs_pc_msa_v',
           'mean_sim_docvecs_pc_msa_v', 'mean_sim_docvecs_pc_v', 'mean_sim_ldavecs_pc_v',
           'norm_mean_sim_ldavecs_pc_msa_v', 'norm_mean_sim_docvecs_pc_msa_v',
           'norm_mean_sim_docvecs_pc_v', 'norm_mean_sim_ldavecs_pc_v'],1)
        
    except:
        pass
    print(rs.columns)
    print(len(rs))
    
    # Drop extreme values
    print(len(rs))
    rs = rs.loc[(rs["norm_mean_sim_docvecs_pc_msa"] >= -5) & (rs["norm_mean_sim_docvecs_pc_msa"] <= 5)]
    rs = rs.loc[(rs["norm_mean_sim_docvecs_pc"] >= -5) & (rs["norm_mean_sim_docvecs_pc"] <= 5)]
    print(len(rs))
    
    print((ks, sample, "started"))
    print(datetime.datetime.now())
    # 3. Define output
    samp_out = {}
    formulas = list(regs[(ks, sample)])
    formulas_ind = list(regs[(ks, sample)].index)
    cov = "HC1"
    for i, j in zip(formulas_ind, formulas):
        print((ks, sample, i, j))
        print(datetime.datetime.now())
        try:
            out = get_fit(j, rs, "year_group", cov, return_fit = False)
            samp_out[i] = {}
            samp_out[i]["model"] = j
            samp_out[i]["tables"] = out[0]
            samp_out[i]["res_no_stars"] = out[1]
            samp_out[i]["res_stars"] = out[2]
            samp_out[i]["part_res_no_stars"] = out[3]
            samp_out[i]["part_res_stars"] = out[4]
        except Exception as e:
            logging.exception("error here")
            pass
        print("finished")
        print(datetime.datetime.now())
    
    # Define outfile
    o_f = "reg_{0}_{1}_out_1003.pkl".format(ks, sample)
    pickle.dump(samp_out, open(pathdir+o_f, "wb"))

# %%
samples_l = ["naics_name", "primclass"]
# ks_l = ["tp_pct_common_cited", "docvecs", "ldavecs", ]
ks_l = ["docvecs"]

for sample, ks in itertools.product(samples_l, ks_l):
    try:
        get_results(sample, ks)
    except Exception as e:
        logging.exception("error here")
        pass
# Out:
# INFO:root:Index(['tp', 'op', 'sim_docvecs', 'sim_ldavecs', 'tp_gyear', 'tp_naics_name',
#        'tp_primclass', 'tp_inv_msa', 'op_naics_name', 'op_primclass',
#        'op_inv_msa', 'inv_msa_match', 'primclass_match', 'norm_sim_ldavecs',
#        'norm_sim_docvecs', 'year_group', 'common_est_inv', 'common_pat_inv',
#        'lawyer_match', 'num_common_cited', 'norm_num_common_cited',
#        'tp_pct_common_cited', 'norm_tp_pct_common_cited', 'common_cited_match',
#        'mean_sim_docvecs_pc', 'mean_sim_ldavecs_pc', 'mean_sim_docvecs_pc_msa',
#        'mean_sim_ldavecs_pc_msa', 'norm_mean_sim_docvecs_pc',
#        'norm_mean_sim_ldavecs_pc', 'norm_mean_sim_docvecs_pc_msa',
#        'norm_mean_sim_ldavecs_pc_msa', 'sd_sim_docvecs_pc',
#        'sd_sim_ldavecs_pc', 'sd_sim_docvecs_pc_msa', 'sd_sim_ldavecs_pc_msa',
#        'pc_msa_greater_0', 'pc_msa_less_0'],
#       dtype='object')
# INFO:root:1498184
# INFO:root:1498184
# INFO:root:1214679
# INFO:root:('docvecs', 'naics_name', 'started')
# INFO:root:2018-10-07 12:05:03.168656
# INFO:root:('docvecs', 'naics_name', 13, 'sim_docvecs ~ C(inv_msa_match) + C(tp_gyear) + mean_sim_docvecs_pc + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:05:03.173109
# INFO:root:finished
# INFO:root:2018-10-07 12:06:31.932765
# INFO:root:('docvecs', 'naics_name', 14, 'sim_docvecs ~ C(inv_msa_match)*mean_sim_docvecs_pc + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:06:31.933978
# INFO:root:finished
# INFO:root:2018-10-07 12:08:02.056391
# INFO:root:('docvecs', 'naics_name', 15, 'sim_docvecs ~ C(inv_msa_match) + C(tp_gyear) + mean_sim_docvecs_pc_msa + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:08:02.060732
# INFO:root:finished
# INFO:root:2018-10-07 12:09:30.622814
# INFO:root:('docvecs', 'naics_name', 16, 'sim_docvecs ~ C(inv_msa_match)*mean_sim_docvecs_pc_msa + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:09:30.628425
# INFO:root:finished
# INFO:root:2018-10-07 12:10:57.150325
# INFO:root:('docvecs', 'naics_name', 17, 'sim_docvecs ~ C(inv_msa_match) + C(tp_gyear) + mean_sim_docvecs_pc_msa + np.power(mean_sim_docvecs_pc_msa, 3) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:10:57.151578
# INFO:root:finished
# INFO:root:2018-10-07 12:12:20.699080
# INFO:root:('docvecs', 'naics_name', 18, 'sim_docvecs ~ C(inv_msa_match)*mean_sim_docvecs_pc_msa + np.power(mean_sim_docvecs_pc_msa,3) + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:12:20.700989
# INFO:root:finished
# INFO:root:2018-10-07 12:13:43.742261
# INFO:root:('docvecs', 'naics_name', 19, 'sim_docvecs ~ C(inv_msa_match)*mean_sim_docvecs_pc_msa + C(inv_msa_match)*np.power(mean_sim_docvecs_pc_msa,3)     + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:13:43.743485
# INFO:root:finished
# INFO:root:2018-10-07 12:15:05.659669
# INFO:root:('docvecs', 'naics_name', 20, 'sim_docvecs ~ C(inv_msa_match) + pc_msa_greater_0:mean_sim_docvecs_pc_msa +     pc_msa_less_0:mean_sim_docvecs_pc_msa + C(inv_msa_match):pc_msa_greater_0:mean_sim_docvecs_pc_msa +     C(inv_msa_match):pc_msa_less_0:mean_sim_docvecs_pc_msa + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match) + C(primclass_match)')
# INFO:root:2018-10-07 12:15:05.660865
# INFO:root:finished
# INFO:root:2018-10-07 12:16:27.497097
# INFO:root:('docvecs', 'naics_name', 21, 'sim_docvecs ~ C(inv_msa_match) + C(tp_gyear) + mean_sim_docvecs_pc + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match)')
# INFO:root:2018-10-07 12:16:27.499121
# INFO:root:finished
# INFO:root:2018-10-07 12:17:52.500417
# INFO:root:('docvecs', 'naics_name', 22, 'sim_docvecs ~ C(inv_msa_match)*mean_sim_docvecs_pc + C(tp_gyear) + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match)')
# INFO:root:2018-10-07 12:17:52.501827
# INFO:root:finished
# INFO:root:2018-10-07 12:19:16.100439
# INFO:root:('docvecs', 'naics_name', 23, 'sim_docvecs ~ C(inv_msa_match) + C(tp_gyear) + mean_sim_docvecs_pc_msa + C(tp_primclass) + C(common_est_inv) + C(common_pat_inv) + C(lawyer_match)')
# INFO:root:2018-10-07 12:19:16.101692

# %% [markdown]
# ### Results

# %%
tab = {}
samples_l = ["naics_name", "primclass"]
# samples_l = ["naics_name"]
# ks_l = ["tp_pct_common_cited", "docvecs", "ldavecs", ]
ks_l = ["docvecs"]

for sample, ks in itertools.product(samples_l, ks_l):
        o_f = "reg_{0}_{1}_out_1003.pkl".format(ks, sample)
        
        res = pickle.load(open(pathdir+o_f, "rb"))

        res_out = pd.DataFrame()

        for k in res.keys():
            lks = res[k]["model"].split(" ~ ")[0]
            
            # Selecting portion of results without intercept
            cdf = res[k]["part_res_stars"].reset_index()
            ic_ind = cdf.loc[cdf["index"] == "Intercept"].index[0]
            # Include N & R^2
            cdf = cdf.iloc[pd.np.r_[0:ic_ind,ic_ind+2:len(cdf)]]
            cdf["Model"] = regs["model_names"][k]
            cdf["Model Num"] = k
            cdf["LKS"] = lks
        
            res_out = res_out.append(cdf)
        
        tab[ks, sample] = res_out
        del(res_out)
        
full_tab = tab

# %%
r = pd.DataFrame()
for k,v in tab.items():
    print(k)
    display(v)
    v["samp"] = str(k)
    v = v.reset_index(drop=True)
    r = pd.concat([r,v],axis=0)
# Out:
# INFO:root:('docvecs', 'naics_name')
#                                                 index     1975-85     1985-95  \
# 0                            C(common_est_inv)[T.1.0]    0.0057**    0.0026**
# 1                                                        (0.0026)    (0.0013)
# 2                           C(common_pat_inv)[T.True]      0.0503   0.0921***
# 3                                                        (0.0446)    (0.0213)
# 4                            C(inv_msa_match)[T.True]      0.0023   0.0053***
# 5                                                        (0.0016)    (0.0009)
# 6                             C(lawyer_match)[T.True]      0.0040   0.0221***
# 7                                                        (0.0155)    (0.0066)
# 8                          C(primclass_match)[T.True]      0.0018    0.0037**
# 9                                                        (0.0030)    (0.0017)
# 10                                mean_sim_docvecs_pc   0.8893***   0.9236***
# 11                                                       (0.0286)    (0.0173)
# 14                                                $N$       40323      110982
# 15                                     Adjusted $R^2$        0.12        0.13
# 0                            C(common_est_inv)[T.1.0]    0.0057**    0.0027**
# 1                                                        (0.0026)    (0.0013)
# 2                           C(common_pat_inv)[T.True]      0.0504   0.0925***
# 3                                                        (0.0446)    (0.0213)
# 4                            C(inv_msa_match)[T.True]      0.0028   0.0072***
# 5                                                        (0.0049)    (0.0027)
# 6        C(inv_msa_match)[T.True]:mean_sim_docvecs_pc     -0.0038     -0.0141
# 7                                                        (0.0367)    (0.0211)
# 8                             C(lawyer_match)[T.True]      0.0040   0.0222***
# 9                                                        (0.0155)    (0.0066)
# 10                         C(primclass_match)[T.True]      0.0018    0.0037**
# 11                                                       (0.0030)    (0.0017)
# 12                                mean_sim_docvecs_pc   0.8902***   0.9273***
# 13                                                       (0.0301)    (0.0182)
# 16                                                $N$       40323      110982
# 17                                     Adjusted $R^2$        0.12        0.13
# ..                                                ...         ...         ...
# 6   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...      0.0243   0.0327***
# 7                                                        (0.0189)    (0.0103)
# 8   C(inv_msa_match)[T.True]:np.power(norm_mean_si...     -0.0007     -0.0020
# 9                                                        (0.0037)    (0.0018)
# 10                            C(lawyer_match)[T.True]      0.0684   0.2101***
# 11                                                       (0.1152)    (0.0492)
# 12                       norm_mean_sim_docvecs_pc_msa   0.2161***   0.2121***
# 13                                                       (0.0100)    (0.0058)
# 14          np.power(norm_mean_sim_docvecs_pc_msa, 3)  -0.0130***  -0.0113***
# 15                                                       (0.0016)    (0.0009)
# 18                                                $N$       40323      110982
# 19                                     Adjusted $R^2$        0.11        0.11
# 0                            C(common_est_inv)[T.1.0]   0.0641***   0.0478***
# 1                                                        (0.0193)    (0.0094)
# 2                           C(common_pat_inv)[T.True]      0.4262   0.6990***
# 3                                                        (0.3411)    (0.1433)
# 4                            C(inv_msa_match)[T.True]      0.0106    0.0255**
# 5                                                        (0.0200)    (0.0118)
# 6   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...      0.0307   0.0399***
# 7                                                        (0.0268)    (0.0154)
# 8   C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...      0.0156     -0.0011
# 9                                                        (0.0238)    (0.0142)
# 10                            C(lawyer_match)[T.True]      0.0415   0.2021***
# 11                                                       (0.1166)    (0.0495)
# 12      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa   0.1753***   0.1791***
# 13                                                       (0.0148)    (0.0089)
# 14         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa   0.1266***   0.1365***
# 15                                                       (0.0114)    (0.0065)
# 18                                                $N$       40323      110982
# 19                                     Adjusted $R^2$        0.10        0.10
#
#        1995-05     2005-15                       Model  Model Num  \
# 0    0.0036***   0.0053***               All FE-Sim PC         13
# 1     (0.0007)    (0.0005)               All FE-Sim PC         13
# 2    0.0911***   0.0944***               All FE-Sim PC         13
# 3     (0.0122)    (0.0113)               All FE-Sim PC         13
# 4    0.0041***   0.0037***               All FE-Sim PC         13
# 5     (0.0006)    (0.0005)               All FE-Sim PC         13
# 6    0.0351***   0.0258***               All FE-Sim PC         13
# 7     (0.0055)    (0.0046)               All FE-Sim PC         13
# 8    0.0032***    0.0019**               All FE-Sim PC         13
# 9     (0.0012)    (0.0009)               All FE-Sim PC         13
# 10   0.8929***   0.9294***               All FE-Sim PC         13
# 11    (0.0126)    (0.0116)               All FE-Sim PC         13
# 14      215861      344313               All FE-Sim PC         13
# 15        0.13        0.08               All FE-Sim PC         13
# 0    0.0036***   0.0053***               All FE-Int PC         14
# 1     (0.0007)    (0.0005)               All FE-Int PC         14
# 2    0.0906***   0.0936***               All FE-Int PC         14
# 3     (0.0122)    (0.0113)               All FE-Int PC         14
# 4       0.0020     -0.0000               All FE-Int PC         14
# 5     (0.0019)    (0.0020)               All FE-Int PC         14
# 6       0.0158     0.0270*               All FE-Int PC         14
# 7     (0.0149)    (0.0144)               All FE-Int PC         14
# 8    0.0350***   0.0257***               All FE-Int PC         14
# 9     (0.0055)    (0.0046)               All FE-Int PC         14
# 10   0.0031***     0.0018*               All FE-Int PC         14
# 11    (0.0012)    (0.0009)               All FE-Int PC         14
# 12   0.8888***   0.9220***               All FE-Int PC         14
# 13    (0.0132)    (0.0122)               All FE-Int PC         14
# 16      215861      344313               All FE-Int PC         14
# 17        0.13        0.08               All FE-Int PC         14
# ..         ...         ...                         ...        ...
# 6    0.0347***   0.0392***  N Inv FE-Int PC MSA-Int Cb         56
# 7     (0.0077)    (0.0071)  N Inv FE-Int PC MSA-Int Cb         56
# 8      -0.0019      0.0021  N Inv FE-Int PC MSA-Int Cb         56
# 9     (0.0016)    (0.0015)  N Inv FE-Int PC MSA-Int Cb         56
# 10   0.2408***   0.1895***  N Inv FE-Int PC MSA-Int Cb         56
# 11    (0.0405)    (0.0334)  N Inv FE-Int PC MSA-Int Cb         56
# 12   0.2672***   0.2811***  N Inv FE-Int PC MSA-Int Cb         56
# 13    (0.0047)    (0.0041)  N Inv FE-Int PC MSA-Int Cb         56
# 14  -0.0151***  -0.0163***  N Inv FE-Int PC MSA-Int Cb         56
# 15    (0.0008)    (0.0008)  N Inv FE-Int PC MSA-Int Cb         56
# 18      215861      344313  N Inv FE-Int PC MSA-Int Cb         56
# 19        0.12        0.07  N Inv FE-Int PC MSA-Int Cb         56
# 0    0.0477***   0.0552***   N Inv FE-Break Int PC MSA         57
# 1     (0.0056)    (0.0039)   N Inv FE-Break Int PC MSA         57
# 2    0.6841***   0.6425***   N Inv FE-Break Int PC MSA         57
# 3     (0.0906)    (0.0858)   N Inv FE-Break Int PC MSA         57
# 4    0.0481***   0.0265***   N Inv FE-Break Int PC MSA         57
# 5     (0.0083)    (0.0061)   N Inv FE-Break Int PC MSA         57
# 6      -0.0042   0.0351***   N Inv FE-Break Int PC MSA         57
# 7     (0.0123)    (0.0107)   N Inv FE-Break Int PC MSA         57
# 8    0.0611***   0.0486***   N Inv FE-Break Int PC MSA         57
# 9     (0.0109)    (0.0103)   N Inv FE-Break Int PC MSA         57
# 10   0.2364***   0.1921***   N Inv FE-Break Int PC MSA         57
# 11    (0.0406)    (0.0335)   N Inv FE-Break Int PC MSA         57
# 12   0.2367***   0.2539***   N Inv FE-Break Int PC MSA         57
# 13    (0.0078)    (0.0067)   N Inv FE-Break Int PC MSA         57
# 14   0.1783***   0.1884***   N Inv FE-Break Int PC MSA         57
# 15    (0.0052)    (0.0050)   N Inv FE-Break Int PC MSA         57
# 18      215861      344313   N Inv FE-Break Int PC MSA         57
# 19        0.12        0.07   N Inv FE-Break Int PC MSA         57
#
#                  LKS                       samp
# 0        sim_docvecs  ('docvecs', 'naics_name')
# 1        sim_docvecs  ('docvecs', 'naics_name')
# 2        sim_docvecs  ('docvecs', 'naics_name')
# 3        sim_docvecs  ('docvecs', 'naics_name')
# 4        sim_docvecs  ('docvecs', 'naics_name')
# 5        sim_docvecs  ('docvecs', 'naics_name')
# 6        sim_docvecs  ('docvecs', 'naics_name')
# 7        sim_docvecs  ('docvecs', 'naics_name')
# 8        sim_docvecs  ('docvecs', 'naics_name')
# 9        sim_docvecs  ('docvecs', 'naics_name')
# 10       sim_docvecs  ('docvecs', 'naics_name')
# 11       sim_docvecs  ('docvecs', 'naics_name')
# 14       sim_docvecs  ('docvecs', 'naics_name')
# 15       sim_docvecs  ('docvecs', 'naics_name')
# 0        sim_docvecs  ('docvecs', 'naics_name')
# 1        sim_docvecs  ('docvecs', 'naics_name')
# 2        sim_docvecs  ('docvecs', 'naics_name')
# 3        sim_docvecs  ('docvecs', 'naics_name')
# 4        sim_docvecs  ('docvecs', 'naics_name')
# 5        sim_docvecs  ('docvecs', 'naics_name')
# 6        sim_docvecs  ('docvecs', 'naics_name')
# 7        sim_docvecs  ('docvecs', 'naics_name')
# 8        sim_docvecs  ('docvecs', 'naics_name')
# 9        sim_docvecs  ('docvecs', 'naics_name')
# 10       sim_docvecs  ('docvecs', 'naics_name')
# 11       sim_docvecs  ('docvecs', 'naics_name')
# 12       sim_docvecs  ('docvecs', 'naics_name')
# 13       sim_docvecs  ('docvecs', 'naics_name')
# 16       sim_docvecs  ('docvecs', 'naics_name')
# 17       sim_docvecs  ('docvecs', 'naics_name')
# ..               ...                        ...
# 6   norm_sim_docvecs  ('docvecs', 'naics_name')
# 7   norm_sim_docvecs  ('docvecs', 'naics_name')
# 8   norm_sim_docvecs  ('docvecs', 'naics_name')
# 9   norm_sim_docvecs  ('docvecs', 'naics_name')
# 10  norm_sim_docvecs  ('docvecs', 'naics_name')
# 11  norm_sim_docvecs  ('docvecs', 'naics_name')
# 12  norm_sim_docvecs  ('docvecs', 'naics_name')
# 13  norm_sim_docvecs  ('docvecs', 'naics_name')
# 14  norm_sim_docvecs  ('docvecs', 'naics_name')
# 15  norm_sim_docvecs  ('docvecs', 'naics_name')
# 18  norm_sim_docvecs  ('docvecs', 'naics_name')
# 19  norm_sim_docvecs  ('docvecs', 'naics_name')
# 0   norm_sim_docvecs  ('docvecs', 'naics_name')
# 1   norm_sim_docvecs  ('docvecs', 'naics_name')
# 2   norm_sim_docvecs  ('docvecs', 'naics_name')
# 3   norm_sim_docvecs  ('docvecs', 'naics_name')
# 4   norm_sim_docvecs  ('docvecs', 'naics_name')
# 5   norm_sim_docvecs  ('docvecs', 'naics_name')
# 6   norm_sim_docvecs  ('docvecs', 'naics_name')
# 7   norm_sim_docvecs  ('docvecs', 'naics_name')
# 8   norm_sim_docvecs  ('docvecs', 'naics_name')
# 9   norm_sim_docvecs  ('docvecs', 'naics_name')
# 10  norm_sim_docvecs  ('docvecs', 'naics_name')
# 11  norm_sim_docvecs  ('docvecs', 'naics_name')
# 12  norm_sim_docvecs  ('docvecs', 'naics_name')
# 13  norm_sim_docvecs  ('docvecs', 'naics_name')
# 14  norm_sim_docvecs  ('docvecs', 'naics_name')
# 15  norm_sim_docvecs  ('docvecs', 'naics_name')
# 18  norm_sim_docvecs  ('docvecs', 'naics_name')
# 19  norm_sim_docvecs  ('docvecs', 'naics_name')
#
# [504 rows x 9 columns]
# INFO:root:('docvecs', 'primclass')
#                                                 index    1975-85     1985-95  \
# 0                            C(common_est_inv)[T.1.0]     0.0031   0.0078***
# 1                                                       (0.0025)    (0.0012)
# 2                           C(common_pat_inv)[T.True]  0.1114***   0.0987***
# 3                                                       (0.0237)    (0.0129)
# 4                            C(inv_msa_match)[T.True]     0.0014   0.0034***
# 5                                                       (0.0020)    (0.0011)
# 6                             C(lawyer_match)[T.True]    0.0271*   0.0314***
# 7                                                       (0.0145)    (0.0057)
# 8                             mean_sim_docvecs_pc_msa  0.1188***   0.1183***
# 9                                                       (0.0136)    (0.0082)
# 12                                                $N$      38324      106152
# 13                                     Adjusted $R^2$       0.08        0.08
# 0                            C(common_est_inv)[T.1.0]     0.0030   0.0078***
# 1                                                       (0.0025)    (0.0012)
# 2                           C(common_pat_inv)[T.True]  0.1106***   0.0995***
# 3                                                       (0.0237)    (0.0129)
# 4                            C(inv_msa_match)[T.True]    -0.0046    0.0081**
# 5                                                       (0.0072)    (0.0039)
# 6    C(inv_msa_match)[T.True]:mean_sim_docvecs_pc_msa     0.0264     -0.0210
# 7                                                       (0.0317)    (0.0179)
# 8                             C(lawyer_match)[T.True]    0.0262*   0.0317***
# 9                                                       (0.0145)    (0.0057)
# 10                            mean_sim_docvecs_pc_msa  0.1148***   0.1218***
# 11                                                      (0.0144)    (0.0087)
# 14                                                $N$      38324      106152
# 15                                     Adjusted $R^2$       0.08        0.08
# 0                            C(common_est_inv)[T.1.0]     0.0030   0.0078***
# 1                                                       (0.0025)    (0.0012)
# 2                           C(common_pat_inv)[T.True]  0.1117***   0.0992***
# 3                                                       (0.0238)    (0.0129)
# ..                                                ...        ...         ...
# 6   C(inv_msa_match)[T.True]:norm_mean_sim_docvecs...     0.0412     -0.0146
# 7                                                       (0.0266)    (0.0144)
# 8   C(inv_msa_match)[T.True]:np.power(norm_mean_si...    -0.0018      0.0015
# 9                                                       (0.0028)    (0.0016)
# 10                            C(lawyer_match)[T.True]    0.1896*   0.2298***
# 11                                                      (0.1046)    (0.0408)
# 12                       norm_mean_sim_docvecs_pc_msa  0.0826***   0.0851***
# 13                                                      (0.0108)    (0.0065)
# 14          np.power(norm_mean_sim_docvecs_pc_msa, 3)  -0.0030**  -0.0030***
# 15                                                      (0.0014)    (0.0009)
# 18                                                $N$      38324      106152
# 19                                     Adjusted $R^2$       0.08        0.08
# 0                            C(common_est_inv)[T.1.0]     0.0218   0.0566***
# 1                                                       (0.0184)    (0.0089)
# 2                           C(common_pat_inv)[T.True]  0.7929***   0.7155***
# 3                                                       (0.1716)    (0.0933)
# 4                            C(inv_msa_match)[T.True]    -0.0085   0.0390***
# 5                                                       (0.0235)    (0.0128)
# 6   C(inv_msa_match)[T.True]:pc_msa_greater_0:norm...     0.0142     -0.0167
# 7                                                       (0.0196)    (0.0114)
# 8   C(inv_msa_match)[T.True]:pc_msa_less_0:norm_me...   -0.1366*     -0.0299
# 9                                                       (0.0791)    (0.0470)
# 10                            C(lawyer_match)[T.True]    0.1847*   0.2275***
# 11                                                      (0.1048)    (0.0409)
# 12      pc_msa_greater_0:norm_mean_sim_docvecs_pc_msa  0.0764***   0.0769***
# 13                                                      (0.0109)    (0.0067)
# 14         pc_msa_less_0:norm_mean_sim_docvecs_pc_msa    0.0301*   0.0446***
# 15                                                      (0.0183)    (0.0105)
# 18                                                $N$      38324      106152
# 19                                     Adjusted $R^2$       0.08        0.08
#
#        1995-05     2005-15                       Model  Model Num  \
# 0    0.0065***   0.0068***           Inv FE-Sim PC MSA         23
# 1     (0.0008)    (0.0005)           Inv FE-Sim PC MSA         23
# 2    0.1032***   0.0895***           Inv FE-Sim PC MSA         23
# 3     (0.0085)    (0.0069)           Inv FE-Sim PC MSA         23
# 4    0.0044***   0.0022***           Inv FE-Sim PC MSA         23
# 5     (0.0008)    (0.0006)           Inv FE-Sim PC MSA         23
# 6    0.0286***   0.0261***           Inv FE-Sim PC MSA         23
# 7     (0.0050)    (0.0042)           Inv FE-Sim PC MSA         23
# 8    0.1500***   0.1698***           Inv FE-Sim PC MSA         23
# 9     (0.0069)    (0.0064)           Inv FE-Sim PC MSA         23
# 12      205248      324142           Inv FE-Sim PC MSA         23
# 13        0.09        0.06           Inv FE-Sim PC MSA         23
# 0    0.0065***   0.0068***           Inv FE-Int PC MSA         24
# 1     (0.0008)    (0.0005)           Inv FE-Int PC MSA         24
# 2    0.1037***   0.0901***           Inv FE-Int PC MSA         24
# 3     (0.0085)    (0.0070)           Inv FE-Int PC MSA         24
# 4    0.0091***    0.0054**           Inv FE-Int PC MSA         24
# 5     (0.0029)    (0.0025)           Inv FE-Int PC MSA         24
# 6      -0.0224     -0.0158           Inv FE-Int PC MSA         24
# 7     (0.0140)    (0.0123)           Inv FE-Int PC MSA         24
# 8    0.0288***   0.0262***           Inv FE-Int PC MSA         24
# 9     (0.0050)    (0.0042)           Inv FE-Int PC MSA         24
# 10   0.1542***   0.1730***           Inv FE-Int PC MSA         24
# 11    (0.0075)    (0.0069)           Inv FE-Int PC MSA         24
# 14      205248      324142           Inv FE-Int PC MSA         24
# 15        0.09        0.06           Inv FE-Int PC MSA         24
# 0    0.0065***   0.0068***        Inv FE-Sim PC MSA-Cb         25
# 1     (0.0008)    (0.0005)        Inv FE-Sim PC MSA-Cb         25
# 2    0.1034***   0.0903***        Inv FE-Sim PC MSA-Cb         25
# 3     (0.0085)    (0.0069)        Inv FE-Sim PC MSA-Cb         25
# ..         ...         ...                         ...        ...
# 6       0.0021      0.0064  N Inv FE-Int PC MSA-Int Cb         56
# 7     (0.0106)    (0.0092)  N Inv FE-Int PC MSA-Int Cb         56
# 8      -0.0007     -0.0010  N Inv FE-Int PC MSA-Int Cb         56
# 9     (0.0012)    (0.0011)  N Inv FE-Int PC MSA-Int Cb         56
# 10   0.2074***   0.1903***  N Inv FE-Int PC MSA-Int Cb         56
# 11    (0.0358)    (0.0299)  N Inv FE-Int PC MSA-Int Cb         56
# 12   0.1030***   0.1121***  N Inv FE-Int PC MSA-Int Cb         56
# 13    (0.0053)    (0.0049)  N Inv FE-Int PC MSA-Int Cb         56
# 14  -0.0032***  -0.0029***  N Inv FE-Int PC MSA-Int Cb         56
# 15    (0.0008)    (0.0007)  N Inv FE-Int PC MSA-Int Cb         56
# 18      205248      324142  N Inv FE-Int PC MSA-Int Cb         56
# 19        0.09        0.06  N Inv FE-Int PC MSA-Int Cb         56
# 0    0.0471***   0.0497***   N Inv FE-Break Int PC MSA         57
# 1     (0.0055)    (0.0039)   N Inv FE-Break Int PC MSA         57
# 2    0.7475***   0.6479***   N Inv FE-Break Int PC MSA         57
# 3     (0.0613)    (0.0502)   N Inv FE-Break Int PC MSA         57
# 4    0.0524***   0.0295***   N Inv FE-Break Int PC MSA         57
# 5     (0.0085)    (0.0063)   N Inv FE-Break Int PC MSA         57
# 6   -0.0267***  -0.0212***   N Inv FE-Break Int PC MSA         57
# 7     (0.0089)    (0.0075)   N Inv FE-Break Int PC MSA         57
# 8       0.0202      0.0118   N Inv FE-Break Int PC MSA         57
# 9     (0.0422)    (0.0406)   N Inv FE-Break Int PC MSA         57
# 10   0.2071***   0.1887***   N Inv FE-Break Int PC MSA         57
# 11    (0.0357)    (0.0300)   N Inv FE-Break Int PC MSA         57
# 12   0.1042***   0.1148***   N Inv FE-Break Int PC MSA         57
# 13    (0.0057)    (0.0051)   N Inv FE-Break Int PC MSA         57
# 14   0.0402***   0.0456***   N Inv FE-Break Int PC MSA         57
# 15    (0.0088)    (0.0084)   N Inv FE-Break Int PC MSA         57
# 18      205248      324142   N Inv FE-Break Int PC MSA         57
# 19        0.09        0.06   N Inv FE-Break Int PC MSA         57
#
#                  LKS                      samp
# 0        sim_docvecs  ('docvecs', 'primclass')
# 1        sim_docvecs  ('docvecs', 'primclass')
# 2        sim_docvecs  ('docvecs', 'primclass')
# 3        sim_docvecs  ('docvecs', 'primclass')
# 4        sim_docvecs  ('docvecs', 'primclass')
# 5        sim_docvecs  ('docvecs', 'primclass')
# 6        sim_docvecs  ('docvecs', 'primclass')
# 7        sim_docvecs  ('docvecs', 'primclass')
# 8        sim_docvecs  ('docvecs', 'primclass')
# 9        sim_docvecs  ('docvecs', 'primclass')
# 12       sim_docvecs  ('docvecs', 'primclass')
# 13       sim_docvecs  ('docvecs', 'primclass')
# 0        sim_docvecs  ('docvecs', 'primclass')
# 1        sim_docvecs  ('docvecs', 'primclass')
# 2        sim_docvecs  ('docvecs', 'primclass')
# 3        sim_docvecs  ('docvecs', 'primclass')
# 4        sim_docvecs  ('docvecs', 'primclass')
# 5        sim_docvecs  ('docvecs', 'primclass')
# 6        sim_docvecs  ('docvecs', 'primclass')
# 7        sim_docvecs  ('docvecs', 'primclass')
# 8        sim_docvecs  ('docvecs', 'primclass')
# 9        sim_docvecs  ('docvecs', 'primclass')
# 10       sim_docvecs  ('docvecs', 'primclass')
# 11       sim_docvecs  ('docvecs', 'primclass')
# 14       sim_docvecs  ('docvecs', 'primclass')
# 15       sim_docvecs  ('docvecs', 'primclass')
# 0        sim_docvecs  ('docvecs', 'primclass')
# 1        sim_docvecs  ('docvecs', 'primclass')
# 2        sim_docvecs  ('docvecs', 'primclass')
# 3        sim_docvecs  ('docvecs', 'primclass')
# ..               ...                       ...
# 6   norm_sim_docvecs  ('docvecs', 'primclass')
# 7   norm_sim_docvecs  ('docvecs', 'primclass')
# 8   norm_sim_docvecs  ('docvecs', 'primclass')
# 9   norm_sim_docvecs  ('docvecs', 'primclass')
# 10  norm_sim_docvecs  ('docvecs', 'primclass')
# 11  norm_sim_docvecs  ('docvecs', 'primclass')
# 12  norm_sim_docvecs  ('docvecs', 'primclass')
# 13  norm_sim_docvecs  ('docvecs', 'primclass')
# 14  norm_sim_docvecs  ('docvecs', 'primclass')
# 15  norm_sim_docvecs  ('docvecs', 'primclass')
# 18  norm_sim_docvecs  ('docvecs', 'primclass')
# 19  norm_sim_docvecs  ('docvecs', 'primclass')
# 0   norm_sim_docvecs  ('docvecs', 'primclass')
# 1   norm_sim_docvecs  ('docvecs', 'primclass')
# 2   norm_sim_docvecs  ('docvecs', 'primclass')
# 3   norm_sim_docvecs  ('docvecs', 'primclass')
# 4   norm_sim_docvecs  ('docvecs', 'primclass')
# 5   norm_sim_docvecs  ('docvecs', 'primclass')
# 6   norm_sim_docvecs  ('docvecs', 'primclass')
# 7   norm_sim_docvecs  ('docvecs', 'primclass')
# 8   norm_sim_docvecs  ('docvecs', 'primclass')
# 9   norm_sim_docvecs  ('docvecs', 'primclass')
# 10  norm_sim_docvecs  ('docvecs', 'primclass')
# 11  norm_sim_docvecs  ('docvecs', 'primclass')
# 12  norm_sim_docvecs  ('docvecs', 'primclass')
# 13  norm_sim_docvecs  ('docvecs', 'primclass')
# 14  norm_sim_docvecs  ('docvecs', 'primclass')
# 15  norm_sim_docvecs  ('docvecs', 'primclass')
# 18  norm_sim_docvecs  ('docvecs', 'primclass')
# 19  norm_sim_docvecs  ('docvecs', 'primclass')
#
# [184 rows x 9 columns]

# %%
r.to_csv(pathdir+"reg_pairs_out_1003.csv")
